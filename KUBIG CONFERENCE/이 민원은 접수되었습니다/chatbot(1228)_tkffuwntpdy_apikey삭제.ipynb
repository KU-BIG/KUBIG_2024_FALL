# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install -U langchain_community tiktoken langchainhub langchain langgraph chromadb

# !pip install -qU langchain-core langchain-upstage langchain-chroma
# !pip install -qU python-dotenv

from langchain.docstore.document import Document
# !pip install tavily-python
from langchain_community.retrievers import TavilySearchAPIRetriever

from langchain import hub
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_upstage import UpstageEmbeddings, ChatUpstage
from langchain.vectorstores import Chroma
from langgraph.graph import END, StateGraph, START
from langchain_core.pydantic_v1 import BaseModel, Field

from dotenv import load_dotenv
from IPython import get_ipython
import numpy as np
import os
import pandas as pd
from pprint import pprint
import re
from typing import List, Dict
from typing_extensions import TypedDict
import warnings
warnings.filterwarnings("ignore")

# !pip install -U langchain-upstage
# !pip install openai==0.27.2

# %%
API_KEYS = {
    "UPSTAGE_API_KEY": None,
    "TAVILY_API_KEY" : None
}

def load_env():
    # 환경 변수 설정
    if "google.colab" in str(get_ipython()):  # Google Colab 환경
        os.environ['UPSTAGE_API_KEY'] = ''
        API_KEYS["UPSTAGE_API_KEY"] = os.environ.get("UPSTAGE_API_KEY")
        os.environ['TAVILY_API_KEY'] = ''
        API_KEYS["TAVILY_API_KEY"] = os.environ.get("TAVILY_API_KEY")
    else:  # 로컬 환경
        load_dotenv()  # .env 파일 로드
        API_KEYS["UPSTAGE_API_KEY"] = os.environ.get("UPSTAGE_API_KEY")
        API_KEYS["TAVILY_API_KEY"] = os.environ.get("TAVILY_API_KEY")

    return API_KEYS["UPSTAGE_API_KEY"], API_KEYS["TAVILY_API_KEY"]

UPSTAGE_API_KEY, TAVILY_API_KEY= load_env()

# %%
from openai import OpenAI
client =OpenAI(api_key='')

# %% [markdown]
# # Chatbot

# %%
# 기존 설정
embedding_function = UpstageEmbeddings(model="solar-embedding-1-large")

# 두 개의 Chroma 인스턴스 생성
persist_directory = '/content/drive/MyDrive/policy_chatbot/policy_combined'
db = Chroma(embedding_function=embedding_function, persist_directory=persist_directory)
retriever = db.as_retriever(search_kwargs={"k": 3})

# %% [markdown]
# ### Retrieval Gradar

# %%
# LLM 기반 검색 시스템에서 검색된 문서의 적합성을 자동으로 평가
# 사용자가 특정 질문을 했을 때, 검색된 문서가 그 질문에 적합한지를 판단하여 "yes" 또는 "no"로 점수를 매긴다.


# Data model
class GradeDocuments(BaseModel):
    """Binary score for relevance check on retrieved documents."""
    # 검색된 문서가 질문에 적합한지를 'yes' 또는 'no'로 저장
    binary_score: str = Field(
        description="Documents are relevant to the conversation history and question, 'yes' or 'no'"
    )

# LLM with function call
llm_1 = ChatUpstage(max_tokens=200, temperature=0) # Parameter tuning 1
# 모델이 구조화된 데이터(GradeDocuments)를 반환하도록 설정
structured_llm_grader = llm_1.with_structured_output(GradeDocuments)

# System Prompt: 검색한 문서에 유저 질문 관련 키워드가 포함되거나 의미적으로 관련이 있으면, 'relevant'로 판단. 결과는 'yes' 또는 'no'로 이진 점수를 줌.
system = """You are a grader assessing relevance of a retrieved document to a user question. \n
    It does not need to be a stringent test. The goal is to filter out erroneous retrievals. \n
    If the document contains keyword(s) or semantic meaning related to the question, grade it as relevant. \n
    Give a binary score 'yes' or 'no' score to indicate whether the document is relevant to the question. \n
    'Yes' means that the document is relevant to the question."""


# grade_prompt = System prompt + 검색된 문서 + 사용자 질문
grade_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system),
        ("human", "Retrieved document: \n\n {document} \n\n User question: {question}"),
    ]
)
# grade_prompt와 structured_llm_grader을 결합하여 문서 평가를 위한 객체 생성
retrieval_grader = grade_prompt | structured_llm_grader

# Wrapper for consistent output
def grade_retrieval(doc_txt, user_question):
    """
    Grades the relevance of a document to the combined question.

    Args:
        doc_txt (str): The text of the document to grade.
        combined_question (str): The combined question including chat history.

    Returns:
        str: 'yes' or 'no' based on relevance grading.
    """
    try:
        # Invoke grader
        result = retrieval_grader.invoke({"document": doc_txt, "question": user_question})
        print(f"Raw result from grader: {result}")

        if result and hasattr(result, "binary_score"):
            return result.binary_score
        else:
            print(f"Invalid result structure: {result}")
    except Exception as e:
        print(f"Error during retrieval grading: {e}")

    # Default to 'no' if something goes wrong
    print('None')
    return "no"

# %%
# example
chat_history = [
    {"role": "user", "content": "나는 서울에 거주하는 25살 대학 졸업자야. 나에게 맞는 정책을 추천해줘."},
    {"role": "assistant", "content": "당신은 25살이고 대학을 졸업한 상태이므로, '동작구 청년 맞춤형 공공주택 입주자 모집' 정책이 적합합니다."},
]

chat_history=[]
user_question = "으뜸관악 청년통장에 대해 말해봐"
# Combine chat history and user question
combined_question = "\n".join(
    [f"{entry['role']}: {entry['content']}" for entry in chat_history]
) + f"\nuser: {user_question}"

# 질문에 대해 관련 문서를 검색
docs = retriever.get_relevant_documents(combined_question)
# 검색된 문서 중 하나를 추출
doc_txt = docs[0].page_content

graded_result = grade_retrieval(doc_txt, user_question)
print(graded_result)
# Out:
# Raw result from grader: binary_score='yes'
# yes

# %% [markdown]
# ### Generate

# %%
generate_system = """
    당신은 질문에 답변을 제공하는 AI 비서입니다. 검색된 context를 바탕으로 질문에 답변하세요. 만약 답을 모를 경우, 모른다고 솔직히 말하세요. \n
    청년 연령, 직업, 주거 상황, 정책 경험 여부 등 다양한 상황을 고려하여 맞춤형 답변을 제공합니다.

    질문의 유형에 따라 아래 지침을 선택하고, 이 지침을 준수하여 답변을 작성하세요: \n
    1.** 정책 추천 질문에 대한 지침 **
    - 아래 형식으로 답변하세요:
      ① 정책명:
      ② 추천 이유: 질문에서 제공된 연령, 상황, 선호도 등을 바탕으로 정책이 왜 적합한지 설명하세요.
      ③ 제공 혜택: 정책을 통해 얻을 수 있는 구체적인 이점을 서술하세요.
    - 정책 추천 시, 최소 2개 이상의 정책은 추천해야 하고, 아래 데이터를 적극 활용하여 가장 추천이 우선시 되는 정책부터 나열해주세요:
        * **복지 및 문화 관련 이슈**
          - 대학생: 진로 불확실성, 졸업유예 증가, 등록금 부담.
          - 직장인: 저임금, 고용불안(1-2년) 우려.
          - 미취업자: 심리상담 지원, 대중교통비 지원 선호.
          - 전반적으로 청년들은 안정적인 자립 지원과 금전적 지원에 대한 관심이 높음.
          - 대중교통비 지원, 심리상담 지원, 문화활동 및 여행 장려금 지원 등이 주요 선호 정책으로 나타남.
    - 높임말 대신 "~요"로 끝나는 말투를 사용하세요.
    - 답변의 시작은 반드시 "세은님에게 맞는 정책을 찾아보았어요😊\n"로 시작하세요.
    - 답변의 끝은 반드시 "\n정책에 대해 더 구체적으로 알고 싶으신가요?"로 끝내세요.

    2. ** 정책 세부 정보 요청 질문에 대한 지침 **
    - 답변의 시작에는 반드시 사용자가 어떤 정책의 어떤 내용을 궁금해하는지 요약하고, "제가 구체적으로 알려드릴게요😄\n" 문장을 추가하세요.
    - 높임말 대신, "~요"로 끝나는 말투를 사용하세요. 예: "알려드릴게요", "도움이 되셨으면 해요"
    - 답변은 나열식이 아닌 줄글 형식으로 작성하세요.
    - 답변의 끝에는 반드시 "\n궁금증이 해결되었나요?" 문장을 추가하세요.
    - **예시 답변 형식**:
    > "경기도 면접수당 정책의 신청 기간이 궁금하셨군요. 제가 구체적으로 알려드릴게요😄\n 신청 기간은 2024년 5월 2일부터 5월 30일까지입니다. \n궁금증이 해결되었나요?"

    3. ** 정책 용어 설명 요청 질문에 대한 지침 **
    - 답변의 시작에는 반드시 사용자가 어떤 단어의 뜻을 궁금해하는지 요약하고, "제가 구체적으로 알려드릴게요😄\n" 문장을 추가하세요.
    - 높임말 대신, "~요"로 끝나는 말투를 사용하세요. 예: "알려드릴게요", "도움이 되셨으면 해요"
    - 문서에 있는 내용을 기반으로 답변은 나열식이 아닌 줄글 형식으로 작성하고, 간결하게 설명하세요.
    - 답변의 끝에는 반드시 "\n궁금증이 해결되었나요?" 문장을 추가하세요.
    - **예시 답변 형식**:
    > "가등기가 무슨 뜻인지 궁금하셨군요. 제가 구체적으로 알려드릴게요😄\n 가등기란, 등기로 표시된 부동산의 권리관계가 외부에 표시되기 때문에 제3자에게도 대항할 수 있는데, 권리관계가 확정되지 않는 등으로 등기를 할 수 없을 경우에 임시로 하는 등기를 뜻합니다. 궁금증이 해결되었나요?"

    4. ** 정책 후기 요청 질문에 대한 지침 **
    - 답변의 시작에는 반드시 사용자가 어떤 정책의 후기를 궁금해하는지 요약하고, "제가 검색해보았어요🔎\n" 문장을 추가하세요.
    - 높임말 대신, "~요"로 끝나는 말투를 사용하세요. 예: "알려드릴게요", "도움이 되셨으면 해요"
    - 문서에는 후기가 없으니 잘 모른다고 답변하고, 외부 검색 기능을 이용하여 답변하세요.
    - 답변의 끝에는 반드시 "\n궁금증이 해결되었나요?" 문장을 추가하세요.
    - **예시 답변 형식**:
    > "경기도 면접수당 정책의 실제 블로그 후기가 궁금하셨군요. 제가 검색해보았어요🔎\n[후기 요약]\n궁금증이 해결되었나요?"
    """

TOKEN_PER_CHAR = 4

def estimate_tokens(text):
    return len(text) // TOKEN_PER_CHAR

# Function to format documents without exceeding the token limit
def format_docs(docs, max_tokens=110000):
    formatted_docs = []
    current_chunk = ""
    current_token_count = 0

    for doc in docs:
        doc_content = doc.page_content
        doc_token_count = estimate_tokens(doc_content)

        # If adding this document exceeds the token limit, start a new chunk
        if current_token_count + doc_token_count > max_tokens:
            formatted_docs.append(current_chunk)
            current_chunk = doc_content  # Start a new chunk
            current_token_count = doc_token_count
        else:
            current_chunk += "\n\n" + doc_content  # Append to the current chunk
            current_token_count += doc_token_count

    # Add the last chunk if there's any content left
    if current_chunk:
        formatted_docs.append(current_chunk)

    return formatted_docs

# 모델 호출 체인
def rag_chain(question, context):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system",
             "content": generate_system},
            {"role": "user",
             "content": f"Question: {question}\n\nContext: {context}\nAnswer the question."},
        ],
        max_tokens=400,
        temperature=0,
    )
    return response.choices[0].message.content

# %%
# 예시 데이터: docs 리스트가 비어있다면, 빈 문자열로 전달
docs = []

combined_question = "서울 청년정책 추천해줘"

# 컨텍스트를 문자열로 포맷
context = format_docs(docs)

# rag_chain 호출
generation = rag_chain(combined_question, context)

# %%
generation
# Out:
# '세은님에게 맞는 정책을 찾아보았어요😊\n\n① 정책명: 서울 청년수당  \n② 추천 이유: 세은님이 청년 정책에 관심이 있으시다면, 서울 청년수당이 도움이 될 것 같아요. 이 정책은 경제적 지원을 통해 청년들이 자립할 수 있도록 돕는 프로그램이에요.  \n③ 제공 혜택: 청년수당을 통해 매달 일정 금액을 지원받을 수 있어요. 이를 통해 생활비 부담을 줄이고, 취업 준비나 자기계발에 집중할 수 있는 기회를 제공받을 수 있어요.  \n\n정책에 대해 더 구체적으로 알고 싶으신가요?'

# %% [markdown]
# ### Answer Grader

# %%
import json
# Data model
class GradeAnswer(BaseModel):
    """Binary score to assess answer addresses question."""

    binary_score: str = Field(
        description="Answer addresses the question, 'yes' or 'no'"
    )
    confidence: float = Field(
        description="Confidence score for the assessment, range 0 to 1"
    )

# Revised System Prompt
answer_system_strict = """당신은 응답이 질문에 적절한지 엄격히 평가하는 채점자입니다.
    1. 응답이 문서의 신뢰할 수 있는 정보를 바탕으로 질문에 명확히 답했는지 확인하세요.
    2. 문서 내용이 질문과 관련 없거나 응답이 문서를 정확히 반영하지 않으면 '아니오'를 반환하세요.
    3. 응답이 신뢰할 수 없는 내용을 포함하거나 불확실하면 '아니오'를 반환하세요.
    4. '예'로 평가하려면 문서 내용을 충분히 참고하여 질문을 직접 해결해야 합니다.
    5. 정책의 후기를 묻는 질문에 대한 답변이 '후기는 sns나 블로그를 통해 찾을 수 있어요' 와 같이 자세하지 않은 내용을 포함한 경우 '아니오'를 반환하세요.

    응답을 반드시 다음 JSON 형식으로 반환하세요:
{
    "binary_score": "yes" 또는 "no",
    "confidence": 0에서 1 사이의 부동소수점 값
}
"""


def answer_grader(question, generation, document):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system",
             "content": answer_system_strict},
            {"role": "user",
             "content": f"User question: {question}\n\nLLM generation: {generation}\n\nContext: {document}\nEvaluate the generated answer strictly based on the context."},
        ],
        max_tokens=400,
        temperature=0,
    )
    print("Raw response:", response.choices[0].message.content)
    try:
        response_data = json.loads(response.choices[0].message.content)
        binary_score = response_data.get("binary_score", "no")  # "binary_score"가 없으면 기본값 "no" 반환
    except json.JSONDecodeError as e:
        print(f"Error parsing JSON: {e}")
        binary_score = "no"  # 파싱 오류가 발생하면 기본값 "no" 반환

    return binary_score

# %%
# example
answer_grader.invoke(
    {"question": user_question, "generation": generation})
# Out:
# GradeAnswer(binary_score='yes')

# %% [markdown]
# ### Question Re Writer

# %%
# LLM을 활용하여 주어진 질문을 "벡터스토어 검색에 최적화된 질문"으로 재작성

# LLM
llm_5 = ChatUpstage(max_tokens=200, temperature=0)

question_rewriter_system = """
    당신은 입력된 질문을 벡터 저장소 검색에 최적화된 더 나은 버전으로 변환하는 질문 재작성자입니다. 입력 내용을 바탕으로, 간단하고 명료한 질문으로 재작성하세요. 문장 간 내용이 다른 범주라 느껴지면 과감히 앞 내용은 버리세요.
    """

re_write_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", question_rewriter_system),
        (
            "human",
           " {question} \n Formulate an improved question.",
        ),
    ]
)

question_rewriter = re_write_prompt | llm_5 | StrOutputParser()

# %%
# example

combined_question = "서울 청년정책 추천해줘. 전라남도 청년정책 추천해줘"

question_rewriter.invoke({"question": combined_question})
# Out:
# '다음은 개선된 질문입니다:\n\n서울시 청년정책, 부산 마음이음 정책, 전라도 신혼부부를 위한 정책에 대해 알려주세요.'

# %% [markdown]
# # Structure

# %%
class GraphState(TypedDict):
    """
    Represents the state of our graph.

    Attributes:
        question: Combined question including chat history and user query.
        generation: LLM generation
        documents: list of documents
        chat_history: List of chat messages containing role and content.
    """

    question: str
    generation: str
    documents: List[str]
    first_generate_attempt: bool

# %% [markdown]
# ## Function

# %%
### Nodes

def check_documents(state):
    """
    Check if documents exist in the current state and update the state accordingly.

    Args:
        state (dict): The current graph state.

    Returns:
        dict: Updated state with a flag indicating the next step.
    """

    if state.get("documents"):
        print("Documents found, marking for 'generate_first'.")
        state["next_node"] = "generate_first"  # Add a marker for the next step
    else:
        print("No documents found, marking for 'retrieve'.")
        state["next_node"] = "retrieve"  # Add a marker for the next step

    return state


def retrieve(state):
    """
    Retrieve documents and update the current state.

    Args:
        state (dict): The current graph state.

    Returns:
        dict: Updated state with retrieved documents.
    """
    print("---RETRIEVE---")
    question = state["question"]

    # Process the question
    if re.search(r'\n\s*user', question):
        lines = question.split("\nuser")
        question_to_retrieve = "\nuser".join(lines[:-1])
    else:
        question_to_retrieve = question

    # Retrieve documents
    documents = retriever.get_relevant_documents(question_to_retrieve)
    print("Retrieved documents:", documents)

    # Update state
    state["documents"] = documents
    return state




def generate(state):
    """
    Generate answer based on the current state.

    Args:
        state (dict): The current graph state containing question and documents.

    Returns:
        dict: Updated state with the generated answer added under the key 'generation'.
    """
    print("---GENERATE---")

    # Extract question and documents from state
    question = state.get("question")
    documents = state.get("documents")

    if not question or not documents:
        raise ValueError("State must include both 'question' and 'documents' keys with valid data.")

    # Format the documents into a single context string
    context = format_docs(documents)

    # Invoke RAG chain to get the generation
    generation = rag_chain(question, context)

    # Return updated state with the generation
    updated_state = {
        **state,
        "generation": generation,
    }

    return updated_state


def extract_last_question(combined_question):
    """
    Extracts the last user question from the combined question.

    Args:
        combined_question (str): The combined question including chat history.

    Returns:
        str: The last user question.
    """
    lines = combined_question.split("\n")
    for line in reversed(lines):
        if line.startswith("user:"):
            return line[len("user: "):].strip()  # Remove "user: " prefix
    return ""  # Default to empty if no user question found



def grade_documents(state):
    """
    Determines whether the retrieved documents are relevant to the question.

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Updates documents key with only filtered relevant documents
    """

    print("---CHECK DOCUMENT RELEVANCE TO QUESTION---")
    question = state["question"]
    documents = state["documents"]

    # Extract the last question
    last_question = extract_last_question(question)
    print(f"Last User Question: {last_question}")  # Debugging: Check extracted question

    # Score each doc
    filtered_docs = []
    all_irrelevant = True
    for d in documents:
        grade = grade_retrieval(d, last_question)
        if grade == "yes":
            print("---GRADE: DOCUMENT RELEVANT---")
            filtered_docs.append(d)
            all_irrelevant = False
              # At least one document is relevant
        else:
            print("---GRADE: DOCUMENT NOT RELEVANT---")
            continue

    # Update state
    state["documents"] = filtered_docs

    # Add a flag to indicate if all documents were irrelevant
    state["all_documents_irrelevant"] = all_irrelevant

    return state



def transform_query(state):
    """
    Transform the query to produce a better question.

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Updates question key with a re-phrased question
    """

    print("---TRANSFORM QUERY---")
    question = state["question"]
    documents = state["documents"]

    # Re-write question
    better_question = question_rewriter.invoke({"question": question})
    return {"documents": documents, "question": better_question}


### Edges


def decide_to_generate(state):
    """
    Determines whether to generate an answer, or re-generate a question.

    Args:
        state (dict): The current graph state

    Returns:
        str: Binary decision for next node to call
    """

    print("---ASSESS GRADED DOCUMENTS---")

    # Extract the last user question directly from the state
    last_question = extract_last_question(state["question"])
    print(f"Last User Question: {last_question}")  # Debugging

    # If all documents are irrelevant, transform the query
    if state.get("all_documents_irrelevant", False):  # Check if irrelevant is True
        print("---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, INIT QUERY---")
        return "init_query"

    # If documents are relevant, generate a response
    else:
        print("---DECISION: GENERATE---")
        return "transform_query"

# %%
# Initialize the not useful counter
not_useful_count = 0
first_generate_count=0

def grade_generation_v_documents_and_question(state):
    """
    Determines whether the generation answers the question.
    Returns:
        str: 'useful', 'not useful', or 'fallback'.
    """
    global not_useful_count
    global first_generate_count

    print("---GRADE GENERATION vs QUESTION---")
    question = state["question"]
    documents = state["documents"]
    generation = state["generation"]

    # Extract the last question for grading
    last_question = extract_last_question(question)

    try:
        # Perform grading based on whether it's the first attempt
        if first_generate_count==0 :
            grade = answer_grader(last_question, generation, documents)
        else:
            grade = answer_grader(question, generation, documents)
    except Exception as e:
        print(f"Error during answer grading: {e}")
        grade = "no"
    if first_generate_count== 0 :
        if grade == "yes":
            print("---FIRST GENERATE ATTEMPT: USEFUL")
            return "useful"
        else:
            print("---FIRST GENERATE ATTEMPT: NOT USEFUL")
            first_generate_count += 1
            return "not useful"
    else:
        if grade == "yes":
            print("---DECISION: GENERATION ADDRESSES QUESTION---")
            not_useful_count = 0
            first_generate_count=0  # Reset the counter
            return "useful"
        else:
            print(f"---DECISION: GENERATION DOES NOT ADDRESS QUESTION---")
            not_useful_count += 1
            print(f"---NOT USEFUL COUNT INCREMENTED: count={not_useful_count}---")
            if not_useful_count == 1:
                return "not useful"
            else:
                return "fallback"

# %%
def init_query(state):
    """
    Removes chat/document history, leaves only the last user question,
    and resets not_useful_count to 0.
    """
    print("---INIT QUERY (CLEAR HISTORY)---")
    # 마지막 사용자 질문만 뽑아오기
    last_question = extract_last_question(state["question"])

    # state 초기화
    state["question"] = f"user: {last_question}"
    state["documents"] = []
    state["generation"] = ""

    print(f"[init_query] Updated question = {state['question']}")
    return state

# %% [markdown]
# ### Tavily

# %%
def filter_documents(docs, question):
    """
    Filter retrieved documents for relevance to the question.

    Args:
        docs (list): List of retrieved documents.
        question (str): The user question.

    Returns:
        list: Filtered relevant documents.
    """
    relevant_docs = []
    for doc in docs:
        grade = grade_retrieval(doc.page_content, question)
        if grade == "yes":
            relevant_docs.append(doc)
    return relevant_docs


def tavily_search(state):
    """
    External search using Tavily and process the results into a structured markdown report.

    Args:
        state (dict): The current graph state

    Returns:
        dict: Updated state with processed documents and structured report
    """
    print("---TAVILY SEARCH---")
    question = state["question"]


    # Perform Tavily search
    tavily = TavilySearchAPIRetriever(k=3, search_depth="advanced", include_domains=["m.blog.naver.com"])
    print("Searching using Tavily...")

    docs_external = tavily.invoke(question)  # Tavily 검색 호출
    print(f"Search results: {len(docs_external)} documents found.")


    if docs_external:
        print("Relevant Tavily search results found.")
        return {"documents": docs_external, "question": question}
    else:
        print("No relevant documents found after filtering.")
        return {"documents": [], "question": question}

# %% [markdown]
# ## Workflow & App

# %%
# Define the workflow
workflow = StateGraph(GraphState)

# Define the nodes
workflow.add_node("retrieve", retrieve)  # Retrieve documents
workflow.add_node("grade_documents", grade_documents)
workflow.add_node("retrieve_no_grade", retrieve)  # Re-retrieve without grading
workflow.add_node("generate_first", generate)  # First generate
workflow.add_node("generate_second", generate)
workflow.add_node("init_query", init_query)  # Initialize query
workflow.add_node("transform_query1", transform_query)
workflow.add_node("transform_query2", transform_query)  # Transform query
workflow.add_node("tavily_search", tavily_search)  # External search node
workflow.add_node("check_documents", check_documents)  # Custom node to check documents


# Add edges for document check
workflow.add_edge(START, "check_documents")

workflow.add_conditional_edges(
    "check_documents",
    lambda state: state.get("next_node"),  # Use `next_node` to determine the flow
    {
        "generate_first": "generate_first",
        "retrieve": "retrieve"
    },
)

# First generate node
workflow.add_conditional_edges(
    "generate_first",
    grade_generation_v_documents_and_question,
    {
        "useful": "transform_query1",  # If generation is useful, end
        "not useful": "retrieve"
    },
)

workflow.add_edge("transform_query1", END)


# Define the main edges
workflow.add_edge("retrieve", "grade_documents")
workflow.add_conditional_edges(
    "grade_documents",
    decide_to_generate,
    {
        "init_query": "init_query",
        "transform_query": "transform_query2"
    },
)

workflow.add_edge("init_query", "retrieve_no_grade")
workflow.add_edge("retrieve_no_grade", "transform_query2")
workflow.add_edge("transform_query2", "generate_second")

# Second generate node
workflow.add_conditional_edges(
    "generate_second",
    grade_generation_v_documents_and_question,
    {
        "useful": END,  # If generation is useful, end
        "not useful": "generate_second",  # Retry with transformed query
        "fallback": "tavily_search"  # Retry generation with external search
    },
)

workflow.add_edge("tavily_search", "generate_second")

# Compile the workflow
app = workflow.compile()

# %%
# Main loop for user interaction
combined_question = ""  # Combined question including chat history
not_useful_count = 0  # Initialize the not useful counter

# Initialize state for retaining documents and other workflow information
state = {"documents": [], "question": ""}

# Reset workflow state if applicable
if hasattr(app, "reset"):
    app.reset()

# Main execution loop
while True:
    user_question = input("Enter your question (or 'exit' to quit): ")
    if user_question.lower() == "exit":
        break

    # Update the combined question for context
    if state["question"]:
        state["question"] += f"\nuser: {user_question}"
    else:
        state["question"] = f"user: {user_question}"

    # Prepare inputs for the workflow
    inputs = {
        "question": state["question"],
        "documents": state["documents"],  # Retain existing documents
    }

    # Stream workflow output
    for output in app.stream(inputs):
        for key, value in output.items():
            print(f"\nNode '{key}':")
            pprint(value.items(), indent=2, width=80, depth=None)

            # Handle document outputs
            if "documents" in value:
                print("\n--- RETRIEVED DOCUMENTS ---")
                print(value["documents"])

            # Handle generation outputs
            if "generation" in value:
                print("\n--- LLM GENERATION ---")
                print(value["generation"])

                state["question"] = value.get('question', state["question"])  # Update question if available
                state["documents"] = value.get('documents', state["documents"])

        print("\n---\n")
# Out:
# Enter your question (or 'exit' to quit): 전라남도 신혼부부를 위한 정책 추천해줘
# No documents found, marking for 'retrieve'.
#
# Node 'check_documents':
# dict_items([('question', 'user: 전라남도 신혼부부를 위한 정책 추천해줘 '), ('documents', [])])
#
# --- RETRIEVED DOCUMENTS ---
# []
#
# ---
#
# ---RETRIEVE---
# Retrieved documents: [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.'), Document(metadata={'id': 'R2024022720123', '정책 ID': 'R2024022720123', '정책명': '신혼부부 전세자금 대출이자 지원'}, page_content='{\n  "정책 ID": "R2024022720123",\n  "기관 코드": 3002005.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책명": "신혼부부 전세자금 대출이자 지원",\n  "정책소개": "신혼부부 주거비 부담 완화로 결혼/출산 친화환경 조성\\n(주택도시기금 신혼부부 전용 전세자금대출의 대출이자 지원)",\n  "지원내용": "□ 지원금액 : 납입한 대출이자의 일부지원\\n(자녀수별 차등 지원)* 무자녀 0.5%, 1자녀 0.7%, 2자녀 이상 1.0% \\n□ 지원한도 : 대출(신청)자가 은행에 납입한 총 이자액 범위 내\\n□ 지원기간 : 본인 대출기한 내 대출일로부터 최장 6년 (단, 2자녀이상일 경우 최장8년)\\n□ 지급방법 : 연간 2회(상,하반기) 청구 및 지급\\n□ 취급은행 : 농협은행, 우리은행, 국민은행, 신한은행, IBK기업은행",\n  "지원규모": "-",\n  "사업운영기간": "2024.01.01.~2024.12.31.",\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-01-01~2024-04-30,2024-07-01~2024-10-31\\n지원대상 접수기간\\n상반기(1차) : 2024. 1. 1. ~ 4. 30.\\n하반기(2차) : 2024. 7. 1. ~ 10. 31.",\n  "연령": "제한없음",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "-",\n  "추가 단서사항": "□ 지원대상 : 『주택도시기금 신혼부부 전용 전세자금대출』신규 대출자 및 대출 연장자(\'21.1월 이후)\\n❍ 대출(신청)자의 주민등록 및 임차(전세)주택 주소지가 광주지역에 소재\\n❍ 3개월이내 혼인 예정이거나 혼인신고일 기준 7년차 이내 무주택 신혼부부",\n  "참여 제한 대상": "-",\n  "신청절차": "광주아이키움 홈페이지 회원가입 후 신청\\n1. 신청서류 구비 > 2. 개인정보 수집 이용 동의 > 3. 신청 서류 제출(첨부파일) > 4. 접수확인",\n  "제출서류": "□ 신청시 구비서류\\n❍ 대출사실확인서\\n❍ 개인정보제공이용동의서\\n❍ 이자지원신청서\\n\\n□ 청구시 구비서류\\n❍ 이자납입내역서\\n❍ 주민등록등본\\n❍ 통장사본(지원금을 수령할 은행의 통장사본)\\n❍ 가족관계증명서(등본상 자녀수 미확인시 별도제출)",\n  "심사발표": "□ 상반기(1차)\\n지원대상 접수기간 : 2024. 1. 1. ~ 4. 30.\\n대출이자 청구기간 : 2024. 5. 1. ~ 5. 15.\\n대출이자 지원기간 : 2023. 11월 ~ 2024. 4월(6개월)\\n지급일 : 2024. 6월중\\n\\n□ 하반기(2차)\\n지원대상 접수기간 : 2024. 4. 1. ~ 10. 31.\\n대출이자 청구기간 : 2024. 11. 1. ~ 11. 15.\\n대출이자 지원기간 : 2024. 5월 ~ 2024. 10월(6개월)\\n지급일 : 2024. 12월중",\n  "신청 사이트": "https://www.광주아이키움.kr/main/hRentSubsidy",\n  "참고 사이트1": "https://www.광주아이키움.kr",\n  "참고 사이트2": "-",\n  "주관부처": "광주광역시 여성가족국 여성가족과",\n  "주관부처 담당자": "이초롱 ...
#
# Node 'retrieve':
# dict_items([('question', 'user: 전라남도 신혼부부를 위한 정책 추천해줘 '), ('documents', [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.'), Document(metadata={'id': 'R2024022720123', '정책 ID': 'R2024022720123', '정책명': '신혼부부 전세자금 대출이자 지원'}, page_content='{\n  "정책 ID": "R2024022720123",\n  "기관 코드": 3002005.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책명": "신혼부부 전세자금 대출이자 지원",\n  "정책소개": "신혼부부 주거비 부담 완화로 결혼/출산 친화환경 조성\\n(주택도시기금 신혼부부 전용 전세자금대출의 대출이자 지원)",\n  "지원내용": "□ 지원금액 : 납입한 대출이자의 일부지원\\n(자녀수별 차등 지원)* 무자녀 0.5%, 1자녀 0.7%, 2자녀 이상 1.0% \\n□ 지원한도 : 대출(신청)자가 은행에 납입한 총 이자액 범위 내\\n□ 지원기간 : 본인 대출기한 내 대출일로부터 최장 6년 (단, 2자녀이상일 경우 최장8년)\\n□ 지급방법 : 연간 2회(상,하반기) 청구 및 지급\\n□ 취급은행 : 농협은행, 우리은행, 국민은행, 신한은행, IBK기업은행",\n  "지원규모": "-",\n  "사업운영기간": "2024.01.01.~2024.12.31.",\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-01-01~2024-04-30,2024-07-01~2024-10-31\\n지원대상 접수기간\\n상반기(1차) : 2024. 1. 1. ~ 4. 30.\\n하반기(2차) : 2024. 7. 1. ~ 10. 31.",\n  "연령": "제한없음",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "-",\n  "추가 단서사항": "□ 지원대상 : 『주택도시기금 신혼부부 전용 전세자금대출』신규 대출자 및 대출 연장자(\'21.1월 이후)\\n❍ 대출(신청)자의 주민등록 및 임차(전세)주택 주소지가 광주지역에 소재\\n❍ 3개월이내 혼인 예정이거나 혼인신고일 기준 7년차 이내 무주택 신혼부부",\n  "참여 제한 대상": "-",\n  "신청절차": "광주아이키움 홈페이지 회원가입 후 신청\\n1. 신청서류 구비 > 2. 개인정보 수집 이용 동의 > 3. 신청 서류 제출(첨부파일) > 4. 접수확인",\n  "제출서류": "□ 신청시 구비서류\\n❍ 대출사실확인서\\n❍ 개인정보제공이용동의서\\n❍ 이자지원신청서\\n\\n□ 청구시 구비서류\\n❍ 이자납입내역서\\n❍ 주민등록등본\\n❍ 통장사본(지원금을 수령할 은행의 통장사본)\\n❍ 가족관계증명서(등본상 자녀수 미확인시 별도제출)",\n  "심사발표": "□ 상반기(1차)\\n지원대상 접수기간 : 2024. 1. 1. ~ 4. 30.\\n대출이자 청구기간 : 2024. 5. 1. ~ 5. 15.\\n대출이자 지원기간 : 2023. 11월 ~ 2024. 4월(6개월)\\n지급일 : 2024. 6월중\\n\\n□ 하반기(2차)\\n지원대상 접수기간 : 2024. 4. 1. ~ 10. 31.\\n대출이자 청구기간 : 2024. 11. 1. ~ 11. 15.\\n대출이자 지원기간 : 2024. 5월 ~ 2024. 10월(6개월)\\n지급일 : 2024. 12월중",\n  "신청 사이트": "https://www.광주아이키움.kr/main/hRentSubsidy",\n  "참고 사이트1": "https://www.광주아이키움.kr",\n  "참고 사이트2": "-",\ ...
#
# --- RETRIEVED DOCUMENTS ---
# [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.'), Document(metadata={'id': 'R2024022720123', '정책 ID': 'R2024022720123', '정책명': '신혼부부 전세자금 대출이자 지원'}, page_content='{\n  "정책 ID": "R2024022720123",\n  "기관 코드": 3002005.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책명": "신혼부부 전세자금 대출이자 지원",\n  "정책소개": "신혼부부 주거비 부담 완화로 결혼/출산 친화환경 조성\\n(주택도시기금 신혼부부 전용 전세자금대출의 대출이자 지원)",\n  "지원내용": "□ 지원금액 : 납입한 대출이자의 일부지원\\n(자녀수별 차등 지원)* 무자녀 0.5%, 1자녀 0.7%, 2자녀 이상 1.0% \\n□ 지원한도 : 대출(신청)자가 은행에 납입한 총 이자액 범위 내\\n□ 지원기간 : 본인 대출기한 내 대출일로부터 최장 6년 (단, 2자녀이상일 경우 최장8년)\\n□ 지급방법 : 연간 2회(상,하반기) 청구 및 지급\\n□ 취급은행 : 농협은행, 우리은행, 국민은행, 신한은행, IBK기업은행",\n  "지원규모": "-",\n  "사업운영기간": "2024.01.01.~2024.12.31.",\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-01-01~2024-04-30,2024-07-01~2024-10-31\\n지원대상 접수기간\\n상반기(1차) : 2024. 1. 1. ~ 4. 30.\\n하반기(2차) : 2024. 7. 1. ~ 10. 31.",\n  "연령": "제한없음",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "-",\n  "추가 단서사항": "□ 지원대상 : 『주택도시기금 신혼부부 전용 전세자금대출』신규 대출자 및 대출 연장자(\'21.1월 이후)\\n❍ 대출(신청)자의 주민등록 및 임차(전세)주택 주소지가 광주지역에 소재\\n❍ 3개월이내 혼인 예정이거나 혼인신고일 기준 7년차 이내 무주택 신혼부부",\n  "참여 제한 대상": "-",\n  "신청절차": "광주아이키움 홈페이지 회원가입 후 신청\\n1. 신청서류 구비 > 2. 개인정보 수집 이용 동의 > 3. 신청 서류 제출(첨부파일) > 4. 접수확인",\n  "제출서류": "□ 신청시 구비서류\\n❍ 대출사실확인서\\n❍ 개인정보제공이용동의서\\n❍ 이자지원신청서\\n\\n□ 청구시 구비서류\\n❍ 이자납입내역서\\n❍ 주민등록등본\\n❍ 통장사본(지원금을 수령할 은행의 통장사본)\\n❍ 가족관계증명서(등본상 자녀수 미확인시 별도제출)",\n  "심사발표": "□ 상반기(1차)\\n지원대상 접수기간 : 2024. 1. 1. ~ 4. 30.\\n대출이자 청구기간 : 2024. 5. 1. ~ 5. 15.\\n대출이자 지원기간 : 2023. 11월 ~ 2024. 4월(6개월)\\n지급일 : 2024. 6월중\\n\\n□ 하반기(2차)\\n지원대상 접수기간 : 2024. 4. 1. ~ 10. 31.\\n대출이자 청구기간 : 2024. 11. 1. ~ 11. 15.\\n대출이자 지원기간 : 2024. 5월 ~ 2024. 10월(6개월)\\n지급일 : 2024. 12월중",\n  "신청 사이트": "https://www.광주아이키움.kr/main/hRentSubsidy",\n  "참고 사이트1": "https://www.광주아이키움.kr",\n  "참고 사이트2": "-",\n  "주관부처": "광주광역시 여성가족국 여성가족과",\n  "주관부처 담당자": "이초롱 주무관",\n  "주관부처 담당자 연 ...
#
# ---
#
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# Last User Question: 전라남도 신혼부부를 위한 정책 추천해줘
# Raw result from grader: binary_score='yes'
# ---GRADE: DOCUMENT RELEVANT---
# Raw result from grader: binary_score='no'
# ---GRADE: DOCUMENT NOT RELEVANT---
# Raw result from grader: binary_score='no'
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# Last User Question: 전라남도 신혼부부를 위한 정책 추천해줘
# ---DECISION: GENERATE---
#
# Node 'grade_documents':
# dict_items([('question', 'user: 전라남도 신혼부부를 위한 정책 추천해줘 '), ('documents', [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.')])])
#
# --- RETRIEVED DOCUMENTS ---
# [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.')]
#
# ---
#
# ---TRANSFORM QUERY---
#
# Node 'transform_query2':
# dict_items([('documents', [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.')]), ('question', '질문: 전라남도에서 신혼부부를 위한 정책은 어떤 것이 있나요?')])
#
# --- RETRIEVED DOCUMENTS ---
# [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.')]
#
# ---
#
# ---GENERATE---
# ---GRADE GENERATION vs QUESTION---
# Raw response: {
#     "binary_score": "yes",
#     "confidence": 0.95
# }
# ---FIRST GENERATE ATTEMPT: USEFUL
#
# Node 'generate_second':
# dict_items([('question', '질문: 전라남도에서 신혼부부를 위한 정책은 어떤 것이 있나요?'), ('documents', [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.')]), ('generation', '세은님에게 맞는 정책을 찾아보았어요😊\n\n① 정책명: 청년부부 결혼축하금 지원  \n② 추천 이유: 전라남도에 거주하는 신혼부부에게 경제적 부담을 덜어주고 안정적인 지역 정착을 지원하기 위해 마련된 정책이에요. 혼인신고일 기준으로 49세 이하의 부부가 대상이므로, 젊은 신혼부부에게 적합해요.  \n③ 제공 혜택: 이 정책을 통해 부부당 200만원의 결혼축하금을 지원받을 수 있어요. 이를 통해 결혼 초기의 경제적 부담을 완화하고, 지역 내에서의 안정적인 정착을 도울 수 있는 이점이 있어요.\n\n또 다른 정책으로는 전라남도의 다양한 주거 지원 정책이 있을 수 있는데, 구체적인 내용은 추가로 확인해보셔야 할 것 같아요. \n\n정책에 대해 더 구체적으로 알고 싶으신가요?')])
#
# --- RETRIEVED DOCUMENTS ---
# [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.')]
#
# --- LLM GENERATION ---
# 세은님에게 맞는 정책을 찾아보았어요😊
#
# ① 정책명: 청년부부 결혼축하금 지원
# ② 추천 이유: 전라남도에 거주하는 신혼부부에게 경제적 부담을 덜어주고 안정적인 지역 정착을 지원하기 위해 마련된 정책이에요. 혼인신고일 기준으로 49세 이하의 부부가 대상이므로, 젊은 신혼부부에게 적합해요.
# ③ 제공 혜택: 이 정책을 통해 부부당 200만원의 결혼축하금을 지원받을 수 있어요. 이를 통해 결혼 초기의 경제적 부담을 완화하고, 지역 내에서의 안정적인 정착을 도울 수 있는 이점이 있어요.
#
# 또 다른 정책으로는 전라남도의 다양한 주거 지원 정책이 있을 수 있는데, 구체적인 내용은 추가로 확인해보셔야 할 것 같아요.
#
# 정책에 대해 더 구체적으로 알고 싶으신가요?
#
# ---
#
# Enter your question (or 'exit' to quit): 청년문화예술패스 정책에 대해 알려줘
# Documents found, marking for 'generate_first'.
#
# Node 'check_documents':
# dict_items([('question', '질문: 전라남도에서 신혼부부를 위한 정책은 어떤 것이 있나요?\nuser: 청년문화예술패스 정책에 대해 알려줘'), ('documents', [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.')])])
#
# --- RETRIEVED DOCUMENTS ---
# [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.')]
#
# ---
#
# ---GENERATE---
# ---GRADE GENERATION vs QUESTION---
# Raw response: {
#     "binary_score": "no",
#     "confidence": 0.0
# }
# ---FIRST GENERATE ATTEMPT: NOT USEFUL
#
# Node 'generate_first':
# dict_items([('question', '질문: 전라남도에서 신혼부부를 위한 정책은 어떤 것이 있나요?\nuser: 청년문화예술패스 정책에 대해 알려줘'), ('documents', [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.')]), ('generation', '청년문화예술패스 정책에 대해 궁금하셨군요. 제가 구체적으로 알려드릴게요😄\n\n청년문화예술패스는 전라남도에서 청년들이 문화예술 활동에 참여할 수 있도록 지원하는 정책이에요. 이 정책은 청년들이 다양한 문화예술 프로그램에 접근할 수 있도록 하여, 문화적 경험을 쌓고 창의성을 발휘할 수 있는 기회를 제공하는 것을 목표로 하고 있어요. 구체적인 지원 내용이나 신청 방법에 대한 정보는 해당 정책의 공식 웹사이트나 관련 기관에 문의하시면 더 자세히 알 수 있을 거예요.\n\n궁금증이 해결되었나요?')])
#
# --- RETRIEVED DOCUMENTS ---
# [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.')]
#
# --- LLM GENERATION ---
# 청년문화예술패스 정책에 대해 궁금하셨군요. 제가 구체적으로 알려드릴게요😄
#
# 청년문화예술패스는 전라남도에서 청년들이 문화예술 활동에 참여할 수 있도록 지원하는 정책이에요. 이 정책은 청년들이 다양한 문화예술 프로그램에 접근할 수 있도록 하여, 문화적 경험을 쌓고 창의성을 발휘할 수 있는 기회를 제공하는 것을 목표로 하고 있어요. 구체적인 지원 내용이나 신청 방법에 대한 정보는 해당 정책의 공식 웹사이트나 관련 기관에 문의하시면 더 자세히 알 수 있을 거예요.
#
# 궁금증이 해결되었나요?
#
# ---
#
# ---RETRIEVE---
# Retrieved documents: [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.'), Document(metadata={'id': 'R2024061223868', '정책 ID': 'R2024061223868', '정책명': '울산 울주군 신혼부부 주택 매입·전세자금 대출이자 지원사업'}, page_content='{\n  "기관 코드": 3002007005.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "신혼부부의 주택 마련 부담을 완화하여 울주군의 인구 유입을 촉진하고 결혼·출산을 장려하는 사회적 분위기를 조성",\n  "지원내용": "□ 지원내용\\n- 신혼부부의 주택 매입‧전세자금 대출이자 최대 2% 지원\\n- 대출금 최대 2억 한도, 이자 최대 400만원/년 ※ 매입·전세 최대 4년 지원",\n  "지원규모": "-",\n  "사업운영기간": "-",\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-01-01~2024-12-31\\n연중 신청",\n  "연령": "제한없음",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 지원대상(아래의 조건을 모두 충족)\\n- 혼인신고일로부터 2년 이내인 신혼부부 또는 6개월 이내 혼인신고 예정인 예비부부\\n- 울주군에 주거지 마련하여 입주 예정인 가구\\n※ 전세 : 5억 이하, 계약서 상 주거면적 85㎡ 이하 /매입 : 5억 이하, 계약서 상 주거면적 85㎡ 이하\\n※ 위 내용은 변경될 수 있으니 신청 전 반드시 민원인이 은행에 확인 필요\\n- 신청일 기준 부부 모두 무주택자이면서 부부합산 연 소득 1억원 이하 가구",\n  "추가 단서사항": "-",\n  "참여 제한 대상": "□ 지원 제외 대상\\n- 기초 생계급여, 주거급여 대상자\\n- 공공임대주택(국민임대주택, 영구임대주택, 행복주택 등) 거주자\\n- 그 밖에 군수가 정하는 기준에 해당되지 않는 경우\\nex) 신혼부부 주거비용 지원사업과 중복지원 불가(택1)",\n  "신청절차": "온라인신청",\n  "제출서류": "□ 구비서류(부부 각1부) : 주민등록등본, 혼인관계증명서(상세), 건강보험자격득실확인서, 근로소득 원천징수영수증 또는 소득금액증명원, 지방세 세목별(재산세)과세증명서, 추가 확인서류 등",\n  "심사발표": "-",\n  "신청 사이트": "https://www.ulju.ulsan.kr/newlyweds/contents.do?mId=0201010000",\n  "참고 사이트1": "https://www.ulju.ulsan.kr/newlyweds/contents.do?mId=0101000000",\n  "참고 사이트2": NaN,\n  "주관부처": "울산광역시 울주군 여성가족과 여성가족팀 (052-204-1015)",\n  "주관부처 담당자": "-",\n  "주관부처 담당자 연락처": "-",\n  "운영기관": "주관기관과 동일",\n  "운영기관 담당자": "-",\n  "운영기관 담당자 연락처": "-",\n  "기타사항": "□ 기타 유의사항\\n○ 혼인 관계 변동 대상자\\n가. 배우자 사별\\n- 재혼안한 경우 : 최초 받았던 시점부터 최대 4년 지원\\n- 재혼한 경우 : 旣 지원 기간 제외하고 잔여기간 지원\\n나. 재혼 부부\\n- 신규 신청 : 기존 절차대로 진행하여 최대 4년간 지원\\n- 이혼 후 재결합 : 이혼한 다음 달부터 지원 중지, 재결합 한 달부터 잔여기간 지원\\n다. 이혼(사별) 후 재혼\\n- 부부 둘 다 지원 이력 없는 경우 : 신규대상자로 진행\\n- 부부 둘 중 한 명이라도 지원 이력 있는 경우  ...
#
# Node 'retrieve':
# dict_items([('question', '질문: 전라남도에서 신혼부부를 위한 정책은 어떤 것이 있나요?\nuser: 청년문화예술패스 정책에 대해 알려줘'), ('generation', '청년문화예술패스 정책에 대해 궁금하셨군요. 제가 구체적으로 알려드릴게요😄\n\n청년문화예술패스는 전라남도에서 청년들이 문화예술 활동에 참여할 수 있도록 지원하는 정책이에요. 이 정책은 청년들이 다양한 문화예술 프로그램에 접근할 수 있도록 하여, 문화적 경험을 쌓고 창의성을 발휘할 수 있는 기회를 제공하는 것을 목표로 하고 있어요. 구체적인 지원 내용이나 신청 방법에 대한 정보는 해당 정책의 공식 웹사이트나 관련 기관에 문의하시면 더 자세히 알 수 있을 거예요.\n\n궁금증이 해결되었나요?'), ('documents', [Document(metadata={'id': 'R2024052023015', '정책 ID': 'R2024052023015', '정책명': '전남청년부부 결혼축하금 지원'}, page_content='{\n  "기관 코드": 3002013.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "전라남도 거주 청년부부의 결혼 초기 경제적 부담 완화와 안정적인 지역정착을 위해 결혼축하금 지원",\n  "지원내용": "□ 지원액 : 부부당 200만원",\n  "지원규모": "5,000부부",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2001,\n  "사업신청기간": "\\n혼인신고일 기준 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청",\n  "연령": "만 0세 ~ 49세",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 다음 조건을 모두 충족하는 청년부부\\n❍ (연령) 혼인신고일 기준, 남녀 모두 49세 이하\\n❍ (혼인) 2022. 7. 4. 이후 혼인신고 한 부부\\n   - 부부 모두 “청년부부 결혼축하금” 수령 이력이 없어야 함(생애 1회)\\n❍ (거주) ①·② 요건을 모두 충족하는 청년부부\\n① 결혼축하금 신청일 직전까지 부부 모두 계속해서 도내에 6개월 이상 주소를 두고 거주\\n② 신청일부터 지급일까지 부부 모두 도내에 주소를 두고 거주하고, 1명(신청자)은 해당 시군(결혼축하금을 신청한 시군)에 주소를 두고 거주 (신청자가 아닌 1명은 도내 주소 이전 가능, 신청일~지급일까지 단 하루라도 타 시도 전출 시 지급 제외)",\n  "추가 단서사항": "□ 시·군별 지원 인원 상이\\n- 목포시 : 547부부\\n- 여수시 : 870부부\\n- 순천시 : 913부부\\n- 나주시 : 367부부\\n- 광양시 : 637부부\\n- 담양군 : 91부부\\n- 곡성군 : 47부부\\n- 구례군 : 57부부\\n- 고흥군 : 90부부\\n- 보성군 : 76부부\\n- 화순군 : 110부부\\n- 장흥군 : 72부부\\n- 강진군 : 86부부\\n- 해남군 : 131부부\\n- 영암군 : 128부부\\n- 무안군 : 348부부\\n- 함평군 : 71부부\\n- 영광군 : 51부부\\n- 장성군 : 74부부\\n- 완도군 : 100부부\\n- 진도군 : 65부부\\n- 신안군 : 69부부\\n ☞ 시･군별 지원 인원은 상황에 따라 조정될 수 있음",\n  "참여 제한 대상": NaN,\n  "신청절차": "□ 신청시기 : 혼인신고일 기준, 6개월이 경과되는 날부터 신청가능하며 혼인신고일 기준 1년 6개월 이내 신청\\n  ❍(예시) 혼인신고일 2022. 7. 4. ⇒ 신청시기 2023. 1. 3. ~ 2024. 1. 2. \\n\\n□ 신청방법\\n  ❍ 사업기간 : 2024. 1. ~ 12.\\n  ❍ 신 청 자 : 부부 중 1명\\n  ❍ 신청방법 : 평일(월~금) 09:00~18:00에 방문 신청 ※ 공휴일 제외\\n  ❍ 접 수 처 : 주민등록상 주소지 관할 읍·면·동 주민센터",\n  "제출서류": "❍ 청년부부 결혼축하금 신청서 1부\\n❍ 개인정보 수집·제공·이용 동의서 1부\\n❍ 주민등록초본(주소변경 이력 포함) 부부 각 1부\\n    * 주민등록번호는 전체가 나와야 하며, 개명한 경우 개명체크란에 필히 체크해야 함\\n❍ 혼인관계증명서 부부 각 1부\\n❍ 통장 사본 1부\\n❍ 외국인 배우자와 혼인한 경우, 외국인등록증 사본 및 주민등록등본 각 1부 추가 제출\\n   - 부부 중 1명이 외국인인 경우에도 신청자격 및 신청시기 동일하게 적용\\n   - 외국인이 초혼인지 확인해야 할 경우, ‘혼인상황확인서’ 등 과거 혼인여부 사실 가능한 서류 제출\\n    * 부부 모두 외국인인 경우는 지원대상자에 해당되지 않음",\n  "심사발표": "□ 지급시기 : 청년부부 결혼축하금 신청한 달의 다음 달 10일\\n  ❍ (예시) 1월 신청 ⇒ 2월 10일 지급 / 2월 신청 ⇒ 3월 10일 지급 등\\n   - 단, 지급일이 공휴일인 경우, 공휴일이 끝난 다음 날 지급\\n    * (예시) 6. 10. 일요일 ⇒ 6. 11. 월요일에 결혼축하금 지급",\n  "신청 사이트": NaN,\n  "참고 사이트1": "https://brand.'), Document(metadata={'id': 'R2024061223868', '정책 ID': 'R2024061223868', '정책명': '울산 울주군 신혼부부 주택 매입·전세자금 대출이자 지원사업'}, page_content='{\n  "기관 코드": 3002007005.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책소개": "신혼부부의 주택 마련 부담을 완화하여 울주군의 인구 유입을 촉진하고 결혼·출산을 장려하는 사회적 분위기를 조성",\n  "지원내용": "□ 지원내용\\n- 신혼부부의 주택 매입‧전세자금 대출이자 최대 2% 지원\\n- 대출금 최대 2억 한도, 이자 최대 400만원/년 ※ 매입·전세 최대 4년 지원",\n  "지원규모": "-",\n  "사업운영기간": "-",\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-01-01~2024-12-31\\n연중 신청",\n  "연령": "제한없음",\n  "전공요건": "-",\n  "취업상태": "-",\n  "특화분야": "-",\n  "학력요건": "-",\n  "거주지 및 소득 조건": "□ 지원대상(아래의 조건을 모두 충족)\\n- 혼인신고일로부터 2년 이내인 신혼부부 또는 6개월 이내 혼인신고 예정인 예비부부\\n- 울주군에 주거지 마련하여 입주 예정인 가구\\n※ 전세 : 5억 이하, 계약서 상 주거면적 85㎡ 이하 /매입 : 5억 이하, 계약서 상 주거면적 85㎡ 이하\\n※ 위 내용은 변경될 수 있으니 신청 전 반드시 민원인이 은행에 확인 필요\\n- 신청일 기준 부부 모두 무주택자이면서 부부합산 연 소득 1억원 이하 가구",\n  "추가 단서사항": "-",\n  "참여 제한 대상": "□ 지원 제외 대상\\n- 기초 생계급여, 주거급여 대상자\\n- 공공임대주택(국민임대주택, 영구임대주택, 행복주택 등) 거주자\\n- 그 밖에 군수가 정하는 기준에 해당되지 않는 경우\\nex) 신혼부부 주거비용 지원사업과 중복지원 불가(택1)",\n  "신청절차": "온라인신청",\n  "제출서류": "□ 구비서류(부부 각1부) : 주민등록등본, 혼인관계증명서(상세), 건강보험자격득실확인서, 근로소득 원천징수영수증 또는 소득금액증명원, 지방세 세목별(재산세)과세증명서, 추가 확인서류 등",\n  "심사발표": "-",\n  "신청 사이트": "https://www.ulju.ulsan.kr/newlyweds/contents.do?mId=0201010000",\n  "참고 사이트1": "https://www.ulju.ulsan.kr/newlyweds/contents.do?mId=0101000000",\n  "참고 사이트2": NaN,\n  "주관부처": "울산광역시 울주군 여성가족과 여성가족팀 (052-204-1015)",\n  "주관부처 담당자": "-",\n  "주관부처 담당 ...
#
# --- RETRIEVED DOCUMENTS ---
# ...
#
# --- RETRIEVED DOCUMENTS ---
# [Document(metadata={'id': 'R2024032521041', '정책 ID': 'R2024032521041', '정책명': '서울청년문화패스'}, page_content='{\n  "정책 ID": "R2024032521041",\n  "기관 코드": 3002001.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책명": "서울청년문화패스",\n  "정책소개": "사회에 첫 발을 내딛는 20세~23세 청년들에게 연극, 뮤지컬, 클래식·오페라, 발레·무용, 국악, 전시 관람 기회를 제공하고 문화예술분야 활성화를 위해 문화이용권을 지원하는 사업",\n  "지원내용": "공연과 전시 관람에 사용할 수 있는 1인당 연간 20만원 상당의 문화이용권(카드) 지급\\n- 카드 발급일로부터 2024.12.31.까지\\n * 예매 이용률과 예산 한도를 고려하여 조기마감 될 수 있음",\n  "지원규모": "30,000명\\n20~23세 서울특별시 거주 청년",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-03-28~2024-04-17\\n2024. 3. 28.(목) ~ 4. 17.(수)",\n  "연령": "만 20세 ~ 23세",\n  "전공요건": "제한없음",\n  "취업상태": "제한없음",\n  "특화분야": "제한없음",\n  "학력요건": "제한없음",\n  "거주지 및 소득 조건": "□ 나  이 : 20~23세\\n ㅇ 2001. 1. 1. ~ 2004. 12. 31. 출생자\\n□ 거주지 : 신청일 기준 서울특별시 거주\\n ㅇ 주민등록 및 외국인등록대장 기준\\n□ 소  득 : 2024년 2월 건강보험료 기준\\n ㅇ 생애 최초 수혜자 : 본인부담금 기준 중위소득 150% 이하\\n ㅇ 2023년 수혜자   : 본인부담금 기준 중위소득 120% 이하\\n ※ 신청시 제공한 주민등록번호(외국인등록번호)와 ‘개인정보 수집·이용 및 제3자 제공 동의’에 따라 모집 마감 후 국민건강보험공단에 일괄 조회\\n ※ 신청자가 지역 세대원 또는 직장 피부양자인 경우 부양자 부과액 기준\\n ※ 가구원수는 건강보험에 함께 등재된 사람을 기준으로 산정",\n  "추가 단서사항": "□ 신청하는 곳 : 청년몽땅정보통(youth.seoul.go.kr)에서 온라인 신청\\n ㅇ 청년몽땅정보통 → 교육문화 → 서울청년문화패스 → 신청하기\\n ※ 장애인 등 온라인 신청이 어려운 취약계층은 콜센터를 통해 신청 가능 (☎ 1533-3427)\\n ※ 방문 신청이나 우편 신청 불가\\n ※ 콜센터는 평일 업무시간(9~12시 / 13~18시)에 이용 가능",\n  "참여 제한 대상": NaN,\n  "신청절차": "신청(온라인) → 자격확인·선정 → 카드발급(비대면) → 사용(결제)",\n  "제출서류": "ㅇ 온라인 신청 및 개인정보 제공 동의를 통한 비대면 자격확인으로 별도 제출서류 없음\\n ㅇ 단, 외국국적동포의 경우 국내거소신고 사실증명서 첨부\\n    ※ 원본 서류를 스캔 또는 다운로드 받아 업로드(화면 캡처, 사진 불인정)",\n  "심사발표": "□ 발 표 일 : 2024. 5. 8.(수) 예정\\n   ※ 발표일은 변동될 수 있으며, 자세한 내용은 청년몽땅정보통 공지사항 게시판 확인\\n□ 발표방법 : 개별 문자 발송 및 청년몽땅정보통 ‘마이페이지’ 확인",\n  "신청 사이트": "youth.seoul.go.kr",\n  "참고 사이트1": "https://www.youthcultureseoul.kr/eventExhibition/2079",\n  "참고 사이트2": "https://youth.seoul.go.kr/youthConts.do?key=2310200023&sc_pbancSeCd=005&sc_bbsStngSn=2212200001&sc_bbsCtgrySn=2310200005&sc_qnaCtgryCd=&sc_faqCtgryCd=002",\n  "주관부처": "서울특별히 문화본부 문화정책과 시민문화팀",\n  "주관부처 담당자": "전민 주무관\\n이승연 주무관",\n  "주관부처 담당자 연락처": "02-2133-2544",\n  "운영기관": "-",\n  "운영기관 담당자": NaN,\n  "운영기관 담당자 연락처": NaN,\n  "기타사항": "ㅇ 관람분야 : 공연(연극·뮤지컬·클래식·오페라·무용·국악), 전시\\n ㅇ 관람방법 : 서울청년문화패스 홈페이지에서 예매 후 관람\\n ㅇ 예매기준 : 예매 건당 7만원 이내 사용(추가금액 자부담)\\n ※ 뮤지컬은 지원기간 중 1회만 예매 가능\\n\\nㅇ 서울청년문화패스 지원 신청 및 사용과 관련한 자세한 사항은 청년몽땅정보통 홈페이지에서 확인해 주시기 바랍니다.\\n    ※ 콜센터 : ☎ 1533-3427 [평일 업무시간(9~12시/13~18시) 이용가능]\\n    ※ 청년몽땅정보통 홈페이지 : https://youth.seoul.go.kr",\n  "정책분야 코드": 23040\n}'), Document(metadata={'id': 'R2024030620343', '정책 ID': 'R2024030620343', '정책명': '청년문화예술패스'}, page_content='{\n  "기관 코드": 3001012.0,\n  "기관 및 지자체 구분": "중앙부처",\n  "정책소개": "청년들의 문화소비를 확대할 수 있도록 지원하기위한 사업",\n  "지원내용": "□ 최대 15만원 지원(국비 10만원 + 지방비 5만원 매칭 지원)",\n  "지원규모": "□ 전국 16만명",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-03-28~2024-11-30\\n□ 신청기간 : 2024. 3. 28.(목) 10:00 ~ 2024. 11. 30(토)\\n※ 예산 소진 시 종료\\n□ 사용기간 : 발급일 ~ 12.31\\n※ 국내 거주하는 2005년생 참여 가능",\n  "연령": "만 19세 ~ 19세",\n  "전공요건": "제한없음",\n  "취업상태": "제한없음",\n  "특화분야": "제한없음",\n  "학력요건": "제한없음",\n  "거주지 및 소득 조건": "□ 국내 거주하는 2005년생 누구나",\n  "추가 단서사항": "□ 이용범위 : 연극, 뮤지컬, 클래식/오페라, 발레/무용, 국악/전시 관람에 활용\\n□ 초과분은 본인부담금액으로 결제",\n  "참여 제한 대상": "-",\n  "신청절차": "□ 인터파크/예스24 누리집 또는 모바일 앱 접속\\n□ 로그인 및 신청자 나이, 거주지역 확인\\n□ 문화예술패스 포인트 지급\\n - 10만원 즉시 지급,.5만원 상반기 중 지급\\n□ 지급된 포인트로 공연/전시 예매",\n  "제출서류": "-",\n  "심사발표": "-",\n  "신청 사이트": "-",\n  "참고 사이트1": "https://litt.ly/24culturepass",\n  "참고 사이트2": "https://www.arko.or.kr/board/view/4053?bid=&page=&cid=1807855",\n  "주관부처": "□ 문화체육관광부",\n  "주관부처 담당자": NaN,\n  "주관부처 담당자 연락처": NaN,\n  "운영기관": "□ 한국문화예술위원회",\n  "운영기관 담당자": NaN,\n  "운영기관 담당자 연락처": NaN,\n  "기타사항": "□ 예매처 : 인터파크, 예스24\\n□ 문의전화 : 청년문화예술패스 고객센터 1577-1968\\n※ 최초 발급한 예매처 한곳에서만 사용이 가능하며, 발급 후 예매처 변경은 불가합니다.\\n※ 사업기간 종료일(2024년 12월 31일)까지 사용하지 않고 남은 잔액은 국고로 자동 반납됩니다. 반드시 사용기간 내에 이용해 주시기 바랍니다.",\n  "정책분야 코드": 23040\n}'), Document(metadata={'id': 'R2024062024203', '정책 ID': 'R2024062024203', '정책명': '부산청년만원문화패스'}, page_content='{\n  "기관 코드": 3002002.0 ...
#
# --- LLM GENERATION ---
# 서울청년문화패스의 신청기간은 2024년 3월 28일(목)부터 4월 17일(수)까지입니다. 제가 구체적으로 알려드릴게요😄
#
# 궁금증이 해결되었나요?
#
# ---
#
# ---TRANSFORM QUERY---
#
# Node 'transform_query1':
# dict_items([('documents', [Document(metadata={'id': 'R2024032521041', '정책 ID': 'R2024032521041', '정책명': '서울청년문화패스'}, page_content='{\n  "정책 ID": "R2024032521041",\n  "기관 코드": 3002001.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책명": "서울청년문화패스",\n  "정책소개": "사회에 첫 발을 내딛는 20세~23세 청년들에게 연극, 뮤지컬, 클래식·오페라, 발레·무용, 국악, 전시 관람 기회를 제공하고 문화예술분야 활성화를 위해 문화이용권을 지원하는 사업",\n  "지원내용": "공연과 전시 관람에 사용할 수 있는 1인당 연간 20만원 상당의 문화이용권(카드) 지급\\n- 카드 발급일로부터 2024.12.31.까지\\n * 예매 이용률과 예산 한도를 고려하여 조기마감 될 수 있음",\n  "지원규모": "30,000명\\n20~23세 서울특별시 거주 청년",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-03-28~2024-04-17\\n2024. 3. 28.(목) ~ 4. 17.(수)",\n  "연령": "만 20세 ~ 23세",\n  "전공요건": "제한없음",\n  "취업상태": "제한없음",\n  "특화분야": "제한없음",\n  "학력요건": "제한없음",\n  "거주지 및 소득 조건": "□ 나  이 : 20~23세\\n ㅇ 2001. 1. 1. ~ 2004. 12. 31. 출생자\\n□ 거주지 : 신청일 기준 서울특별시 거주\\n ㅇ 주민등록 및 외국인등록대장 기준\\n□ 소  득 : 2024년 2월 건강보험료 기준\\n ㅇ 생애 최초 수혜자 : 본인부담금 기준 중위소득 150% 이하\\n ㅇ 2023년 수혜자   : 본인부담금 기준 중위소득 120% 이하\\n ※ 신청시 제공한 주민등록번호(외국인등록번호)와 ‘개인정보 수집·이용 및 제3자 제공 동의’에 따라 모집 마감 후 국민건강보험공단에 일괄 조회\\n ※ 신청자가 지역 세대원 또는 직장 피부양자인 경우 부양자 부과액 기준\\n ※ 가구원수는 건강보험에 함께 등재된 사람을 기준으로 산정",\n  "추가 단서사항": "□ 신청하는 곳 : 청년몽땅정보통(youth.seoul.go.kr)에서 온라인 신청\\n ㅇ 청년몽땅정보통 → 교육문화 → 서울청년문화패스 → 신청하기\\n ※ 장애인 등 온라인 신청이 어려운 취약계층은 콜센터를 통해 신청 가능 (☎ 1533-3427)\\n ※ 방문 신청이나 우편 신청 불가\\n ※ 콜센터는 평일 업무시간(9~12시 / 13~18시)에 이용 가능",\n  "참여 제한 대상": NaN,\n  "신청절차": "신청(온라인) → 자격확인·선정 → 카드발급(비대면) → 사용(결제)",\n  "제출서류": "ㅇ 온라인 신청 및 개인정보 제공 동의를 통한 비대면 자격확인으로 별도 제출서류 없음\\n ㅇ 단, 외국국적동포의 경우 국내거소신고 사실증명서 첨부\\n    ※ 원본 서류를 스캔 또는 다운로드 받아 업로드(화면 캡처, 사진 불인정)",\n  "심사발표": "□ 발 표 일 : 2024. 5. 8.(수) 예정\\n   ※ 발표일은 변동될 수 있으며, 자세한 내용은 청년몽땅정보통 공지사항 게시판 확인\\n□ 발표방법 : 개별 문자 발송 및 청년몽땅정보통 ‘마이페이지’ 확인",\n  "신청 사이트": "youth.seoul.go.kr",\n  "참고 사이트1": "https://www.youthcultureseoul.kr/eventExhibition/2079",\n  "참고 사이트2": "https://youth.seoul.go.kr/youthConts.do?key=2310200023&sc_pbancSeCd=005&sc_bbsStngSn=2212200001&sc_bbsCtgrySn=2310200005&sc_qnaCtgryCd=&sc_faqCtgryCd=002",\n  "주관부처": "서울특별히 문화본부 문화정책과 시민문화팀",\n  "주관부처 담당자": "전민 주무관\\n이승연 주무관",\n  "주관부처 담당자 연락처": "02-2133-2544",\n  "운영기관": "-",\n  "운영기관 담당자": NaN,\n  "운영기관 담당자 연락처": NaN,\n  "기타사항": "ㅇ 관람분야 : 공연(연극·뮤지컬·클래식·오페라·무용·국악), 전시\\n ㅇ 관람방법 : 서울청년문화패스 홈페이지에서 예매 후 관람\\n ㅇ 예매기준 : 예매 건당 7만원 이내 사용(추가금액 자부담)\\n ※ 뮤지컬은 지원기간 중 1회만 예매 가능\\n\\nㅇ 서울청년문화패스 지원 신청 및 사용과 관련한 자세한 사항은 청년몽땅정보통 홈페이지에서 확인해 주시기 바랍니다.\\n    ※ 콜센터 : ☎ 1533-3427 [평일 업무시간(9~12시/13~18시) 이용가능]\\n    ※ 청년몽땅정보통 홈페이지 : https://youth.seoul.go.kr",\n  "정책분야 코드": 23040\n}'), Document(metadata={'id': 'R2024030620343', '정책 ID': 'R2024030620343', '정책명': '청년문화예술패스'}, page_content='{\n  "기관 코드": 3001012.0,\n  "기관 및 지자체 구분": "중앙부처",\n  "정책소개": "청년들의 문화소비를 확대할 수 있도록 지원하기위한 사업",\n  "지원내용": "□ 최대 15만원 지원(국비 10만원 + 지방비 5만원 매칭 지원)",\n  "지원규모": "□ 전국 16만명",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-03-28~2024-11-30\\n□ 신청기간 : 2024. 3. 28.(목) 10:00 ~ 2024. 11. 30(토)\\n※ 예산 소진 시 종료\\n□ 사용기간 : 발급일 ~ 12.31\\n※ 국내 거주하는 2005년생 참여 가능",\n  "연령": "만 19세 ~ 19세",\n  "전공요건": "제한없음",\n  "취업상태": "제한없음",\n  "특화분야": "제한없음",\n  "학력요건": "제한없음",\n  "거주지 및 소득 조건": "□ 국내 거주하는 2005년생 누구나",\n  "추가 단서사항": "□ 이용범위 : 연극, 뮤지컬, 클래식/오페라, 발레/무용, 국악/전시 관람에 활용\\n□ 초과분은 본인부담금액으로 결제",\n  "참여 제한 대상": "-",\n  "신청절차": "□ 인터파크/예스24 누리집 또는 모바일 앱 접속\\n□ 로그인 및 신청자 나이, 거주지역 확인\\n□ 문화예술패스 포인트 지급\\n - 10만원 즉시 지급,.5만원 상반기 중 지급\\n□ 지급된 포인트로 공연/전시 예매",\n  "제출서류": "-",\n  "심사발표": "-",\n  "신청 사이트": "-",\n  "참고 사이트1": "https://litt.ly/24culturepass",\n  "참고 사이트2": "https://www.arko.or.kr/board/view/4053?bid=&page=&cid=1807855",\n  "주관부처": "□ 문화체육관광부",\n  "주관부처 담당자": NaN,\n  "주관부처 담당자 연락처": NaN,\n  "운영기관": "□ 한국문화예술위원회",\n  "운영기관 담당자": NaN,\n  "운영기관 담당자 연락처": NaN,\n  "기타사항": "□ 예매처 : 인터파크, 예스24\\n□ 문의전화 : 청년문화예술패스 고객센터 1577-1968\\n※ 최초 발급한 예매처 한곳에서만 사용이 가능하며, 발급 후 예매처 변경은 불가합니다.\\n※ 사업기간 종료일(2024년 12월 31일)까지 사용하지 않고 남은 잔액은 국고로 자동 반납됩니다. 반드시 사용기간 내에 이용해 주시기 바랍니다.",\n  "정책분야 코드": 23040\n}'), Document(metadata={'id': 'R2024062024203', '정책 ID': 'R2024062024203', '정책명': '부산청년만원문화패스'}, page_conten ...
#
# --- RETRIEVED DOCUMENTS ---
# [Document(metadata={'id': 'R2024032521041', '정책 ID': 'R2024032521041', '정책명': '서울청년문화패스'}, page_content='{\n  "정책 ID": "R2024032521041",\n  "기관 코드": 3002001.0,\n  "기관 및 지자체 구분": "지자체",\n  "정책명": "서울청년문화패스",\n  "정책소개": "사회에 첫 발을 내딛는 20세~23세 청년들에게 연극, 뮤지컬, 클래식·오페라, 발레·무용, 국악, 전시 관람 기회를 제공하고 문화예술분야 활성화를 위해 문화이용권을 지원하는 사업",\n  "지원내용": "공연과 전시 관람에 사용할 수 있는 1인당 연간 20만원 상당의 문화이용권(카드) 지급\\n- 카드 발급일로부터 2024.12.31.까지\\n * 예매 이용률과 예산 한도를 고려하여 조기마감 될 수 있음",\n  "지원규모": "30,000명\\n20~23세 서울특별시 거주 청년",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-03-28~2024-04-17\\n2024. 3. 28.(목) ~ 4. 17.(수)",\n  "연령": "만 20세 ~ 23세",\n  "전공요건": "제한없음",\n  "취업상태": "제한없음",\n  "특화분야": "제한없음",\n  "학력요건": "제한없음",\n  "거주지 및 소득 조건": "□ 나  이 : 20~23세\\n ㅇ 2001. 1. 1. ~ 2004. 12. 31. 출생자\\n□ 거주지 : 신청일 기준 서울특별시 거주\\n ㅇ 주민등록 및 외국인등록대장 기준\\n□ 소  득 : 2024년 2월 건강보험료 기준\\n ㅇ 생애 최초 수혜자 : 본인부담금 기준 중위소득 150% 이하\\n ㅇ 2023년 수혜자   : 본인부담금 기준 중위소득 120% 이하\\n ※ 신청시 제공한 주민등록번호(외국인등록번호)와 ‘개인정보 수집·이용 및 제3자 제공 동의’에 따라 모집 마감 후 국민건강보험공단에 일괄 조회\\n ※ 신청자가 지역 세대원 또는 직장 피부양자인 경우 부양자 부과액 기준\\n ※ 가구원수는 건강보험에 함께 등재된 사람을 기준으로 산정",\n  "추가 단서사항": "□ 신청하는 곳 : 청년몽땅정보통(youth.seoul.go.kr)에서 온라인 신청\\n ㅇ 청년몽땅정보통 → 교육문화 → 서울청년문화패스 → 신청하기\\n ※ 장애인 등 온라인 신청이 어려운 취약계층은 콜센터를 통해 신청 가능 (☎ 1533-3427)\\n ※ 방문 신청이나 우편 신청 불가\\n ※ 콜센터는 평일 업무시간(9~12시 / 13~18시)에 이용 가능",\n  "참여 제한 대상": NaN,\n  "신청절차": "신청(온라인) → 자격확인·선정 → 카드발급(비대면) → 사용(결제)",\n  "제출서류": "ㅇ 온라인 신청 및 개인정보 제공 동의를 통한 비대면 자격확인으로 별도 제출서류 없음\\n ㅇ 단, 외국국적동포의 경우 국내거소신고 사실증명서 첨부\\n    ※ 원본 서류를 스캔 또는 다운로드 받아 업로드(화면 캡처, 사진 불인정)",\n  "심사발표": "□ 발 표 일 : 2024. 5. 8.(수) 예정\\n   ※ 발표일은 변동될 수 있으며, 자세한 내용은 청년몽땅정보통 공지사항 게시판 확인\\n□ 발표방법 : 개별 문자 발송 및 청년몽땅정보통 ‘마이페이지’ 확인",\n  "신청 사이트": "youth.seoul.go.kr",\n  "참고 사이트1": "https://www.youthcultureseoul.kr/eventExhibition/2079",\n  "참고 사이트2": "https://youth.seoul.go.kr/youthConts.do?key=2310200023&sc_pbancSeCd=005&sc_bbsStngSn=2212200001&sc_bbsCtgrySn=2310200005&sc_qnaCtgryCd=&sc_faqCtgryCd=002",\n  "주관부처": "서울특별히 문화본부 문화정책과 시민문화팀",\n  "주관부처 담당자": "전민 주무관\\n이승연 주무관",\n  "주관부처 담당자 연락처": "02-2133-2544",\n  "운영기관": "-",\n  "운영기관 담당자": NaN,\n  "운영기관 담당자 연락처": NaN,\n  "기타사항": "ㅇ 관람분야 : 공연(연극·뮤지컬·클래식·오페라·무용·국악), 전시\\n ㅇ 관람방법 : 서울청년문화패스 홈페이지에서 예매 후 관람\\n ㅇ 예매기준 : 예매 건당 7만원 이내 사용(추가금액 자부담)\\n ※ 뮤지컬은 지원기간 중 1회만 예매 가능\\n\\nㅇ 서울청년문화패스 지원 신청 및 사용과 관련한 자세한 사항은 청년몽땅정보통 홈페이지에서 확인해 주시기 바랍니다.\\n    ※ 콜센터 : ☎ 1533-3427 [평일 업무시간(9~12시/13~18시) 이용가능]\\n    ※ 청년몽땅정보통 홈페이지 : https://youth.seoul.go.kr",\n  "정책분야 코드": 23040\n}'), Document(metadata={'id': 'R2024030620343', '정책 ID': 'R2024030620343', '정책명': '청년문화예술패스'}, page_content='{\n  "기관 코드": 3001012.0,\n  "기관 및 지자체 구분": "중앙부처",\n  "정책소개": "청년들의 문화소비를 확대할 수 있도록 지원하기위한 사업",\n  "지원내용": "□ 최대 15만원 지원(국비 10만원 + 지방비 5만원 매칭 지원)",\n  "지원규모": "□ 전국 16만명",\n  "사업운영기간": NaN,\n  "사업신청기간 반복구분 코드": 2004,\n  "사업신청기간": "2024-03-28~2024-11-30\\n□ 신청기간 : 2024. 3. 28.(목) 10:00 ~ 2024. 11. 30(토)\\n※ 예산 소진 시 종료\\n□ 사용기간 : 발급일 ~ 12.31\\n※ 국내 거주하는 2005년생 참여 가능",\n  "연령": "만 19세 ~ 19세",\n  "전공요건": "제한없음",\n  "취업상태": "제한없음",\n  "특화분야": "제한없음",\n  "학력요건": "제한없음",\n  "거주지 및 소득 조건": "□ 국내 거주하는 2005년생 누구나",\n  "추가 단서사항": "□ 이용범위 : 연극, 뮤지컬, 클래식/오페라, 발레/무용, 국악/전시 관람에 활용\\n□ 초과분은 본인부담금액으로 결제",\n  "참여 제한 대상": "-",\n  "신청절차": "□ 인터파크/예스24 누리집 또는 모바일 앱 접속\\n□ 로그인 및 신청자 나이, 거주지역 확인\\n□ 문화예술패스 포인트 지급\\n - 10만원 즉시 지급,.5만원 상반기 중 지급\\n□ 지급된 포인트로 공연/전시 예매",\n  "제출서류": "-",\n  "심사발표": "-",\n  "신청 사이트": "-",\n  "참고 사이트1": "https://litt.ly/24culturepass",\n  "참고 사이트2": "https://www.arko.or.kr/board/view/4053?bid=&page=&cid=1807855",\n  "주관부처": "□ 문화체육관광부",\n  "주관부처 담당자": NaN,\n  "주관부처 담당자 연락처": NaN,\n  "운영기관": "□ 한국문화예술위원회",\n  "운영기관 담당자": NaN,\n  "운영기관 담당자 연락처": NaN,\n  "기타사항": "□ 예매처 : 인터파크, 예스24\\n□ 문의전화 : 청년문화예술패스 고객센터 1577-1968\\n※ 최초 발급한 예매처 한곳에서만 사용이 가능하며, 발급 후 예매처 변경은 불가합니다.\\n※ 사업기간 종료일(2024년 12월 31일)까지 사용하지 않고 남은 잔액은 국고로 자동 반납됩니다. 반드시 사용기간 내에 이용해 주시기 바랍니다.",\n  "정책분야 코드": 23040\n}'), Document(metadata={'id': 'R2024062024203', '정책 ID': 'R2024062024203', '정책명': '부산청년만원문화패스'}, page_content='{\n  "기관 코드": 3002002.0 ...
#
# ---
#
# Enter your question (or 'exit' to quit): exit
