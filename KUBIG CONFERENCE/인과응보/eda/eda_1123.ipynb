# %%
import pandas as pd
# import matlib
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
com = pd.read_csv('preprocessed_data/jiwon_combined_data.csv', index_col=0)
com
# Out:
#          AGE2  IRSEX  IRMARIT  SERVICE  CG30EST  AL30EST  year
# 0          15      1        3        2       99       93  2020
# 1          15      1        4        2       99       99  2020
# 2          14      2        4        2       91       93  2020
# 3          15      1        1        2       91       99  2020
# 4           3      1       99       99       91       93  2020
# ...       ...    ...      ...      ...      ...      ...   ...
# 1152550    14      2        4        2       99       99  2011
# 1152551    16      2        1        2       93       93  2011
# 1152552    17      1        3        1       93       93  2011
# 1152553    13      1        1        2       91       91  2011
# 1152554    16      1        3        2       93       93  2011
#
# [1152555 rows x 7 columns]

# %%
import pandas as pd

df = com

# Group the data by 'year'
yearly_groups = df.groupby('year')

# Function to perform EDA for each year
def perform_yearly_eda(groups):
    eda_results = {}
    for year, group in groups:
        eda_results[year] = {
            "Row Count": len(group),
            "AGE2 Stats": group['AGE2'].describe(),
            "IRSEX Distribution": group['IRSEX'].value_counts(),
            "IRMARIT Distribution": group['IRMARIT'].value_counts(),
            "SERVICE Distribution": group['SERVICE'].value_counts(),
            "CG30EST Distribution": group['CG30EST'].value_counts(),
            "AL30EST Distribution": group['AL30EST'].value_counts(),
        }
    return eda_results

# Perform EDA
eda_results = perform_yearly_eda(yearly_groups)

# Print EDA results for each year
for year, stats in eda_results.items():
    print(f"\nYear: {year}")
    print(f"Row Count: {stats['Row Count']}")
    print(f"AGE2 Stats:\n{stats['AGE2 Stats']}")
    print(f"IRSEX Distribution:\n{stats['IRSEX Distribution']}")
    print(f"IRMARIT Distribution:\n{stats['IRMARIT Distribution']}")
    print(f"SERVICE Distribution:\n{stats['SERVICE Distribution']}")
    print(f"CG30EST Distribution:\n{stats['CG30EST Distribution']}")
    print(f"AL30EST Distribution:\n{stats['AL30EST Distribution']}")
# Out:
# Year: 2000
# Row Count: 58680
# AGE2 Stats:
# count    58680.000000
# mean         9.567468
# std          4.997815
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    30568
# 1    28112
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     27150
# 1     17188
# 99     9970
# 3      3188
# 2      1184
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     38920
# 99    16468
# 1      3287
# 97        3
# 94        2
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    24654
# 93    18926
# 99    14735
# 6        77
# 98       63
# 4        38
# 94       38
# 3        35
# 2        35
# 1        35
# 5        32
# 97       12
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    23749
# 91    16795
# 93    16790
# 98     1061
# 1        81
# 2        49
# 97       41
# 3        40
# 94       34
# 4        33
# 5         4
# 6         2
# 85        1
# Name: count, dtype: int64
#
# Year: 2001
# Row Count: 55561
# AGE2 Stats:
# count    55561.000000
# mean         9.765825
# std          4.975911
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         15.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28920
# 1    26641
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     25862
# 1     16586
# 99     8875
# 3      3147
# 2      1091
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     37857
# 99    14738
# 1      2963
# 97        3
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    22623
# 93    18131
# 99    14597
# 6        41
# 98       37
# 4        30
# 2        24
# 3        23
# 94       21
# 5        17
# 1        12
# 97        5
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    23719
# 93    15679
# 91    14906
# 98     1004
# 1        67
# 2        53
# 97       39
# 3        37
# 94       26
# 4        23
# 5         5
# 6         3
# Name: count, dtype: int64
#
# Year: 2002
# Row Count: 54079
# AGE2 Stats:
# count    54079.000000
# mean         9.524714
# std          4.976097
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28122
# 1    25957
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     25941
# 1     14603
# 99     9315
# 3      3294
# 2       926
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     36475
# 99    14935
# 1      2668
# 97        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    21315
# 93    17748
# 99    14845
# 98       37
# 6        35
# 4        28
# 1        16
# 3        15
# 5        12
# 94       12
# 2        10
# 97        6
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    24078
# 93    14895
# 91    14034
# 98      900
# 1        43
# 3        35
# 2        30
# 4        27
# 94       21
# 97       13
# 5         2
# 6         1
# Name: count, dtype: int64
#
# Year: 2003
# Row Count: 55230
# AGE2 Stats:
# count    55230.000000
# mean         9.497827
# std          4.934148
# min          1.000000
# 25%          5.000000
# 50%         10.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28464
# 1    26766
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     27231
# 1     14613
# 99     9118
# 3      3400
# 2       868
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     37492
# 99    15189
# 1      2548
# 97        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    22346
# 93    17534
# 99    15187
# 98       32
# 4        24
# 6        23
# 2        19
# 1        17
# 3        15
# 5        14
# 94       11
# 97        8
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    24400
# 93    15286
# 91    14428
# 98      940
# 1        48
# 2        39
# 3        29
# 94       19
# 4        19
# 97       12
# 5         4
# 85        3
# 6         3
# Name: count, dtype: int64
#
# Year: 2004
# Row Count: 55602
# AGE2 Stats:
# count    55602.000000
# mean         9.498993
# std          4.931582
# min          1.000000
# 25%          5.000000
# 50%         10.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28889
# 1    26713
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     27581
# 1     14471
# 99     9199
# 3      3455
# 2       896
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     37756
# 99    15325
# 1      2519
# 94        1
# 98        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    23365
# 93    17128
# 99    14956
# 6        38
# 4        28
# 98       23
# 2        18
# 5        15
# 3        13
# 1         9
# 94        6
# 97        3
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    24219
# 93    15384
# 91    14938
# 98      880
# 1        54
# 2        31
# 4        24
# 3        24
# 97       23
# 94       16
# 6         5
# 5         4
# Name: count, dtype: int64
#
# Year: 2005
# Row Count: 55905
# AGE2 Stats:
# count    55905.000000
# mean         9.473643
# std          4.933747
# min          1.000000
# 25%          5.000000
# 50%         10.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    29366
# 1    26539
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     28179
# 1     14178
# 99     9190
# 3      3451
# 2       907
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     37835
# 99    15631
# 1      2439
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    24232
# 93    16723
# 99    14776
# 6        39
# 98       31
# 4        22
# 2        17
# 1        16
# 3        15
# 5        14
# 94       13
# 97        7
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    24381
# 91    15247
# 93    15112
# 98      984
# 1        56
# 3        33
# 2        26
# 4        20
# 94       17
# 97       15
# 5         9
# 6         4
# 85        1
# Name: count, dtype: int64
#
# Year: 2006
# Row Count: 55035
# AGE2 Stats:
# count    55035.000000
# mean         9.558354
# std          4.962272
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28411
# 1    26624
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     27621
# 1     14279
# 99     8891
# 3      3218
# 2      1026
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     37294
# 99    15219
# 1      2519
# 97        2
# 98        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    24307
# 93    16357
# 99    14208
# 6        37
# 98       28
# 1        21
# 4        18
# 5        17
# 2        12
# 3        12
# 94       12
# 97        6
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    24117
# 91    15034
# 93    14745
# 98      944
# 1        62
# 2        39
# 3        24
# 94       22
# 4        21
# 97       14
# 5         8
# 85        3
# 6         2
# Name: count, dtype: int64
#
# Year: 2007
# Row Count: 55049
# AGE2 Stats:
# count    55049.000000
# mean         9.639757
# std          4.903529
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28530
# 1    26519
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     28052
# 1     14184
# 99     8442
# 3      3464
# 2       907
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     38112
# 99    14607
# 1      2328
# 97        2
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    24819
# 93    16028
# 99    14008
# 6        47
# 5        28
# 98       27
# 4        27
# 1        20
# 3        13
# 94       12
# 2        12
# 97        8
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    24051
# 91    15084
# 93    14813
# 98      914
# 1        55
# 2        37
# 3        28
# 4        20
# 97       19
# 94       15
# 85        6
# 5         5
# 6         2
# Name: count, dtype: int64
#
# Year: 2008
# Row Count: 55110
# AGE2 Stats:
# count    55110.000000
# mean         9.588478
# std          4.859297
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28682
# 1    26428
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     29114
# 1     13486
# 99     8280
# 3      3358
# 2       872
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     38341
# 99    14522
# 1      2244
# 94        1
# 98        1
# 97        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    25262
# 93    15943
# 99    13761
# 98       26
# 3        25
# 6        23
# 4        20
# 1        13
# 2        13
# 94        9
# 5         9
# 97        6
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    23816
# 91    15422
# 93    14771
# 98      913
# 1        57
# 2        34
# 3        27
# 4        24
# 97       21
# 94       15
# 5         6
# 85        3
# 6         1
# Name: count, dtype: int64
#
# Year: 2009
# Row Count: 55234
# AGE2 Stats:
# count    55234.000000
# mean         9.645182
# std          4.863260
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28760
# 1    26474
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     29376
# 1     13428
# 99     8167
# 3      3382
# 2       881
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     38634
# 99    14375
# 1      2223
# 94        2
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    25602
# 93    15848
# 99    13612
# 98       36
# 6        30
# 4        24
# 5        21
# 2        19
# 1        16
# 3        15
# 94        9
# 97        2
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    24271
# 91    15350
# 93    14485
# 98      934
# 1        66
# 3        35
# 2        31
# 4        23
# 97       20
# 94       11
# 5         6
# 85        1
# 6         1
# Name: count, dtype: int64
#
# Year: 2010
# Row Count: 57313
# AGE2 Stats:
# count    57313.000000
# mean         9.624553
# std          4.906953
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    29785
# 1    27528
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     30116
# 1     13789
# 99     8881
# 3      3567
# 2       960
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     39909
# 99    15186
# 1      2207
# 85        9
# 97        1
# 98        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    27157
# 93    16475
# 99    13534
# 4        28
# 6        23
# 98       21
# 94       18
# 5        15
# 2        14
# 3        13
# 1         8
# 97        7
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    25017
# 91    16397
# 93    14743
# 98      940
# 1        61
# 3        43
# 2        34
# 4        28
# 94       20
# 97       16
# 5         9
# 85        3
# 6         2
# Name: count, dtype: int64
#
# Year: 2011
# Row Count: 58397
# AGE2 Stats:
# count    58397.000000
# mean         9.583283
# std          4.959374
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    30043
# 1    28354
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     30679
# 1     13760
# 99     9293
# 3      3694
# 2       971
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     40142
# 99    15941
# 1      2306
# 85        5
# 98        2
# 97        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    28633
# 93    16205
# 99    13403
# 6        28
# 4        22
# 98       21
# 3        21
# 1        16
# 2        16
# 5        15
# 94       10
# 97        7
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    24813
# 91    17570
# 93    14926
# 98      914
# 1        52
# 2        33
# 4        22
# 94       21
# 3        20
# 97       19
# 6         3
# 85        2
# 5         2
# Name: count, dtype: int64
#
# Year: 2012
# Row Count: 55268
# AGE2 Stats:
# count    55268.000000
# mean         9.724506
# std          4.922287
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         14.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28726
# 1    26542
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     29238
# 1     13110
# 99     8347
# 3      3596
# 2       977
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     38660
# 99    14361
# 1      2234
# 85       12
# 97        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    27387
# 93    15324
# 99    12412
# 6        39
# 4        21
# 98       16
# 1        15
# 5        14
# 94       14
# 3        13
# 2         8
# 97        5
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    23817
# 91    16489
# 93    13929
# 98      860
# 1        58
# 2        30
# 4        24
# 3        24
# 97       18
# 94       12
# 5         5
# 6         2
# Name: count, dtype: int64
#
# Year: 2013
# Row Count: 55160
# AGE2 Stats:
# count    55160.000000
# mean         9.690555
# std          4.955355
# min          1.000000
# 25%          5.000000
# 50%         11.000000
# 75%         15.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28829
# 1    26331
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     29151
# 1     12881
# 99     8689
# 3      3489
# 2       950
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     38320
# 99    14753
# 1      2069
# 85       17
# 94        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    28008
# 93    15194
# 99    11845
# 6        16
# 98       16
# 4        14
# 5        13
# 3        13
# 2        13
# 1        12
# 94       10
# 97        6
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    23377
# 91    17005
# 93    13740
# 98      868
# 1        57
# 2        42
# 3        21
# 4        17
# 97       15
# 94       10
# 5         5
# 6         2
# 85        1
# Name: count, dtype: int64
#
# Year: 2014
# Row Count: 55271
# AGE2 Stats:
# count    55271.000000
# mean        11.008359
# std          4.940738
# min          1.000000
# 25%          7.000000
# 50%         13.000000
# 75%         15.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    28949
# 1    26322
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     24713
# 1     17785
# 99     6683
# 3      4801
# 2      1289
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     41121
# 99    11383
# 1      2739
# 85       28
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    26059
# 93    17594
# 99    11507
# 6        24
# 98       21
# 4        17
# 3        12
# 1        12
# 2        11
# 94        7
# 5         6
# 97        1
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    25598
# 91    14571
# 93    14164
# 98      739
# 1        57
# 2        43
# 3        30
# 4        20
# 94       17
# 97       17
# 5        10
# 6         4
# 85        1
# Name: count, dtype: int64
#
# Year: 2015
# Row Count: 57146
# AGE2 Stats:
# count    57146.000000
# mean        11.001575
# std          4.859445
# min          1.000000
# 25%          7.000000
# 50%         13.000000
# 75%         15.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    30410
# 1    26736
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     25897
# 1     18062
# 99     6639
# 3      4856
# 2      1692
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     43147
# 99    11324
# 1      2652
# 85       21
# 89        1
# 94        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    28236
# 93    17481
# 99    11321
# 98       24
# 6        23
# 3        14
# 4        13
# 2        13
# 1         7
# 97        5
# 5         5
# 94        4
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    25717
# 91    15536
# 93    14859
# 98      879
# 1        53
# 97       26
# 2        22
# 3        19
# 4        15
# 5        10
# 94        6
# 6         3
# 85        1
# Name: count, dtype: int64
#
# Year: 2016
# Row Count: 56897
# AGE2 Stats:
# count    56897.000000
# mean        10.925550
# std          4.951137
# min          1.000000
# 25%          6.000000
# 50%         13.000000
# 75%         15.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    29756
# 1    27141
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     26312
# 1     17475
# 99     7068
# 3      4753
# 2      1289
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     42224
# 99    12016
# 1      2624
# 85       30
# 89        1
# 97        1
# 94        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    29174
# 93    17027
# 99    10589
# 6        25
# 98       16
# 94       13
# 2        12
# 1        11
# 3        10
# 4         8
# 97        7
# 5         5
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    25032
# 91    16409
# 93    14460
# 98      859
# 1        43
# 2        28
# 4        17
# 97       14
# 3        14
# 94        8
# 5         7
# 6         5
# 85        1
# Name: count, dtype: int64
#
# Year: 2017
# Row Count: 56276
# AGE2 Stats:
# count    56276.000000
# mean        10.993496
# std          4.892097
# min          1.000000
# 25%          7.000000
# 50%         13.000000
# 75%         15.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    29239
# 1    27037
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     26370
# 1     17655
# 99     6585
# 3      4467
# 2      1199
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     42331
# 99    11366
# 1      2558
# 85       21
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    28971
# 93    17018
# 99    10166
# 98       31
# 6        29
# 1        16
# 4        10
# 5        10
# 3         9
# 2         9
# 97        4
# 94        3
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    25114
# 91    15715
# 93    14440
# 98      855
# 1        50
# 2        26
# 3        22
# 94       19
# 97       15
# 4        13
# 5         4
# 6         3
# Name: count, dtype: int64
#
# Year: 2018
# Row Count: 56313
# AGE2 Stats:
# count    56313.000000
# mean        11.086268
# std          4.888741
# min          1.000000
# 25%          7.000000
# 50%         13.000000
# 75%         15.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    29358
# 1    26955
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     26042
# 1     17932
# 99     6528
# 3      4547
# 2      1264
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     42661
# 99    11064
# 1      2568
# 85       15
# 98        3
# 97        2
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    29686
# 93    16991
# 99     9525
# 98       25
# 6        20
# 3        15
# 94       11
# 1        11
# 2        10
# 4         8
# 97        6
# 5         5
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    24886
# 91    15849
# 93    14573
# 98      824
# 1        54
# 2        40
# 3        22
# 94       21
# 97       19
# 4        15
# 5         7
# 6         3
# Name: count, dtype: int64
#
# Year: 2019
# Row Count: 56136
# AGE2 Stats:
# count    56136.000000
# mean        10.998753
# std          4.889195
# min          1.000000
# 25%          7.000000
# 50%         13.000000
# 75%         15.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    29348
# 1    26788
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     26750
# 1     16983
# 99     6555
# 3      4515
# 2      1333
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     42608
# 99    11171
# 1      2336
# 85       20
# 97        1
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    30465
# 93    16426
# 99     9142
# 6        28
# 98       22
# 4        15
# 2        12
# 1         8
# 94        7
# 97        5
# 3         3
# 5         3
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    24660
# 91    16008
# 93    14441
# 98      851
# 1        66
# 2        28
# 3        20
# 4        19
# 97       18
# 94       13
# 5         8
# 6         3
# 85        1
# Name: count, dtype: int64
#
# Year: 2020
# Row Count: 32893
# AGE2 Stats:
# count    32893.000000
# mean        11.839297
# std          4.594596
# min          1.000000
# 25%          9.000000
# 50%         14.000000
# 75%         15.000000
# max         17.000000
# Name: AGE2, dtype: float64
# IRSEX Distribution:
# IRSEX
# 2    17763
# 1    15130
# Name: count, dtype: int64
# IRMARIT Distribution:
# IRMARIT
# 4     14452
# 1     12146
# 99     3021
# 3      2613
# 2       661
# Name: count, dtype: int64
# SERVICE Distribution:
# SERVICE
# 2     26421
# 99     4882
# 1      1561
# 85       24
# 97        5
# Name: count, dtype: int64
# CG30EST Distribution:
# CG30EST
# 91    18268
# 93    10511
# 99     4079
# 98        9
# 4         6
# 6         6
# 2         4
# 1         3
# 3         3
# 5         3
# 94        1
# Name: count, dtype: int64
# AL30EST Distribution:
# AL30EST
# 99    15821
# 91     8373
# 93     8297
# 98      335
# 1        17
# 2        15
# 3        11
# 97        9
# 4         9
# 5         5
# 94        1
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = com

# Group the data by 'year'
yearly_groups = df.groupby('year')

# Function to visualize yearly distributions
def visualize_yearly_eda(groups):
    for year, group in groups:
        print(f"Visualizing data for year: {year}")
        
        # Create a figure with subplots
        fig, axes = plt.subplots(3, 2, figsize=(12, 18))
        fig.suptitle(f"Yearly EDA for {year}", fontsize=16)

        # AGE2 - Histogram
        sns.histplot(group['AGE2'], bins=10, kde=True, ax=axes[0, 0])
        axes[0, 0].set_title("AGE2 Distribution")
        axes[0, 0].set_xlabel("AGE2")
        axes[0, 0].set_ylabel("Frequency")

        # IRSEX - Bar Plot
        group['IRSEX'].value_counts(sort=False).sort_index().plot(kind='bar', ax=axes[0, 1], color='skyblue')
        axes[0, 1].set_title("IRSEX Distribution")
        axes[0, 1].set_xlabel("IRSEX")
        axes[0, 1].set_ylabel("Count")

        # IRMARIT - Bar Plot
        group['IRMARIT'].value_counts(sort=False).sort_index().plot(kind='bar', ax=axes[1, 0], color='lightgreen')
        axes[1, 0].set_title("IRMARIT Distribution")
        axes[1, 0].set_xlabel("IRMARIT")
        axes[1, 0].set_ylabel("Count")

        # SERVICE - Bar Plot
        group['SERVICE'].value_counts(sort=False).sort_index().plot(kind='bar', ax=axes[1, 1], color='salmon')
        axes[1, 1].set_title("SERVICE Distribution")
        axes[1, 1].set_xlabel("SERVICE")
        axes[1, 1].set_ylabel("Count")

        # CG30EST - Bar Plot
        group['CG30EST'].value_counts(sort=False).sort_index().plot(kind='bar', ax=axes[2, 0], color='orange')
        axes[2, 0].set_title("CG30EST Distribution")
        axes[2, 0].set_xlabel("CG30EST")
        axes[2, 0].set_ylabel("Count")

        # AL30EST - Bar Plot
        group['AL30EST'].value_counts(sort=False).sort_index().plot(kind='bar', ax=axes[2, 1], color='purple')
        axes[2, 1].set_title("AL30EST Distribution")
        axes[2, 1].set_xlabel("AL30EST")
        axes[2, 1].set_ylabel("Count")

        # Adjust layout and save the figure
        plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust rect for the title
        plt.savefig(f"eda_visualization_{year}.png")  # Save the visualization as a PNG
        plt.show()

# Call the visualization function
visualize_yearly_eda(yearly_groups)
# Out:
# Visualizing data for year: 2000
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2001
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2002
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2003
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2004
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2005
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2006
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2007
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2008
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2009
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2010
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2011
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2012
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2013
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2014
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2015
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2016
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2017
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2018
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2019
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Visualizing data for year: 2020
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
