# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ## Download repo and installing required packages

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main
# Out:
# /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# fatal: destination path 'yolov10' already exists and is not an empty directory.

# %%
cd yolov10
# Out:
# /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/yolov10

# %%
# !pip install .
# Out:
# Processing /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...

# %% [markdown]
# ## Download pretrained model(YOLOv10l)

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/yolov10/weights/yolov10l.pt

# %% [markdown]
# ## Inference using pretrained model - Object Detection

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=../weights/yolov10l.pt source="/content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4"
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10l summary (fused): 461 layers, 25839728 parameters, 148320 gradients, 127.0 GFLOPs
#
# video 1/1 (frame 1/201) /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4: 384x640 1 58, 102.4ms
# video 1/1 (frame 2/201) /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4: 384x640 1 58, 36.0ms
# video 1/1 (frame 3/201) /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4: 384x640 1 58, 36.0ms
# video 1/1 (frame 4/201) /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4: 384x640 1 58, 34.9ms
# video 1/1 (frame 5/201) /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4: 384x640 (no detections), 31.3ms
# ...

# %% [markdown]
# ## Train Custom Model

# %% [markdown]
# ### 1~50 epoch

# %%
# !yolo task=detect mode=train epochs=50 batch=16 plots=True model=weights/yolov10l.pt data='/content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/custom_dataset/fall-detection.v2i.yolov9/data.yaml' save_period=5
# Out:
# New https://pypi.org/project/ultralytics/8.2.81 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### 51~100 epoch

# %%
# !yolo task=detect mode=train epochs=50 batch=16 plots=True model=runs/detect/train6/weights/last.pt data='/content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/custom_dataset/fall-detection.v2i.yolov9/data.yaml' save_period=5
# Out:
# New https://pypi.org/project/ultralytics/8.2.81 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Inference on Video - Fall Detection

# %%
# !yolo task=detect mode=predict conf=0.05 save=True model=runs/detect/train7/weights/best.pt source="/content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4"
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10l summary (fused): 461 layers, 25717910 parameters, 0 gradients, 126.3 GFLOPs
#
# video 1/1 (frame 1/201) /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4: 384x640 (no detections), 82.8ms
# video 1/1 (frame 2/201) /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4: 384x640 (no detections), 32.2ms
# video 1/1 (frame 3/201) /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4: 384x640 (no detections), 32.1ms
# video 1/1 (frame 4/201) /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4: 384x640 (no detections), 32.1ms
# video 1/1 (frame 5/201) /content/drive/MyDrive/Colab Notebooks/YOLOv10-Custom-Object-Detection-main/Fall_yeonho.mp4: 384x640 (no detections), 32.1ms
# ...
