# %%
import random

# 주민등록번호와 휴대번호 데이터가 기존 데이터셋에 부재
# 가상의 주민등록번호와 휴대번호 데이터셋 생성
def generate_fake_data(num_samples):
    names = ["홍길동", "김철수", "이영희"]
    places = ["서울", "부산", "대구"]
    organizations = ["삼성", "LG", "현대"]
    phone_prefixes = ["010", "011", "016"]
    rrn_prefixes = ["990101", "850505", "770303"]

    data = []
    for _ in range(num_samples):
        name = random.choice(names)
        place = random.choice(places)
        org = random.choice(organizations)
        phone = f"{random.choice(phone_prefixes)}-{random.randint(1000, 9999)}-{random.randint(1000, 9999)}"
        rrn = f"{random.choice(rrn_prefixes)}-{random.randint(1000000, 9999999)}"

        sample = f"{name}은 {place}에 사는 {org} 직원입니다. 연락처는 {phone}이고, 주민등록번호는 {rrn}입니다."
        data.append(sample)
    return data

# 데이터셋 토큰화 및 레이블링
def tokenize_and_label(text):
    tokens = []
    labels = []
    words = text.split()
    for word in words:
        if "-" in word and word.count("-") == 2 and word.split("-")[0] in ["010", "011", "016"]:
            for i, part in enumerate(word.split("-")):
                if i == 0:
                    tokens.append(part)
                    labels.append("B-PH")
                else:
                    tokens.append(part)
                    labels.append("I-PH")
        elif "-" in word and word.count("-") == 1 and word.split("-")[0].isdigit() and len(word.split("-")[0]) == 6:
            for i, part in enumerate(word.split("-")):
                if i == 0:
                    tokens.append(part)
                    labels.append("B-RRN")
                else:
                    tokens.append(part)
                    labels.append("I-RRN")
        else:
            for char in word:
                tokens.append(char)
                labels.append("O")
    return tokens, labels

# 가상의 데이터셋 생성 및 레이블링
fake_data = generate_fake_data(2000)
tokenized_data = [tokenize_and_label(sample) for sample in fake_data]

# %%
fake_data
# Out:
# ['홍길동은 부산에 사는 LG 직원입니다. 연락처는 010-4308-8150이고, 주민등록번호는 990101-7451148입니다.',
#  '김철수은 서울에 사는 삼성 직원입니다. 연락처는 011-8256-8593이고, 주민등록번호는 990101-2191342입니다.',
#  '김철수은 대구에 사는 현대 직원입니다. 연락처는 010-8657-2581이고, 주민등록번호는 770303-6044718입니다.',
#  '김철수은 서울에 사는 LG 직원입니다. 연락처는 010-8584-8460이고, 주민등록번호는 990101-2106666입니다.',
#  '이영희은 서울에 사는 현대 직원입니다. 연락처는 016-5508-6701이고, 주민등록번호는 990101-8760928입니다.',
#  '홍길동은 부산에 사는 LG 직원입니다. 연락처는 016-4934-1390이고, 주민등록번호는 850505-9753780입니다.',
#  '홍길동은 대구에 사는 삼성 직원입니다. 연락처는 010-2041-4652이고, 주민등록번호는 770303-1491280입니다.',
#  '이영희은 대구에 사는 LG 직원입니다. 연락처는 011-9625-6517이고, 주민등록번호는 850505-2642537입니다.',
#  '김철수은 서울에 사는 삼성 직원입니다. 연락처는 011-6706-7223이고, 주민등록번호는 850505-7818963입니다.',
#  '이영희은 서울에 사는 삼성 직원입니다. 연락처는 011-8408-9870이고, 주민등록번호는 990101-7876736입니다.',
#  '이영희은 서울에 사는 삼성 직원입니다. 연락처는 010-7042-3308이고, 주민등록번호는 770303-7245944입니다.',
#  '홍길동은 부산에 사는 LG 직원입니다. 연락처는 010-8017-3781이고, 주민등록번호는 770303-9178076입니다.',
#  '이영희은 부산에 사는 현대 직원입니다. 연락처는 011-2766-5103이고, 주민등록번호는 990101-8679254입니다.',
#  '이영희은 부산에 사는 현대 직원입니다. 연락처는 016-5231-4443이고, 주민등록번호는 770303-9300328입니다.',
#  '김철수은 서울에 사는 삼성 직원입니다. 연락처는 011-3036-1254이고, 주민등록번호는 850505-3105680입니다.',
#  '이영희은 서울에 사는 현대 직원입니다. 연락처는 010-9317-4803이고, 주민등록번호는 770303-1091270입니다.',
#  '홍길동은 서울에 사는 삼성 직원입니다. 연락처는 010-5588-1264이고, 주민등록번호는 990101-6370618입니다.',
#  '김철수은 부산에 사는 삼성 직원입니다. 연락처는 016-7411-3895이고, 주민등록번호는 770303-4566922입니다.',
#  '김철수은 부산에 사는 LG 직원입니다. 연락처는 011-4680-6466이고, 주민등록번호는 990101-2232201입니다.',
#  '홍길동은 대구에 사는 현대 직원입니다. 연락처는 016-5581-8899이고, 주민등록번호는 850505-1561325입니다.',
#  '홍길동은 대구에 사는 삼성 직원입니다. 연락처는 011-9855-8625이고, 주민등록번호는 850505-4516193입니다.',
#  '김철수은 서울에 사는 현대 직원입니다. 연락처는 016-2229-7385이고, 주민등록번호는 990101-1286311입니다.',
#  '김철수은 서울에 사는 삼성 직원입니다. 연락처는 011-2980-2316이고, 주민등록번호는 850505-1753926입니다.',
#  '김철수은 서울에 사는 현대 직원입니다. 연락처는 011-9204-8202이고, 주민등록번호는 990101-3159310입니다.',
#  '김철수은 대구에 사는 LG 직원입니다. 연락처는
니다.',
#  '김철수은 서울에 사는 LG 직원입니다. 연락처는 010-2822-4109이고, 주민등록번호는 850505-6344119입니다.',
#  '홍길동은 서울에 사는 삼성 직원입니다. 연락처는 011-1660-3823이고, 주민등록번호는 770303-1524433입니다.',
#  '김철수은 대구에 사는 LG 직원입니다. 연락처는 016-6689-8835이고, 주민등록번호는 990101-8270200입니다.',
#  '김철수은 서울에 사는 LG 직원입니다. 연락처는 011-4520-5118이고, 주민등록번호는 850505-4205201입니다.',
#  '김철수은 대구에 사는 삼성 직원입니다. 연락처는 011-4228-6290이고, 주민등록번호는 770303-8731120입니다.',
#  '홍길동은 부산에 사는 현대 직원입니다. 연락처는 016-6035-9001이고, 주민등록번호는 770303-4595749입니다.',
#  '김철수은 부산에 사는 LG 직원입니다. 연락처는 016-2373-9363이고, 주민등록번호는 770303-8474958입니다.',
#  '홍길동은 서울에 사는 삼성 직원입니다. 연락처는 016-7497-1880이고, 주민등록번호는 850505-4455490입니다.',
#  '홍길동은 서울에 사는 LG 직원입니다. 연락처는 010-5657-3375이고, 주민등록번호는 850505-5339041입니다.',
#  '김철수은 대구에 사는 삼성 직원입니다. 연락처는 010-1464-9196이고, 주민등록번호는 990101-9121197입니다.',
#  '홍길동은 서울에 사는 LG 직원입니다. 연락처는 016-8448-7671이고, 주민등록번호는 990101-2734695입니다.',
#  '홍길동은 서울에 사는 현대 직원입니다. 연락처는 010-9433-2265이고, 주민등록번호는 770303-9759471입니다.',
#  '이영희은 대구에 사는 삼성 직원입니다. 연락처는 011-7090-7099이고, 주민등록번호는 770303-9328117입니다.',
#  '이영희은 대구에 사는 LG 직원입니다. 연락처는 016-6043-5481이고, 주민등록번호는 990101-4142391입니다.',
#  '홍길동은 부산에 사는 현대 직원입니다. 연락처는 011-5878-7765이고, 주민등록번호는 990101-4260114입니다.',
#  '김철수은 부산에 사는 LG 직원입니다. 연락처는 010-2604-8998이고, 주민등록번호는 850505-5583086입니다.',
#  '이영희은 대구에 사는 삼성 직원입니다. 연락처는 010-3902-2099이고, 주민등록번호는 770303-7912897입니다.',
#  '홍길동은 대구에 사는 현대 직원입니다. 연락처는 011-7187-8490이고, 주민등록번호는 850505-9480281입니다.',
#  '홍길동은 대구에 사는 삼성 직원입니다. 연락처는 016-6052-4721이고, 주민등록번호는 990101-9248467입니다.',
#  '이영희은 부산에 사는 삼성 직원입니다. 연락처는 011-3020-2209이고, 주민등록번호는 990101-3229655입니다.',
#  '홍길동은 대구에 사는 현대 직원입니다. 연락처는 016-2254-8796이고, 주민등록번호는 990101-8544907입니다.',
#  '홍길동은 부산에 사는 LG 직원입니다. 연락처는 010-7385-6102이고, 주민등록번호는 990101-8876440입니다.',
#  '김철수은 대구에 사는 현대 직원입니다. 연락처는 011-1744-9677이고, 주민등록번호는 990101-7494690입니다.',
#  '홍길동은 대구에 사는 삼성 직원입니다. 연락처는 016-8291-8785이고, 주민등록번호는 990101-1682920입니다.',
#  '이영희은 서울에 사는 현대 직원입니다. 연락처는 010-5428-7651이고, 주민등록번호는 770303-1572502입니다.',
#  '김철수은 부산에 사는 삼성 직원입니다. 연락처는 016-7176-3234이고, 주민등록번호는 850505-9879546입니다.',
#  '김철수은 대구에 사는 삼성 직원입니다. 연락처는 010-1309-5519이고, 주민등록번호는 770303-3017534입니다.',
#  '김철수은 대구에 사는 삼성 직원입니다. 연락처는 016-4312-9770이고, 주민등록번호는 850505-2851899입니다.',
#  '이영희은 서울에 사는 LG 직원입니다. 연락처는 011-7427-5151이고, 주민등록번호는 770303-8899231입니다.',
#  '이영희은 서울에 사는 LG 직원입니다. 연락처는 011-8608-5289이고, 주민등록번호는 990101-5708616입니다.',
#  '이영희은 부산에 사는 LG 직원입니다. 연락처는 011-7205-2216이고, 주민등록번호는 850505-2358472입니다.',
#  '홍길동은 대구에 사는 현대 직원입니다. 연락처는 016-7084-9383이고, 주민등록번호는 770303-7053901입니다.',
#  '이영희은 부산에 사는 삼성 직원입니다. 연락처는 016-3232-2217이고, 주민등록번호는 850505-6420761입니다.',
#  '이영희은 대구에 사는 LG 직원입니다. 연락처는 011-7276-4756이고, 주민등록번호는 990101-2150790입니다.',
#  '이영희은 서울에 사는 LG 직원입니다. 연락처는 010-7979-2110이고, 주민등록번호는 990101-9380884입니다.',
#  '홍길동은 대구에 사는 LG 직원입니다. 연락처는 016-7137-1301이고, 주민등록번호는 850505-2556293입니다.',
#  '홍길동은 대구에 사는 현대 직원입니다. 연락처는 011-2845-2838이고, 주민등록번호는 770303-1136277입니다.',
#  '홍길동은 부산에 사는 삼성 직원입니다. 연락처는 016-4916-5698이고, 주민등록번호는 770303-6759132입니다.',
#  '김철수은 서울에 사는 LG 직원입니다. 연락처는 016-3286-9093이고, 주민등록번호는 850505-7714865입니다.',
#  '홍길동은 대구에 사는 현대 직원입니다. 연락처는 016-2294-2708이고, 주민등록번호는 770303-2817445입니다.',
#  '이영희은 대구에 사는 삼성 직원입니다. 연락처는 010-6049-2371이고, 주민등록번호는 990101-9022436입니다.',
#  '김철수은 대구에 사는 삼성 직원입니다. 연락처는 011-7454-1050이고, 주민등록번호는 850505-9355770입니다.',
#  '김철수은 부산에 사는 삼성 직원입니다. 연락처는 010-6101-7027이고, 주민등록번호는 850505-4537809입니다.',
#  '이영희은 대구에 사는 현대 직원입니다. 연락처는 011-2438-4694이고, 주민등록번호는 990101-4625653입니다.',
#  '홍길동은 대구에 사는 현대 직원입니다. 연락처는 011-7773-6525이고, 주민등록번호는 850505-8342325입니다.',
#  ...]

# %%
tokenized_data
# Out:
# [(['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '4308',
#    '8150이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '7451148입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '8256',
#    '8593이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '2191342입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '8657',
#    '2581이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '6044718입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '8584',
#    '8460이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '2106666입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '5508',
#    '6701이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '8760928입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '4934',
#    '1390이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '9753780입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '2041',
#    '4652이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '1491280입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '9625',
#    '6517이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '2642537입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '6706',
#    '7223이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '7818963입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '8408',
#    '9870이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '7876736입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '7042',
#    '3308이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '7245944입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '8017',
#    '3781이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '9178076입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '2766',
#    '5103이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '8679254입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '5231',
#    '4443이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '9300328입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '3036',
#    '1254이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '3105680입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '9317',
#    '4803이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '1091270입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '5588',
#    '1264이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '6370618입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '7411',
#    '3895이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '4566922입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '4680',
#    '6466이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '2232201입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '5581',
#    '8899이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '1561325입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '9855',
#    '8625이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '4516193입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2229',
#    '7385이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '1286311입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '2980',
#    '2316이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '1753926입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '9204',
#    '8202이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '3159310입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '5808',
#    '2097이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '5321255입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '4259',
#    '2829이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '8916041입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '9075',
#    '5603이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '7285093입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '3303',
#    '9792이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '1288168입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '6544',
#    '9323이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '6342604입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2020',
#    '9231이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '2951751입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '5577',
#    '8180이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '8252132입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '3358',
#    '8037이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '1032870입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '1419',
#    '9512이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '5143187입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '2766',
#    '1669이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '1840913입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '3077',
#    '6016이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '5195603입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '6141',
#    '2584이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '1906569입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '6283',
#    '3154이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '7779820입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2641',
#    '4386이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '6144889입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '4310',
#    '3315이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '9342514입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '2319',
#    '5932이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '3289740입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2033',
#    '6457이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '8132409입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2796',
#    '8695이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '4266501입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '9626',
#    '8343이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '5770649입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '5865',
#    '1721이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '2227315입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2648',
#    '2274이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '6957368입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '9348',
#    '4629이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '3506577입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2639',
#    '2706이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '1897050입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '4607',
#    '6027이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '9149405입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '4086',
#    '1088이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '3769721입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '2222',
#    '5705이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '2901340입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '6589',
#    '9458이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '8535961입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '6221',
#    '7977이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '5044219입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2365',
#    '5520이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '5340016입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '5865',
#    '3688이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '3964918입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '1350',
#    '5428이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '9522721입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '9056',
#    '6871이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '6104108입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '9066',
#    '7122이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '7110298입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '8818',
#    '7266이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '9560873입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '1723',
#    '4518이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '1405479입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '5821',
#    '2629이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '1935663입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '1679',
#    '4346이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '8823773입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '6716',
#    '8358이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '9470898입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '1992',
#    '6171이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '6903063입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '3772',
#    '1176이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '7958214입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '9148',
#    '8892이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '4126136입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '1535',
#    '1334이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '3917808입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '6190',
#    '8309이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '1816341입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2872',
#    '9771이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '6745778입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '6995',
#    '8680이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '5122393입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '2410',
#    '6469이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '4069261입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '4857',
#    '7672이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '5414906입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '1752',
#    '1207이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '3024651입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '3683',
#    '2214이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '5661181입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '1800',
#    '9285이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '8463949입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '3975',
#    '7565이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '7242187입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '2974',
#    '8117이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '9552021입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '5179',
#    '6168이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '1256920입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '4102',
#    '3344이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '6548945입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '1615',
#    '9190이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '9890874입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '3499',
#    '8755이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '1625636입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '7114',
#    '1915이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '1005612입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '9784',
#    '4026이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '4733312입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '4220',
#    '4170이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '6428866입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '2448',
#    '5708이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '5887343입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
# ...
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '7187',
#    '8490이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '9480281입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '6052',
#    '4721이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '9248467입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '3020',
#    '2209이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '3229655입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2254',
#    '8796이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '8544907입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '7385',
#    '6102이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '8876440입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '1744',
#    '9677이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '7494690입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '8291',
#    '8785이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '1682920입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '5428',
#    '7651이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '1572502입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '7176',
#    '3234이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '9879546입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '1309',
#    '5519이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '3017534입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '4312',
#    '9770이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '2851899입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '7427',
#    '5151이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '8899231입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '8608',
#    '5289이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '5708616입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '7205',
#    '2216이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '2358472입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '7084',
#    '9383이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '7053901입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '3232',
#    '2217이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '6420761입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '7276',
#    '4756이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '2150790입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '7979',
#    '2110이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '9380884입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '7137',
#    '1301이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '2556293입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '2845',
#    '2838이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '1136277입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '4916',
#    '5698이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '6759132입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '서',
#    '울',
#    '에',
#    '사',
#    '는',
#    'L',
#    'G',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '3286',
#    '9093이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '7714865입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '016',
#    '2294',
#    '2708이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '770303',
#    '2817445입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '6049',
#    '2371이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '9022436입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '7454',
#    '1050이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '9355770입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['김',
#    '철',
#    '수',
#    '은',
#    '부',
#    '산',
#    '에',
#    '사',
#    '는',
#    '삼',
#    '성',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '010',
#    '6101',
#    '7027이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '4537809입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['이',
#    '영',
#    '희',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '2438',
#    '4694이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '990101',
#    '4625653입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  (['홍',
#    '길',
#    '동',
#    '은',
#    '대',
#    '구',
#    '에',
#    '사',
#    '는',
#    '현',
#    '대',
#    '직',
#    '원',
#    '입',
#    '니',
#    '다',
#    '.',
#    '연',
#    '락',
#    '처',
#    '는',
#    '011',
#    '7773',
#    '6525이고,',
#    '주',
#    '민',
#    '등',
#    '록',
#    '번',
#    '호',
#    '는',
#    '850505',
#    '8342325입니다.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PH',
#    'I-PH',
#    'I-PH',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-RRN',
#    'I-RRN']),
#  ...]

# %%
# 기존 데이터 로드 및 새로운 레이블 추가 함수
def load_data_with_new_labels(file_path, new_data):
    texts, labels = [], []
    label_map = {
        'O': 0, 'B-PS': 1, 'I-PS': 2, 'B-LC': 3, 'I-LC': 4,
        'B-OG': 5, 'I-OG': 6, 'B-QT': 7, 'I-QT': 8, 'B-DT': 9,
        'I-DT': 10, 'B-TI': 11, 'I-TI': 12, 'B-LT': 13, 'I-LT': 14,
        'B-PO': 15, 'I-PO': 16, 'B-PH': 17, 'I-PH': 18, 'B-RRN': 19, 'I-RRN': 20
    }
    # 기존 데이터 로드
    with open(file_path, 'r', encoding='utf-8') as file:
        text, label = [], []
        for line in file:
            if line.startswith('##') or not line.strip():
                if text:
                    texts.append(" ".join(text))
                    labels.append([label_map[l] for l in label])
                    text, label = [], []
                continue
            parts = line.strip().split('\t')
            if len(parts) != 2:
                continue
            char, tag = parts
            text.append(char)
            label.append(tag)

    # 새로운 가상 주민등록번호 및 휴대번호 데이터셋 추가
    for tokens, tags in new_data:
        texts.append(" ".join(tokens))
        labels.append([label_map[tag] for tag in tags])

    return texts, labels

# 새로운 데이터셋 로드 및 추가
train_texts, train_labels = load_data_with_new_labels('klue-ner-v1.1_train (2).tsv', tokenized_data)
dev_texts, dev_labels = load_data_with_new_labels('klue-ner-v1.1_dev (3).tsv', tokenized_data)

# %%
import torch
from transformers import BertTokenizer, BertForTokenClassification
from torch.utils.data import Dataset, DataLoader

class PIIDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, item):
        text = str(self.texts[item])
        labels = self.labels[item]

        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )

        tokens = self.tokenizer.convert_ids_to_tokens(encoding['input_ids'][0])
        aligned_labels = [0] * len(tokens)
        j = 0

        for i, token in enumerate(tokens):
            if token.startswith("##"):
                continue
            if token in ["[CLS]", "[SEP]", "[PAD]"]:
                aligned_labels[i] = 0
            elif j < len(labels):
                aligned_labels[i] = labels[j]
                j += 1

        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(aligned_labels, dtype=torch.long)
        }

# 토크나이저 및 데이터셋 준비
tokenizer = BertTokenizer.from_pretrained('klue/bert-base')
model = BertForTokenClassification.from_pretrained('klue/bert-base', num_labels=21)

max_len = 128
train_dataset = PIIDataset(train_texts, train_labels, tokenizer, max_len)
dev_dataset = PIIDataset(dev_texts, dev_labels, tokenizer, max_len)

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
dev_dataloader = DataLoader(dev_dataset, batch_size=32, shuffle=False)

# GPU 설정(L4 GPU 사용)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# 학습 및 평가
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=5,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=dev_dataset
)

trainer.train()
trainer.evaluate()
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at klue/bert-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='3595' max='3595' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3595/3595 21:56, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.049900</td>
#       <td>0.049121</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.039200</td>
#       <td>0.040190</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.030900</td>
#       <td>0.039557</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.025900</td>
#       <td>0.039124</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.019900</td>
#       <td>0.040152</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='219' max='219' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [219/219 00:24]
#     </div>
# {'eval_loss': 0.04015155881643295,
#  'eval_runtime': 24.7733,
#  'eval_samples_per_second': 282.563,
#  'eval_steps_per_second': 8.84,
#  'epoch': 5.0}

# %%
def detect_and_mask_pii(text, model, tokenizer, device):
    model.eval()
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    inputs = inputs.to(device)
    with torch.no_grad():
        outputs = model(**inputs)

    predictions = torch.argmax(outputs.logits, dim=2)
    tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])

    label_map = {
        0: 'O', 1: 'B-PS', 2: 'I-PS', 3: 'B-LC', 4: 'I-LC',
        5: 'B-OG', 6: 'I-OG', 7: 'B-QT', 8: 'I-QT', 9: 'B-DT',
        10: 'I-DT', 11: 'B-TI', 12: 'I-TI', 13: 'B-LT', 14: 'I-LT',
        15: 'B-PO', 16: 'I-PO', 17: 'B-PH', 18: 'I-PH', 19: 'B-RRN', 20: 'I-RRN'
    }
    masked_text = []
    current_mask = None
    for token, pred in zip(tokens, predictions[0]):
        if token in ["[CLS]", "[SEP]", "[PAD]"]:
            continue
        label = label_map[pred.item()]
        if label != 'O':
            if current_mask != label:
                current_mask = label
                masked_text.append(f'[MASK-{label}]')
        else:
            masked_text.append(token)
            current_mask = None

    masked_text = " ".join(masked_text)
    masked_text = masked_text.replace(" ##", "").replace(" .", ".")
    return masked_text

# %%
test_text = "강감찬 장군은 고려시대 인물로 , 현재 서울시 관악구 봉천동 1234번지에 그의 동상이 있습니다 . 그의 생년은 948년으로 알려져 있습니다 ."
masked_text = detect_and_mask_pii(test_text, model, tokenizer, device)
print(masked_text)
# Out:
# [MASK-B-PS] [MASK-I-PS] 장군은 고려시대 인물로 , 현재 [MASK-B-LC] [MASK-I-LC]4번지에 그의 동상이 있습니다. 그의 생년은 [MASK-B-DT] [MASK-I-DT]으로 알려져 있습니다.

# %%
test_text = "이순신의 전화번호는 010-3318-3994이다. 그의 주민등록번호는 000908-2133434이다."
masked_text = detect_and_mask_pii(test_text, model, tokenizer, device)
print(masked_text)
# Out:
# 이순신의 전화번호 [MASK-B-RRN] [MASK-B-PH] [MASK-I-PH]18 [MASK-I-PH]94이다. 그의 주민등록번호 [MASK-B-RRN] [MASK-I-RRN]908 - 2133434이다.

# %%
test_text = "이순신의 전화번호는 01033183994이다. 그의 주민등록번호는 000908-2133434이다."
masked_text = detect_and_mask_pii(test_text, model, tokenizer, device)
print(masked_text)
# Out:
# 이순신의 전화번호 [MASK-B-RRN] [MASK-B-PH]33183994이다. 그의 주민등록번호 [MASK-B-RRN] [MASK-I-RRN]908 - 2133434이다.

# %%
test_text = "김지민은 현재 경희대학교 근처에서 일을 하고 있으며, 의사로 일하고 있다. 그녀는 현재 이사를 고려 중이며 이사갈 곳은 서울시 동대문구 이문동 회기로이다. 그녀는 1995년 6월 29일에 태어났으며, 태어난 곳은 부산이다."
masked_text = detect_and_mask_pii(test_text, model, tokenizer, device)
print(masked_text)
# Out:
# [MASK-B-PS] [MASK-I-PS]은 현재 경희대학교 근처에서 일을 하고 있으며 , 의사로 일하고 있다. 그녀는 현재 이사를 고려 중이며 이사갈 곳은 [MASK-B-LC] [MASK-I-LC]로이다. 그녀는 [MASK-B-DT]년 [MASK-I-DT]에 태어났으며 , 태어난 곳은 부산이다.

# %%
test_text = "하진우는 지금은 부산시 금정구에 살고있는데 그의 취미는 종합격투기와 잠자기이며 그는 2000년에 태어났다."
masked_text = detect_and_mask_pii(test_text, model, tokenizer, device)
print(masked_text)
# Out:
# [MASK-B-PS] [MASK-I-PS]는 지금은 [MASK-B-LC] [MASK-I-LC]에 살고있는데 그의 취미는 종합격투기와 잠자기이며 그는 [MASK-B-DT]년에 태어났다.
