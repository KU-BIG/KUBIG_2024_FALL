# %% [markdown]
# # **KUBIG 24S NLP Basic Team 4**
#
# ## **사투리 번역기 구현**
#
# ### 19기 정종락

# %% [markdown]
# # **Import Libraries, Modules, and Dataset**

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/Othercomputers/My MacBook Pro/Colab/KUBIG/24S/NLP/Team/data/'
columns_to_load = ['standard_form', 'dialect_form']
# Out:
# Mounted at /content/drive

# %%
jl_train = pd.read_parquet(path + 'jl_train.parquet')

# %% [markdown]
# ## **Dataset**

# %%
jl_train.tail()
# Out:
#                            id    form  standard_form dialect_form  \
# 1992096  DJSX20001484.1.1.226  895.12         896.29            1
# 1992097  DJSX20001484.1.1.227  897.25         899.41            1
# 1992098  DJSX20001484.1.1.228  900.75         903.77            2
# 1992099  DJSX20001484.1.1.229  904.38         905.60            2
# 1992100  DJSX20001484.1.1.230  906.69         908.11            1
#
#                  speaker_id               start                 end note  \
# 1992096        음~ (없제)/(없지)               음~ 없지               음~ 없제
# 1992097  나는 (()) 등이 너무 뜨거워.  나는 (()) 등이 너무 뜨거워.  나는 (()) 등이 너무 뜨거워.
# 1992098             어 그래 이제             어 그래 이제             어 그래 이제
# 1992099             끝내자 @웃음      끝내자 {laughing}      끝내자 {laughing}
# 1992100             어 좋다 좋다             어 좋다 좋다             어 좋다 좋다
#
#                                                 eojeolList
# 1992096  [{'eojeol': '음~', 'id': 1, 'isDialect': False,...
# 1992097  [{'eojeol': '나는', 'id': 1, 'isDialect': False,...
# 1992098  [{'eojeol': '어', 'id': 1, 'isDialect': False, ...
# 1992099  [{'eojeol': '끝내자', 'id': 1, 'isDialect': False...
# 1992100  [{'eojeol': '어', 'id': 1, 'isDialect': False, ...

# %%
jl_train.rename(columns = {'form': 'start',
                           'speaker_id': 'form',
                           'standard_form': 'end',
                           'dialect_form': 'speaker_id',
                           'start': 'standard_form',
                           'end': 'dialect_form'},
                inplace = True)
order = ['id', 'form', 'standard_form',	'dialect_form',
         'speaker_id',	'start',	'end',	'note',	'eojeolList']
jl_train = jl_train[order]

# %%
jl_train = jl_train[columns_to_load]

# %%
jl_train.head(10)
# Out:
#                  standard_form                 dialect_form
# 0                     역사 이야기네.                     역사 이야기네.
# 1  우리 {laughing} 역사에 관심 많이 있어?  우리 {laughing} 역사에 관심 많이 있어?
# 2                       글쎄 언니.                       글쎄 언니.
# 3                       역사에 관심                       역사에 관심
# 4      관심이 있는 건 아니고 요즘에 &name&      관심이 있는 건 아니고 요즘에 &name&
# 5               인제 또 시험 기간이잖아.               인제 또 시험 기간이잖아.
# 6      그래서 지금 역사에 지금 공부하고 있거든.      그래서 지금 역사에 지금 공부하고 있거든.
# 7          근데 이번에 시험 범위가 조선이야.          근데 이번에 시험 범위가 조선이야.
# 8            근데 조선이 너무 많대 외울게.            근데 조선이 너무 많대 외울게.
# 9                그래서 너무 힘들어가지고                그래서 너무 힘들어가지고

# %%
jl_train.tail(10)
# Out:
#                                     standard_form  \
# 1992091                    근데 항상 거기에서 영감을 얻는 다니까.
# 1992092                        아따~ 영감도 받고 좋은 건물이네
# 1992093                      응~ 나 그래서 해외여행 꼭 가보려고
# 1992094               나 이 코로나 자식 꼭 이기고 해외여행 가볼께 꼭
# 1992095  코로나 언젠가 이길 수 있겠지 뭐 대한민국 사람들이 못 하는 것이 있겠냐
# 1992096                                     음~ 없지
# 1992097                        나는 (()) 등이 너무 뜨거워.
# 1992098                                   어 그래 이제
# 1992099                            끝내자 {laughing}
# 1992100                                   어 좋다 좋다
#
#                                      dialect_form
# 1992091                     근데 항상 거기에서 영감을 얻는 당께.
# 1992092                       아따~ 영감도 받고 좋은 건물이네잉
# 1992093                      응~ 나 그래서 해외여행 꼭 가보려고
# 1992094               나 이 코로나 자식 꼭 이기고 해외여행 가볼께 꼭
# 1992095  코로나 언젠가 이길 수 있겄제 뭐 대한민국 사람들이 못 하는 것이 있겄냐
# 1992096                                     음~ 없제
# 1992097                        나는 (()) 등이 너무 뜨거워.
# 1992098                                   어 그래 이제
# 1992099                            끝내자 {laughing}
# 1992100                                   어 좋다 좋다

# %%
jl_aug = pd.read_csv(path + 'jl_aug.csv',
                     usecols = columns_to_load
                     )

jl_train = pd.concat([jl_train, jl_aug], ignore_index = True)
jl_train.tail()
# Out:
#                                              standard_form  \
# 2059590               내장산 선운사 관악산 월출산 어 주로 가을에 단풍놀이를 많이 가지
# 2059591                          나는 여기 읍에서 이 도시에서 사는 거이 좋소
# 2059592  시골에 살면서 부잣집 시집 와 갖고 어찌 일이 많은가라 논밭이 많은가 어른은 일을 ...
# 2059593                       그러니까 지금은 참 대통령 세상 살고 있소 편안하니
# 2059594           그러니까 나는 이 도시가 좋아요  너무 고생해서 일을 못 해갖고 고생해서
#
#                                               dialect_form
# 2059590               내장산 선운사 관악산 월출산 어 주로 가을에 단풍놀이를 많이 가제
# 2059591                          나는 여그 읍에서 이 도시에서 사는 거이 좋소
# 2059592  시골에 삼스로 부잣집 시집 와 갖고 어찌께 일이 많은가라 논밭이 많은가 어른은 일을...
# 2059593                        그랑께 지금은 참 대통령 시상 살고 있소 편안하니
# 2059594             그랑께 나는 이 도시가 좋소야 너무 고생해서 일을 못 해갖고 고생해서

# %% [markdown]
# # **Models**

# %% [markdown]
# ## **표준어 - 전라도, KoBART - Batch Size 32, epoch 5**

# %%
jl_train_sampled = jl_train.sample(n = 100000, random_state = 42)

# %%
df = pd.DataFrame({
    'standard_form': ['아직', '아직', '아직 멀었지', '아직 멀었지', '아무렇지도 않으면서', '맞지', '맞지?', '아무렇지도', '때문에',
                      '너때문에', '살아', '너때문에 살아', '도영아 너때문에 살아', '야 허깅페이스야 너때문에 살아',
                      '야 너 뭐하냐', '지금', '야 너 지금 뭐하냐', '응', '우와', '와',
                      '학교가 일찍 끝났는데', '어서 씻어버리고', '난리를 피우더라니까', '입만 살았지', '살았지',
                      '우리 아버지', '뿌리다', '물 좀 뿌려라', '겨우', '참기름', '고소한 참기름 냄새가 나면서',
                      '먹지도 못하고 가는데', '뭐가 중요한데', '너땜에', '그래가지고', '그래가지고 되겠냐?', '그래가지고 되겠니?'],
    'dialect_form': ['당애', '당당', '당애 멀었제', '당당 멀었지', '암시랑토 않음서', '맞제', '맞제?', '암시랑토', '땜시',
                     '니땜시', '살어야', '니땜시 살어야', '도영아 니땜시 살어야', '아야 허깅페이스야 니땀시 살어야',
                     '아야 니 뭣허냐', '시방', '아야 니 시방 뭣허냐', '잉', '워메', '워메',
                     '핵교가 일찍 파했는디', '언넝 시쳐블고', '염병 사동 병을 하드랑께', '주둥이만 살았제', '살았제',
                     '울아부지', '찌끄르다', '물 좀 찌끄러라', '포도시', '참지름', '꼬순 참지름 냄시가 남서',
                     '먹지도 못허고 가는디', '뭣이 중헌디', '너땜시', '그래가꼬', '그래가꼬 되것냐?', '그래가지고 되것냐?']})

jl_train_sampled = pd.concat([jl_train_sampled, df], ignore_index = True)

# %%
jl_train_sampled
# Out:
#                                             standard_form  \
# 0                                     아니면 다 글지 뭐 잡채 아니면 뭐
# 1                  전쟁 영화예요 전쟁 영화 그~ 빅뱅에 누구 나왔다고는 최근에 알았는데
# 2                또 눈꽃 축제 같은 경우에도 겨울에만 즐길 수 있는 행사다 보니까 올해에
# 3                         다 물어뜯고 화장지는 화장지를 펼쳐가지고 난장판을 쳐놓고
# 4       그래서 요새는 이제 화순 주변에 그 무등산도 있고 어 어 안양산도 있고 뭐 백아산도...
# ...                                                   ...
# 100032                                            뭐가 중요한데
# 100033                                                너땜에
# 100034                                              그래가지고
# 100035                                         그래가지고 되겠냐?
# 100036                                         그래가지고 되겠니?
#
#                                              dialect_form
# 0                                     아니면 다 글지 뭐 잡채 아니면 뭐
# 1                  전쟁 영화예요 전쟁 영화 그~ 빅뱅에 누구 나왔다고는 최근에 알았는데
# 2                또 눈꽃 축제 같은 경우에도 겨울에만 즐길 수 있는 행사다 보니까 올해에
# 3                         다 물어뜯고 화장지는 화장지를 펼쳐가지고 난장판을 쳐놓고
# 4       그래서 요새는 이제 화순 주변에 그 무등산도 있고 어 어 안양산도 있고 뭐 백아산도...
# ...                                                   ...
# 100032                                             뭣이 중헌디
# 100033                                                너땜시
# 100034                                               그래가꼬
# 100035                                          그래가꼬 되것냐?
# 100036                                         그래가지고 되것냐?
#
# [100037 rows x 2 columns]

# %%
from transformers import PreTrainedTokenizerFast, BartForConditionalGeneration, Trainer, TrainingArguments
from torch.utils.data import Dataset, DataLoader
import torch
import pandas as pd
from sklearn.model_selection import train_test_split

# 데이터셋 로드
df = jl_train_sampled.copy()

# 필요한 전처리 (예: 결측값 제거 등)
df = df.dropna()

# 학습 및 검증 셋 분리
train_df, val_df = train_test_split(df, test_size = 0.2, random_state = 42)

tokenizer = PreTrainedTokenizerFast.from_pretrained('gogamza/kobart-base-v2')

# 토큰화 함수 정의
def tokenize_data(texts):
    return tokenizer(texts, padding = "max_length",
                     max_length = 128, truncation = True, return_tensors = "pt")

# 토큰화 수행
train_encodings = tokenize_data(train_df['standard_form'].tolist())
train_labels = tokenize_data(train_df['dialect_form'].tolist())

val_encodings = tokenize_data(val_df['standard_form'].tolist())
val_labels = tokenize_data(val_df['dialect_form'].tolist())

import torch
from torch.utils.data import Dataset, DataLoader

class TranslationDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __len__(self):
        return len(self.encodings['input_ids'])

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels['input_ids'][idx])
        return item

# 데이터셋 생성
train_dataset = TranslationDataset(train_encodings, train_labels)
val_dataset = TranslationDataset(val_encodings, val_labels)

# 데이터로더 생성
train_loader = DataLoader(train_dataset, batch_size = 32, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size = 32, shuffle = False)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
from transformers import BartForConditionalGeneration, AdamW

model = BartForConditionalGeneration.from_pretrained('gogamza/kobart-base-v2')
optimizer = AdamW(model.parameters(), lr = 2e-5)

from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

num_epochs = 5

for epoch in range(num_epochs):
    model.train()
    loop = tqdm(train_loader, leave=True)
    for batch in loop:
        # 데이터 준비
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        # 모델 예측 및 손실 계산
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss

        # 역전파 및 최적화
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 진행 상황 출력
        loop.set_description(f'Epoch {epoch + 1}')
        loop.set_postfix(loss=loss.item())

    # 검증 단계 (옵션)
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            val_loss += outputs.loss.item()

    print(f'Validation Loss: {val_loss / len(val_loader)}')

# 모델과 토크나이저 저장 경로
model_save_path = '/content/drive/Othercomputers/My MacBook Pro/Colab/KUBIG/24S/NLP/Team/model/translation_model_st_jl'
tokenizer_save_path = '/content/drive/Othercomputers/My MacBook Pro/Colab/KUBIG/24S/NLP/Team/model/translation_tokenizer_st_jl'

# 모델 저장
model.save_pretrained(model_save_path)
tokenizer.save_pretrained(tokenizer_save_path)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/2501 [00:00<?, ?it/s]<ipython-input-26-09266a795dde>:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# <ipython-input-26-09266a795dde>:43: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(self.labels['input_ids'][idx])
# Epoch 1: 100%|██████████| 2501/2501 [17:29<00:00,  2.38it/s, loss=0.0069]
# Validation Loss: 0.018826790552507466
# Epoch 2: 100%|██████████| 2501/2501 [17:29<00:00,  2.38it/s, loss=0.00944]
# Validation Loss: 0.01485524542442636
# Epoch 3: 100%|██████████| 2501/2501 [17:29<00:00,  2.38it/s, loss=0.0103]
# Validation Loss: 0.014087807918002772
# Epoch 4: 100%|██████████| 2501/2501 [17:29<00:00,  2.38it/s, loss=0.0203]
# Validation Loss: 0.0129517058217686
# Epoch 5: 100%|██████████| 2501/2501 [17:29<00:00,  2.38it/s, loss=0.00204]
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'forced_eos_token_id': 1}
# Validation Loss: 0.012922803207617491
# ('/content/drive/Othercomputers/My MacBook Pro/Colab/KUBIG/24S/NLP/Team/model/translation_tokenizer_st_jl/tokenizer_config.json',
#  '/content/drive/Othercomputers/My MacBook Pro/Colab/KUBIG/24S/NLP/Team/model/translation_tokenizer_st_jl/special_tokens_map.json',
#  '/content/drive/Othercomputers/My MacBook Pro/Colab/KUBIG/24S/NLP/Team/model/translation_tokenizer_st_jl/tokenizer.json')

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from transformers import BartForConditionalGeneration, PreTrainedTokenizerFast

model_save_path = '/content/drive/Othercomputers/My MacBook Pro/Colab/KUBIG/24S/NLP/Team/model/translation_model_st_jl'
tokenizer_save_path = '/content/drive/Othercomputers/My MacBook Pro/Colab/KUBIG/24S/NLP/Team/model/translation_tokenizer_st_jl'

model = BartForConditionalGeneration.from_pretrained(model_save_path)
tokenizer = PreTrainedTokenizerFast.from_pretrained(tokenizer_save_path)
model.to(device)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0e708b64785b> in <cell line: 8>()
#       6 model = BartForConditionalGeneration.from_pretrained(model_save_path)
#       7 tokenizer = PreTrainedTokenizerFast.from_pretrained(tokenizer_save_path)
# ----> 8 model.to(device)
#
# NameError: name 'device' is not defined

# %%
# 입력 문장
input_sentence = "와 입만 살았지 아무렇지 않으면서 난리를 피우더라니까"

# 토큰화
input_ids = tokenizer.encode(input_sentence, return_tensors = "pt").to(device)

# 모델 예측
output_ids = model.generate(input_ids, max_length = 50, num_beams = 5, early_stopping = True)

# 결과 해독
output_sentence = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(output_sentence)
# Out:
# 와 입만 살았지 아무렇지 않으면서 난리를 피우더라니까

# %%
# 입력 문장
input_sentence = "도영아 너때문에 살아"

# 토큰화
input_ids = tokenizer.encode(input_sentence, return_tensors = "pt").to(device)

# 모델 예측
output_ids = model.generate(input_ids, max_length = 50, num_beams = 5, early_stopping = True)

# 결과 해독
output_sentence = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(output_sentence)
# Out:
# 도영아 너땜시 살아

# %%
# 입력 문장
input_sentence = "그러니까 나는 이 도시가 좋아요"

# 토큰화
input_ids = tokenizer.encode(input_sentence, return_tensors = "pt").to(device)

# 모델 예측
output_ids = model.generate(input_ids, max_length = 50, num_beams = 5, early_stopping = True)

# 결과 해독
output_sentence = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(output_sentence)
# Out:
# 그러니까 나는 이 도시가 좋아요

# %%
# 입력 문장
input_sentence = "야 아직 멀었어 아무렇지도 않으면서 그래가지고 되겠어?"

# 토큰화
input_ids = tokenizer.encode(input_sentence, return_tensors = "pt").to(device)

# 모델 예측
output_ids = model.generate(input_ids, max_length = 50, num_beams = 5, early_stopping = True)

# 결과 해독
output_sentence = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(output_sentence)
# Out:
# 야 아직 멀었어 아무렇지도 않으면서 그래가지고 되겠어?

# %%
# 입력 문장
input_sentence = "그러니까 지금은 참"

# 토큰화
input_ids = tokenizer.encode(input_sentence, return_tensors = "pt").to(device)

# 모델 예측
output_ids = model.generate(input_ids, max_length = 50, num_beams = 5, early_stopping = True)

# 결과 해독
output_sentence = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(output_sentence)
# Out:
# 그러니까 지금은 참
