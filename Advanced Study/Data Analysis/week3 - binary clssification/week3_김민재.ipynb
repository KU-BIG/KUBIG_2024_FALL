# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.5.0)

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

# %%
NFOLDS = 3
SEED = 0
NROWS = None

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/home_credit/application_train.csv')
test = pd.read_csv('/content/drive/MyDrive/home_credit/application_test.csv')
prev = pd.read_csv('/content/drive/MyDrive/home_credit/previous_application.csv')

# %%
categorical_feats = [
    f for f in data.columns if data[f].dtype == 'object'
]

for f_ in categorical_feats:
  data[f_], indexer = pd.factorize(data[f_])
  test[f_] = indexer.get_indexer(test[f_])

gc.enable()

y_train = data['TARGET']
del data['TARGET']

# %%
prev_cat_features = [
    f_ for f_ in prev.columns if prev[f_].dtype == 'object'
]
for f_ in prev_cat_features:
  prev[f_], _ = pd.factorize(prev[f_])

avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

x_train = data.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')
x_test = test.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')

x_train = x_train.fillna(0)
x_test = x_test.fillna(0)

ntrain = x_train.shape[0]
ntest = x_test.shape[0]

excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

kf = KFold(n_splits= NFOLDS, shuffle=True, random_state=SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed = 0, params = None):
      params['random_state'] = seed
      self.clf = clf(**params)

    def train(self, x_train, y_train):
      self.clf.fit(x_train, y_train)

    def predict(self, x):
      return self.clf.predict_proba(x)[:,1]

# %%
class CatboostWrapper(object):
    def __init__(self, clf, seed = 0, params = None):
      params['random_seed'] = seed
      self.clf = clf(**params)

    def train(self, x_train, y_train):
      self.clf.fit(x_train, y_train)

    def predict(self, x):
      return self.clf.predict_proba(x)[:,1]

# %%
class LightGBMWrapper(object):
    def __init__(self, clf, seed = 0, params = None):
        params['bagging_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

# %%
class XgbWrapper(object):
    def __init__(self, seed = 0, params = None):
      self.param = params
      self.param['seed'] = seed
      self.nrounds = params.pop('nrounds', 250)

    def train(self, x_train, y_train):
      dtrain = xgb.DMatrix(x_train, label=y_train)
      self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))

# %%
def get_oof(clf):
  oof_train = np.zeros((ntrain,))
  oof_test = np.zeros((ntest,))
  oof_test_skf = np.empty((NFOLDS, ntest))

  for i, (train_index, test_index) in enumerate(kf.split(x_train)):
    x_tr = x_train.loc[train_index]
    y_tr = y_train.loc[train_index]
    x_te = x_train.loc[test_index]

    clf.train(x_tr, y_tr)

    oof_train[test_index] = clf.predict(x_te)
    oof_test_skf[i, :] = clf.predict(x_test)

  oof_test[:] = oof_test_skf.mean(axis=0)
  return oof_train.reshape(-1,1), oof_test.reshape(-1,1)

# %%
et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators':200,
    'learning_rate':0.1,
    'num_leaves':123,
    'colsample_bytree':0.8,
    'subsample':0.9,
    'max_depth':15,
    'reg_alpha':0.1,
    'reg_lambda':0.1,
    'min_split_gain':0.01,
    'min_child_weight':2
}

# %%
xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf= CatBoostClassifier, seed = SEED, params=catboost_params)
lg = LightGBMWrapper(clf = LGBMClassifier, seed = SEED, params = lightgbm_params)

# %%
xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [01:03:08] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [01:03:35] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [01:04:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
cb_oof_train, cb_oof_test = get_oof(cb)
# Out:
# 0:	total: 165ms	remaining: 32.9s
# 1:	total: 247ms	remaining: 24.4s
# 2:	total: 316ms	remaining: 20.8s
# 3:	total: 401ms	remaining: 19.6s
# 4:	total: 484ms	remaining: 18.9s
# 5:	total: 561ms	remaining: 18.1s
# 6:	total: 642ms	remaining: 17.7s
# 7:	total: 714ms	remaining: 17.1s
# 8:	total: 796ms	remaining: 16.9s
# 9:	total: 880ms	remaining: 16.7s
# 10:	total: 958ms	remaining: 16.5s
# 11:	total: 1.05s	remaining: 16.5s
# 12:	total: 1.17s	remaining: 16.9s
# 13:	total: 1.26s	remaining: 16.7s
# 14:	total: 1.4s	remaining: 17.3s
# 15:	total: 1.47s	remaining: 17s
# 16:	total: 1.54s	remaining: 16.6s
# 17:	total: 1.62s	remaining: 16.4s
# 18:	total: 1.69s	remaining: 16.1s
# 19:	total: 1.76s	remaining: 15.8s
# 20:	total: 1.84s	remaining: 15.7s
# 21:	total: 1.91s	remaining: 15.5s
# 22:	total: 2s	remaining: 15.4s
# 23:	total: 2.1s	remaining: 15.4s
# 24:	total: 2.18s	remaining: 15.2s
# 25:	total: 2.27s	remaining: 15.2s
# 26:	total: 2.35s	remaining: 15.1s
# 27:	total: 2.43s	remaining: 14.9s
# 28:	total: 2.5s	remaining: 14.7s
# 29:	total: 2.58s	remaining: 14.6s
# 30:	total: 2.67s	remaining: 14.5s
# 31:	total: 2.75s	remaining: 14.5s
# 32:	total: 2.84s	remaining: 14.4s
# 33:	total: 2.91s	remaining: 14.2s
# 34:	total: 2.98s	remaining: 14s
# 35:	total: 3.07s	remaining: 14s
# 36:	total: 3.14s	remaining: 13.9s
# 37:	total: 3.24s	remaining: 13.8s
# 38:	total: 3.32s	remaining: 13.7s
# 39:	total: 3.4s	remaining: 13.6s
# 40:	total: 3.48s	remaining: 13.5s
# 41:	total: 3.55s	remaining: 13.4s
# 42:	total: 3.63s	remaining: 13.2s
# 43:	total: 3.72s	remaining: 13.2s
# 44:	total: 3.79s	remaining: 13.1s
# 45:	total: 3.87s	remaining: 12.9s
# 46:	total: 3.94s	remaining: 12.8s
# 47:	total: 4.03s	remaining: 12.8s
# 48:	total: 4.11s	remaining: 12.7s
# 49:	total: 4.18s	remaining: 12.5s
# 50:	total: 4.29s	remaining: 12.5s
# 51:	total: 4.36s	remaining: 12.4s
# 52:	total: 4.43s	remaining: 12.3s
# 53:	total: 4.52s	remaining: 12.2s
# 54:	total: 4.6s	remaining: 12.1s
# 55:	total: 4.68s	remaining: 12s
# 56:	total: 4.76s	remaining: 12s
# 57:	total: 4.83s	remaining: 11.8s
# 58:	total: 4.91s	remaining: 11.7s
# 59:	total: 4.99s	remaining: 11.7s
# 60:	total: 5.08s	remaining: 11.6s
# 61:	total: 5.17s	remaining: 11.5s
# 62:	total: 5.24s	remaining: 11.4s
# 63:	total: 5.34s	remaining: 11.3s
# 64:	total: 5.41s	remaining: 11.2s
# 65:	total: 5.48s	remaining: 11.1s
# 66:	total: 5.55s	remaining: 11s
# 67:	total: 5.63s	remaining: 10.9s
# 68:	total: 5.71s	remaining: 10.8s
# 69:	total: 5.79s	remaining: 10.7s
# 70:	total: 5.86s	remaining: 10.6s
# 71:	total: 5.94s	remaining: 10.6s
# 72:	total: 6.01s	remaining: 10.5s
# 73:	total: 6.1s	remaining: 10.4s
# 74:	total: 6.19s	remaining: 10.3s
# 75:	total: 6.26s	remaining: 10.2s
# 76:	total: 6.39s	remaining: 10.2s
# 77:	total: 6.52s	remaining: 10.2s
# 78:	total: 6.68s	remaining: 10.2s
# 79:	total: 6.81s	remaining: 10.2s
# 80:	total: 7s	remaining: 10.3s
# 81:	total: 7.15s	remaining: 10.3s
# 82:	total: 7.29s	remaining: 10.3s
# 83:	total: 7.47s	remaining: 10.3s
# 84:	total: 7.6s	remaining: 10.3s
# 85:	total: 7.75s	remaining: 10.3s
# 86:	total: 7.91s	remaining: 10.3s
# 87:	total: 8.08s	remaining: 10.3s
# 88:	total: 8.21s	remaining: 10.2s
# 89:	total: 8.36s	remaining: 10.2s
# 90:	total: 8.49s	remaining: 10.2s
# 91:	total: 8.66s	remaining: 10.2s
# 92:	total: 8.82s	remaining: 10.1s
# 93:	total: 8.95s	remaining: 10.1s
# 94:	total: 9.1s	remaining: 10.1s
# 95:	total: 9.24s	remaining: 10s
# 96:	total: 9.54s	remaining: 10.1s
# 97:	total: 9.98s	remaining: 10.4s
# 98:	total: 10.4s	remaining: 10.7s
# 99:	total: 10.6s	remaining: 10.6s
# 100:	total: 10.8s	remaining: 10.6s
# 101:	total: 11s	remaining: 10.5s
# 102:	total: 11.1s	remaining: 10.5s
# 103:	total: 11.3s	remaining: 10.4s
# 104:	total: 11.4s	remaining: 10.3s
# 105:	total: 11.6s	remaining: 10.3s
# 106:	total: 11.7s	remaining: 10.2s
# 107:	total: 11.9s	remaining: 10.1s
# 108:	total: 12s	remaining: 10s
# 109:	total: 12.1s	remaining: 9.93s
# 110:	total: 12.3s	remaining: 9.83s
# 111:	total: 12.3s	remaining: 9.69s
# 112:	total: 12.4s	remaining: 9.56s
# 113:	total: 12.5s	remaining: 9.42s
# 114:	total: 12.5s	remaining: 9.28s
# 115:	total: 12.6s	remaining: 9.14s
# 116:	total: 12.7s	remaining: 9.01s
# 117:	total: 12.8s	remaining: 8.88s
# 118:	total: 12.9s	remaining: 8.76s
# 119:	total: 12.9s	remaining: 8.62s
# 120:	total: 13s	remaining: 8.51s
# 121:	total: 13.1s	remaining: 8.38s
# 122:	total: 13.2s	remaining: 8.25s
# 123:	total: 13.3s	remaining: 8.12s
# 124:	total: 13.3s	remaining: 8s
# 125:	total: 13.4s	remaining: 7.88s
# 126:	total: 13.5s	remaining: 7.75s
# 127:	total: 13.6s	remaining: 7.63s
# 128:	total: 13.6s	remaining: 7.51s
# 129:	total: 13.7s	remaining: 7.38s
# 130:	total: 13.8s	remaining: 7.28s
# 131:	total: 13.9s	remaining: 7.16s
# 132:	total: 14s	remaining: 7.04s
# 133:	total: 14.1s	remaining: 6.92s
# 134:	total: 14.1s	remaining: 6.8s
# 135:	total: 14.2s	remaining: 6.68s
# 136:	total: 14.3s	remaining: 6.57s
# 137:	total: 14.3s	remaining: 6.44s
# 138:	total: 14.4s	remaining: 6.33s
# 139:	total: 14.5s	remaining: 6.22s
# 140:	total: 14.6s	remaining: 6.1s
# 141:	total: 14.6s	remaining: 5.98s
# 142:	total: 14.7s	remaining: 5.87s
# 143:	total: 14.8s	remaining: 5.75s
# 144:	total: 14.9s	remaining: 5.64s
# 145:	total: 15s	remaining: 5.53s
# 146:	total: 15s	remaining: 5.42s
# 147:	total: 15.1s	remaining: 5.31s
# 148:	total: 15.2s	remaining: 5.2s
# 149:	total: 15.3s	remaining: 5.09s
# 150:	total: 15.3s	remaining: 4.98s
# 151:	total: 15.4s	remaining: 4.87s
# 152:	total: 15.5s	remaining: 4.76s
# 153:	total: 15.6s	remaining: 4.65s
# 154:	total: 15.6s	remaining: 4.54s
# 155:	total: 15.7s	remaining: 4.43s
# 156:	total: 15.8s	remaining: 4.32s
# 157:	total: 15.9s	remaining: 4.22s
# 158:	total: 16s	remaining: 4.12s
# 159:	total: 16s	remaining: 4.01s
# 160:	total: 16.1s	remaining: 3.91s
# 161:	total: 16.2s	remaining: 3.8s
# 162:	total: 16.3s	remaining: 3.7s
# 163:	total: 16.4s	remaining: 3.59s
# 164:	total: 16.4s	remaining: 3.49s
# 165:	total: 16.5s	remaining: 3.38s
# 166:	total: 16.6s	remaining: 3.28s
# 167:	total: 16.7s	remaining: 3.18s
# 168:	total: 16.8s	remaining: 3.08s
# 169:	total: 16.9s	remaining: 2.97s
# 170:	total: 17s	remaining: 2.88s
# 171:	total: 17s	remaining: 2.77s
# 172:	total: 17.1s	remaining: 2.67s
# 173:	total: 17.2s	remaining: 2.57s
# 174:	total: 17.3s	remaining: 2.47s
# 175:	total: 17.3s	remaining: 2.37s
# 176:	total: 17.4s	remaining: 2.26s
# 177:	total: 17.5s	remaining: 2.16s
# 178:	total: 17.6s	remaining: 2.06s
# 179:	total: 17.6s	remaining: 1.96s
# 180:	total: 17.7s	remaining: 1.86s
# 181:	total: 17.8s	remaining: 1.76s
# 182:	total: 17.9s	remaining: 1.66s
# 183:	total: 18s	remaining: 1.56s
# 184:	total: 18.1s	remaining: 1.47s
# 185:	total: 18.1s	remaining: 1.36s
# 186:	total: 18.2s	remaining: 1.27s
# 187:	total: 18.3s	remaining: 1.17s
# 188:	total: 18.4s	remaining: 1.07s
# 189:	total: 18.4s	remaining: 970ms
# 190:	total: 18.5s	remaining: 872ms
# 191:	total: 18.6s	remaining: 774ms
# 192:	total: 18.6s	remaining: 676ms
# 193:	total: 18.7s	remaining: 579ms
# 194:	total: 18.8s	remaining: 482ms
# 195:	total: 18.9s	remaining: 385ms
# 196:	total: 18.9s	remaining: 288ms
# 197:	total: 19s	remaining: 192ms
# 198:	total: 19.1s	remaining: 96ms
# 199:	total: 19.2s	remaining: 0us
# 0:	total: 94.2ms	remaining: 18.7s
# 1:	total: 188ms	remaining: 18.6s
# 2:	total: 327ms	remaining: 21.5s
# 3:	total: 473ms	remaining: 23.2s
# 4:	total: 628ms	remaining: 24.5s
# 5:	total: 781ms	remaining: 25.2s
# 6:	total: 940ms	remaining: 25.9s
# 7:	total: 1.07s	remaining: 25.6s
# 8:	total: 1.22s	remaining: 25.9s
# 9:	total: 1.39s	remaining: 26.4s
# 10:	total: 1.55s	remaining: 26.6s
# 11:	total: 1.71s	remaining: 26.8s
# 12:	total: 1.87s	remaining: 26.9s
# 13:	total: 2.02s	remaining: 26.9s
# 14:	total: 2.18s	remaining: 26.9s
# 15:	total: 2.32s	remaining: 26.7s
# 16:	total: 2.46s	remaining: 26.5s
# 17:	total: 2.59s	remaining: 26.2s
# 18:	total: 2.73s	remaining: 26s
# 19:	total: 2.86s	remaining: 25.7s
# 20:	total: 3.04s	remaining: 25.9s
# 21:	total: 3.19s	remaining: 25.8s
# 22:	total: 3.35s	remaining: 25.8s
# 23:	total: 3.48s	remaining: 25.5s
# 24:	total: 3.64s	remaining: 25.5s
# 25:	total: 3.77s	remaining: 25.3s
# 26:	total: 3.95s	remaining: 25.3s
# 27:	total: 4.07s	remaining: 25s
# 28:	total: 4.25s	remaining: 25.1s
# 29:	total: 4.41s	remaining: 25s
# 30:	total: 4.57s	remaining: 24.9s
# 31:	total: 4.71s	remaining: 24.7s
# 32:	total: 4.88s	remaining: 24.7s
# 33:	total: 5.02s	remaining: 24.5s
# 34:	total: 5.17s	remaining: 24.4s
# 35:	total: 5.32s	remaining: 24.3s
# 36:	total: 5.48s	remaining: 24.2s
# 37:	total: 5.64s	remaining: 24s
# 38:	total: 5.79s	remaining: 23.9s
# 39:	total: 5.86s	remaining: 23.5s
# 40:	total: 5.95s	remaining: 23.1s
# 41:	total: 6.03s	remaining: 22.7s
# 42:	total: 6.12s	remaining: 22.3s
# 43:	total: 6.2s	remaining: 22s
# 44:	total: 6.29s	remaining: 21.7s
# 45:	total: 6.37s	remaining: 21.3s
# 46:	total: 6.45s	remaining: 21s
# 47:	total: 6.56s	remaining: 20.8s
# 48:	total: 6.64s	remaining: 20.5s
# 49:	total: 6.72s	remaining: 20.2s
# 50:	total: 6.8s	remaining: 19.9s
# 51:	total: 6.87s	remaining: 19.6s
# 52:	total: 6.96s	remaining: 19.3s
# 53:	total: 7.04s	remaining: 19.1s
# 54:	total: 7.12s	remaining: 18.8s
# 55:	total: 7.19s	remaining: 18.5s
# 56:	total: 7.28s	remaining: 18.3s
# 57:	total: 7.35s	remaining: 18s
# 58:	total: 7.43s	remaining: 17.7s
# 59:	total: 7.5s	remaining: 17.5s
# 60:	total: 7.59s	remaining: 17.3s
# 61:	total: 7.66s	remaining: 17.1s
# 62:	total: 7.75s	remaining: 16.8s
# 63:	total: 7.83s	remaining: 16.6s
# 64:	total: 7.91s	remaining: 16.4s
# 65:	total: 8.01s	remaining: 16.3s
# 66:	total: 8.08s	remaining: 16s
# 67:	total: 8.15s	remaining: 15.8s
# 68:	total: 8.24s	remaining: 15.6s
# 69:	total: 8.31s	remaining: 15.4s
# 70:	total: 8.38s	remaining: 15.2s
# 71:	total: 8.47s	remaining: 15.1s
# 72:	total: 8.54s	remaining: 14.9s
# 73:	total: 8.63s	remaining: 14.7s
# 74:	total: 8.72s	remaining: 14.5s
# 75:	total: 8.8s	remaining: 14.4s
# 76:	total: 8.88s	remaining: 14.2s
# 77:	total: 8.98s	remaining: 14s
# 78:	total: 9.05s	remaining: 13.9s
# 79:	total: 9.14s	remaining: 13.7s
# 80:	total: 9.23s	remaining: 13.6s
# 81:	total: 9.34s	remaining: 13.4s
# 82:	total: 9.44s	remaining: 13.3s
# 83:	total: 9.53s	remaining: 13.2s
# 84:	total: 9.62s	remaining: 13s
# 85:	total: 9.71s	remaining: 12.9s
# 86:	total: 9.79s	remaining: 12.7s
# 87:	total: 9.89s	remaining: 12.6s
# 88:	total: 10s	remaining: 12.5s
# 89:	total: 10.1s	remaining: 12.3s
# 90:	total: 10.1s	remaining: 12.1s
# 91:	total: 10.2s	remaining: 12s
# 92:	total: 10.3s	remaining: 11.8s
# 93:	total: 10.4s	remaining: 11.7s
# 94:	total: 10.4s	remaining: 11.5s
# 95:	total: 10.5s	remaining: 11.4s
# 96:	total: 10.6s	remaining: 11.2s
# 97:	total: 10.7s	remaining: 11.1s
# 98:	total: 10.7s	remaining: 11s
# 99:	total: 10.8s	remaining: 10.8s
# 100:	total: 10.9s	remaining: 10.7s
# 101:	total: 11s	remaining: 10.5s
# 102:	total: 11s	remaining: 10.4s
# 103:	total: 11.1s	remaining: 10.3s
# 104:	total: 11.2s	remaining: 10.1s
# 105:	total: 11.3s	remaining: 10s
# 106:	total: 11.3s	remaining: 9.87s
# 107:	total: 11.4s	remaining: 9.73s
# 108:	total: 11.5s	remaining: 9.61s
# 109:	total: 11.6s	remaining: 9.47s
# 110:	total: 11.7s	remaining: 9.35s
# 111:	total: 11.7s	remaining: 9.22s
# 112:	total: 11.8s	remaining: 9.09s
# 113:	total: 11.9s	remaining: 8.96s
# 114:	total: 12s	remaining: 8.84s
# 115:	total: 12s	remaining: 8.71s
# 116:	total: 12.1s	remaining: 8.59s
# 117:	total: 12.2s	remaining: 8.46s
# 118:	total: 12.2s	remaining: 8.33s
# 119:	total: 12.3s	remaining: 8.22s
# 120:	total: 12.4s	remaining: 8.1s
# 121:	total: 12.5s	remaining: 7.98s
# 122:	total: 12.6s	remaining: 7.86s
# 123:	total: 12.6s	remaining: 7.74s
# 124:	total: 12.7s	remaining: 7.63s
# 125:	total: 12.8s	remaining: 7.52s
# 126:	total: 12.9s	remaining: 7.4s
# 127:	total: 13s	remaining: 7.29s
# 128:	total: 13s	remaining: 7.17s
# 129:	total: 13.1s	remaining: 7.06s
# 130:	total: 13.2s	remaining: 6.95s
# 131:	total: 13.3s	remaining: 6.83s
# 132:	total: 13.3s	remaining: 6.72s
# 133:	total: 13.4s	remaining: 6.61s
# 134:	total: 13.5s	remaining: 6.5s
# 135:	total: 13.6s	remaining: 6.38s
# 136:	total: 13.6s	remaining: 6.27s
# 137:	total: 13.7s	remaining: 6.16s
# 138:	total: 13.8s	remaining: 6.06s
# 139:	total: 13.9s	remaining: 5.95s
# 140:	total: 14s	remaining: 5.84s
# 141:	total: 14s	remaining: 5.73s
# 142:	total: 14.1s	remaining: 5.62s
# 143:	total: 14.2s	remaining: 5.51s
# 144:	total: 14.3s	remaining: 5.41s
# 145:	total: 14.3s	remaining: 5.3s
# 146:	total: 14.4s	remaining: 5.19s
# 147:	total: 14.5s	remaining: 5.08s
# 148:	total: 14.5s	remaining: 4.97s
# 149:	total: 14.6s	remaining: 4.87s
# 150:	total: 14.7s	remaining: 4.77s
# 151:	total: 14.8s	remaining: 4.66s
# 152:	total: 14.8s	remaining: 4.56s
# 153:	total: 14.9s	remaining: 4.46s
# 154:	total: 15s	remaining: 4.35s
# 155:	total: 15.1s	remaining: 4.25s
# 156:	total: 15.1s	remaining: 4.15s
# 157:	total: 15.2s	remaining: 4.04s
# 158:	total: 15.3s	remaining: 3.94s
# 159:	total: 15.4s	remaining: 3.84s
# 160:	total: 15.4s	remaining: 3.74s
# 161:	total: 15.5s	remaining: 3.64s
# 162:	total: 15.6s	remaining: 3.54s
# 163:	total: 15.7s	remaining: 3.44s
# 164:	total: 15.7s	remaining: 3.34s
# 165:	total: 15.9s	remaining: 3.25s
# 166:	total: 16s	remaining: 3.16s
# 167:	total: 16.1s	remaining: 3.06s
# 168:	total: 16.3s	remaining: 2.98s
# 169:	total: 16.4s	remaining: 2.9s
# 170:	total: 16.6s	remaining: 2.81s
# 171:	total: 16.7s	remaining: 2.72s
# 172:	total: 16.9s	remaining: 2.64s
# 173:	total: 17s	remaining: 2.55s
# 174:	total: 17.2s	remaining: 2.46s
# 175:	total: 17.4s	remaining: 2.37s
# 176:	total: 17.5s	remaining: 2.27s
# 177:	total: 17.7s	remaining: 2.18s
# 178:	total: 17.8s	remaining: 2.09s
# 179:	total: 18s	remaining: 2s
# 180:	total: 18.1s	remaining: 1.9s
# 181:	total: 18.3s	remaining: 1.8s
# 182:	total: 18.4s	remaining: 1.71s
# 183:	total: 18.5s	remaining: 1.61s
# 184:	total: 18.7s	remaining: 1.51s
# 185:	total: 18.8s	remaining: 1.42s
# 186:	total: 19s	remaining: 1.32s
# 187:	total: 19.1s	remaining: 1.22s
# 188:	total: 19.3s	remaining: 1.12s
# 189:	total: 19.4s	remaining: 1.02s
# 190:	total: 19.5s	remaining: 921ms
# 191:	total: 19.7s	remaining: 820ms
# 192:	total: 19.8s	remaining: 719ms
# 193:	total: 20s	remaining: 617ms
# 194:	total: 20.1s	remaining: 516ms
# 195:	total: 20.2s	remaining: 413ms
# 196:	total: 20.4s	remaining: 310ms
# 197:	total: 20.5s	remaining: 207ms
# 198:	total: 20.7s	remaining: 104ms
# 199:	total: 20.8s	remaining: 0us
# 0:	total: 80.9ms	remaining: 16.1s
# 1:	total: 149ms	remaining: 14.7s
# 2:	total: 219ms	remaining: 14.4s
# 3:	total: 301ms	remaining: 14.8s
# 4:	total: 384ms	remaining: 15s
# 5:	total: 454ms	remaining: 14.7s
# 6:	total: 525ms	remaining: 14.5s
# 7:	total: 601ms	remaining: 14.4s
# 8:	total: 686ms	remaining: 14.5s
# 9:	total: 761ms	remaining: 14.5s
# 10:	total: 833ms	remaining: 14.3s
# 11:	total: 906ms	remaining: 14.2s
# 12:	total: 983ms	remaining: 14.1s
# 13:	total: 1.07s	remaining: 14.2s
# 14:	total: 1.15s	remaining: 14.2s
# 15:	total: 1.24s	remaining: 14.3s
# 16:	total: 1.31s	remaining: 14.1s
# 17:	total: 1.4s	remaining: 14.2s
# 18:	total: 1.47s	remaining: 14s
# 19:	total: 1.55s	remaining: 14s
# 20:	total: 1.63s	remaining: 13.9s
# 21:	total: 1.71s	remaining: 13.9s
# 22:	total: 1.79s	remaining: 13.8s
# 23:	total: 1.87s	remaining: 13.7s
# 24:	total: 1.94s	remaining: 13.6s
# 25:	total: 2.01s	remaining: 13.4s
# 26:	total: 2.08s	remaining: 13.3s
# 27:	total: 2.16s	remaining: 13.3s
# 28:	total: 2.23s	remaining: 13.1s
# 29:	total: 2.29s	remaining: 13s
# 30:	total: 2.36s	remaining: 12.9s
# 31:	total: 2.44s	remaining: 12.8s
# 32:	total: 2.5s	remaining: 12.6s
# 33:	total: 2.56s	remaining: 12.5s
# 34:	total: 2.63s	remaining: 12.4s
# 35:	total: 2.73s	remaining: 12.4s
# 36:	total: 2.8s	remaining: 12.3s
# 37:	total: 2.87s	remaining: 12.2s
# 38:	total: 2.93s	remaining: 12.1s
# 39:	total: 3.01s	remaining: 12s
# 40:	total: 3.09s	remaining: 12s
# 41:	total: 3.19s	remaining: 12s
# 42:	total: 3.27s	remaining: 11.9s
# 43:	total: 3.35s	remaining: 11.9s
# 44:	total: 3.44s	remaining: 11.8s
# 45:	total: 3.51s	remaining: 11.7s
# 46:	total: 3.59s	remaining: 11.7s
# 47:	total: 3.68s	remaining: 11.7s
# 48:	total: 3.77s	remaining: 11.6s
# 49:	total: 3.85s	remaining: 11.5s
# 50:	total: 3.92s	remaining: 11.5s
# 51:	total: 4s	remaining: 11.4s
# 52:	total: 4.06s	remaining: 11.3s
# 53:	total: 4.15s	remaining: 11.2s
# 54:	total: 4.24s	remaining: 11.2s
# 55:	total: 4.32s	remaining: 11.1s
# 56:	total: 4.4s	remaining: 11s
# 57:	total: 4.46s	remaining: 10.9s
# 58:	total: 4.55s	remaining: 10.9s
# 59:	total: 4.62s	remaining: 10.8s
# 60:	total: 4.7s	remaining: 10.7s
# 61:	total: 4.79s	remaining: 10.7s
# 62:	total: 4.87s	remaining: 10.6s
# 63:	total: 4.94s	remaining: 10.5s
# 64:	total: 5.01s	remaining: 10.4s
# 65:	total: 5.08s	remaining: 10.3s
# 66:	total: 5.15s	remaining: 10.2s
# 67:	total: 5.22s	remaining: 10.1s
# 68:	total: 5.29s	remaining: 10.1s
# 69:	total: 5.38s	remaining: 9.99s
# 70:	total: 5.46s	remaining: 9.92s
# 71:	total: 5.54s	remaining: 9.85s
# 72:	total: 5.61s	remaining: 9.75s
# 73:	total: 5.68s	remaining: 9.67s
# 74:	total: 5.75s	remaining: 9.59s
# 75:	total: 5.84s	remaining: 9.53s
# 76:	total: 5.92s	remaining: 9.45s
# 77:	total: 6s	remaining: 9.38s
# 78:	total: 6.07s	remaining: 9.29s
# 79:	total: 6.13s	remaining: 9.2s
# 80:	total: 6.23s	remaining: 9.15s
# 81:	total: 6.3s	remaining: 9.06s
# 82:	total: 6.37s	remaining: 8.98s
# 83:	total: 6.46s	remaining: 8.92s
# 84:	total: 6.53s	remaining: 8.83s
# 85:	total: 6.61s	remaining: 8.76s
# 86:	total: 6.67s	remaining: 8.67s
# 87:	total: 6.75s	remaining: 8.59s
# 88:	total: 6.83s	remaining: 8.52s
# 89:	total: 6.94s	remaining: 8.48s
# 90:	total: 7s	remaining: 8.39s
# 91:	total: 7.08s	remaining: 8.32s
# 92:	total: 7.17s	remaining: 8.25s
# 93:	total: 7.24s	remaining: 8.17s
# 94:	total: 7.34s	remaining: 8.12s
# 95:	total: 7.46s	remaining: 8.09s
# 96:	total: 7.59s	remaining: 8.06s
# 97:	total: 7.73s	remaining: 8.05s
# 98:	total: 7.86s	remaining: 8.01s
# 99:	total: 8.02s	remaining: 8.02s
# 100:	total: 8.16s	remaining: 8s
# 101:	total: 8.31s	remaining: 7.99s
# 102:	total: 8.45s	remaining: 7.96s
# 103:	total: 8.59s	remaining: 7.92s
# 104:	total: 8.72s	remaining: 7.89s
# 105:	total: 8.87s	remaining: 7.87s
# 106:	total: 9.02s	remaining: 7.84s
# 107:	total: 9.16s	remaining: 7.8s
# 108:	total: 9.31s	remaining: 7.77s
# 109:	total: 9.45s	remaining: 7.73s
# 110:	total: 9.58s	remaining: 7.68s
# 111:	total: 9.72s	remaining: 7.64s
# 112:	total: 9.87s	remaining: 7.59s
# 113:	total: 10s	remaining: 7.55s
# 114:	total: 10.2s	remaining: 7.51s
# 115:	total: 10.3s	remaining: 7.44s
# 116:	total: 10.4s	remaining: 7.39s
# 117:	total: 10.6s	remaining: 7.34s
# 118:	total: 10.7s	remaining: 7.29s
# 119:	total: 10.9s	remaining: 7.25s
# 120:	total: 11s	remaining: 7.19s
# 121:	total: 11.2s	remaining: 7.15s
# 122:	total: 11.3s	remaining: 7.09s
# 123:	total: 11.4s	remaining: 7.01s
# 124:	total: 11.6s	remaining: 6.95s
# 125:	total: 11.7s	remaining: 6.9s
# 126:	total: 11.9s	remaining: 6.83s
# 127:	total: 12s	remaining: 6.76s
# 128:	total: 12.2s	remaining: 6.69s
# 129:	total: 12.3s	remaining: 6.62s
# 130:	total: 12.5s	remaining: 6.56s
# 131:	total: 12.6s	remaining: 6.5s
# 132:	total: 12.7s	remaining: 6.42s
# 133:	total: 12.9s	remaining: 6.35s
# 134:	total: 13s	remaining: 6.24s
# 135:	total: 13s	remaining: 6.13s
# 136:	total: 13.1s	remaining: 6.03s
# 137:	total: 13.2s	remaining: 5.92s
# 138:	total: 13.3s	remaining: 5.83s
# 139:	total: 13.4s	remaining: 5.73s
# 140:	total: 13.4s	remaining: 5.62s
# 141:	total: 13.5s	remaining: 5.52s
# 142:	total: 13.6s	remaining: 5.42s
# 143:	total: 13.7s	remaining: 5.32s
# 144:	total: 13.7s	remaining: 5.21s
# 145:	total: 13.8s	remaining: 5.11s
# 146:	total: 13.9s	remaining: 5.01s
# 147:	total: 14s	remaining: 4.91s
# 148:	total: 14s	remaining: 4.81s
# 149:	total: 14.1s	remaining: 4.7s
# 150:	total: 14.2s	remaining: 4.61s
# 151:	total: 14.3s	remaining: 4.51s
# 152:	total: 14.4s	remaining: 4.41s
# 153:	total: 14.4s	remaining: 4.31s
# 154:	total: 14.5s	remaining: 4.21s
# 155:	total: 14.6s	remaining: 4.12s
# 156:	total: 14.7s	remaining: 4.01s
# 157:	total: 14.7s	remaining: 3.92s
# 158:	total: 14.8s	remaining: 3.82s
# 159:	total: 14.9s	remaining: 3.72s
# 160:	total: 15s	remaining: 3.63s
# 161:	total: 15s	remaining: 3.53s
# 162:	total: 15.1s	remaining: 3.43s
# 163:	total: 15.2s	remaining: 3.33s
# 164:	total: 15.3s	remaining: 3.24s
# 165:	total: 15.4s	remaining: 3.15s
# 166:	total: 15.5s	remaining: 3.06s
# 167:	total: 15.5s	remaining: 2.96s
# 168:	total: 15.6s	remaining: 2.86s
# 169:	total: 15.7s	remaining: 2.78s
# 170:	total: 15.8s	remaining: 2.68s
# 171:	total: 15.9s	remaining: 2.59s
# 172:	total: 16s	remaining: 2.49s
# 173:	total: 16.1s	remaining: 2.4s
# 174:	total: 16.2s	remaining: 2.31s
# 175:	total: 16.2s	remaining: 2.21s
# 176:	total: 16.3s	remaining: 2.12s
# 177:	total: 16.4s	remaining: 2.03s
# 178:	total: 16.5s	remaining: 1.93s
# 179:	total: 16.6s	remaining: 1.84s
# 180:	total: 16.6s	remaining: 1.75s
# 181:	total: 16.7s	remaining: 1.65s
# 182:	total: 16.8s	remaining: 1.56s
# 183:	total: 16.9s	remaining: 1.47s
# 184:	total: 17s	remaining: 1.38s
# 185:	total: 17s	remaining: 1.28s
# 186:	total: 17.1s	remaining: 1.19s
# 187:	total: 17.2s	remaining: 1.1s
# 188:	total: 17.3s	remaining: 1.01s
# 189:	total: 17.4s	remaining: 916ms
# 190:	total: 17.5s	remaining: 824ms
# 191:	total: 17.6s	remaining: 731ms
# 192:	total: 17.6s	remaining: 639ms
# 193:	total: 17.7s	remaining: 547ms
# 194:	total: 17.8s	remaining: 455ms
# 195:	total: 17.8s	remaining: 364ms
# 196:	total: 17.9s	remaining: 273ms
# 197:	total: 18s	remaining: 182ms
# 198:	total: 18.1s	remaining: 90.7ms
# 199:	total: 18.1s	remaining: 0us

# %%
print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("CB-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))
# Out:
# XG-CV: 0.2597362771878248
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629856213006646
# CB-CV: 0.3309547098229581

# %%
x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)

print("{},{}".format(x_train.shape, x_test.shape))
# Out:
# (307511, 4),(48744, 4)

# %%
logistic_regression = LogisticRegression()
logistic_regression.fit(x_train, y_train)

test['TARGET'] = logistic_regression.predict_proba(x_test)[:, 1]

test[['SK_ID_CURR', 'TARGET']].to_csv('first_submission.csv', index=False, float_format='%.8f')
