# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.7 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
pip install dask[dataframe]
# Out:
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.10/dist-packages (2024.7.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (24.1)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (8.5.0)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (2.1.4)
# Collecting dask-expr<1.2,>=1.1 (from dask[dataframe])
#   Downloading dask_expr-1.1.14-py3-none-any.whl.metadata (2.5 kB)
# INFO: pip is looking at multiple versions of dask-expr to determine which version is compatible with other requirements. This could take a while.
#   Downloading dask_expr-1.1.13-py3-none-any.whl.metadata (2.5 kB)
#   Downloading dask_expr-1.1.12-py3-none-any.whl.metadata (2.5 kB)
#   Downloading dask_expr-1.1.11-py3-none-any.whl.metadata (2.5 kB)
#   Downloading dask_expr-1.1.10-py3-none-any.whl.metadata (2.5 kB)
#   Downloading dask_expr-1.1.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyarrow>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]) (14.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]) (3.20.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (2024.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]) (1.16.0)
# Downloading dask_expr-1.1.9-py3-none-any.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.9/241.9 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: dask-expr
# Successfully installed dask-expr-1.1.9

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

# 설정 값
NFOLDS = 3
SEED = 0
NROWS = None

# 데이터 로딩
data = pd.read_csv('/content/drive/MyDrive/application_train.csv/application_train.csv')
test = pd.read_csv('/content/drive/MyDrive/application_test.csv/application_test.csv')
prev = pd.read_csv('/content/drive/MyDrive/previous_application.csv/previous_application.csv')

# 범주형 데이터를 숫자로 변환
categorical_feats = [f for f in data.columns if data[f].dtype == 'object']
for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_])
    test[f_] = indexer.get_indexer(test[f_])

gc.enable()  # 가비지 컬렉션 활성화

# 타겟 변수 분리
y_train = data['TARGET']
del data['TARGET']

# 이전 신청 데이터의 범주형 변수 변환
prev_cat_features = [f_ for f_ in prev.columns if prev[f_].dtype == 'object']
for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])

# 평균과 신청 건수 계산
avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

# 데이터 병합 및 결측치 처리
x_train = data.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')
x_test = test.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')

x_train = x_train.fillna(0)  # 결측치 0으로 채우기
x_test = x_test.fillna(0)

ntrain = x_train.shape[0]
ntest = x_test.shape[0]

# 제외할 특징 정의
excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

# 교차 검증 설정
kf = KFold(n_splits=NFOLDS, shuffle=True, random_state=SEED)

# 모델 래퍼 클래스 정의
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]

class CatboostWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]

class LightGBMWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]

class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)

    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))

# Out-of-Fold 예측 생성 함수
def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))

    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.iloc[train_index]
        y_tr = y_train.iloc[train_index]
        x_te = x_train.iloc[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# 각 모델의 파라미터 설정
et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter'
}

lightgbm_params = {
    'n_estimators': 200,
    'learning_rate': 0.1,
    'num_leaves': 123,
    'colsample_bytree': 0.8,
    'subsample': 0.9,
    'max_depth': 15,
    'reg_alpha': 0.1,
    'reg_lambda': 0.1,
    'min_split_gain': 0.01,
    'min_child_weight': 2
}

# 각 모델의 인스턴스 생성
xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf=CatBoostClassifier, seed=SEED, params=catboost_params)
lg = LightGBMWrapper(clf=LGBMClassifier, seed=SEED, params=lightgbm_params)

# Out-of-Fold 예측 생성
xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)

# 교차 검증 점수 출력
print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("CB-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))

# 스태킹을 위한 새로운 특징 생성
x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)

print("{},{}".format(x_train.shape, x_test.shape))

# 최종 메타 모델 훈련 및 예측
logistic_regression = LogisticRegression()
logistic_regression.fit(x_train, y_train)

# 최종 예측 결과 저장
test['TARGET'] = logistic_regression.predict_proba(x_test)[:, 1]
test[['SK_ID_CURR', 'TARGET']].to_csv('first_submission.csv', index=False, float_format='%.8f')
# Out:
# 0:	total: 117ms	remaining: 23.4s
# 1:	total: 182ms	remaining: 18.1s
# 2:	total: 235ms	remaining: 15.4s
# 3:	total: 294ms	remaining: 14.4s
# 4:	total: 403ms	remaining: 15.7s
# 5:	total: 459ms	remaining: 14.9s
# 6:	total: 516ms	remaining: 14.2s
# 7:	total: 569ms	remaining: 13.6s
# 8:	total: 632ms	remaining: 13.4s
# 9:	total: 703ms	remaining: 13.4s
# 10:	total: 765ms	remaining: 13.1s
# 11:	total: 825ms	remaining: 12.9s
# 12:	total: 892ms	remaining: 12.8s
# 13:	total: 952ms	remaining: 12.7s
# 14:	total: 1.02s	remaining: 12.5s
# 15:	total: 1.07s	remaining: 12.3s
# 16:	total: 1.13s	remaining: 12.2s
# 17:	total: 1.21s	remaining: 12.2s
# 18:	total: 1.27s	remaining: 12.1s
# 19:	total: 1.35s	remaining: 12.2s
# 20:	total: 1.45s	remaining: 12.3s
# 21:	total: 1.54s	remaining: 12.5s
# 22:	total: 1.65s	remaining: 12.7s
# 23:	total: 1.73s	remaining: 12.7s
# 24:	total: 1.86s	remaining: 13s
# 25:	total: 1.98s	remaining: 13.2s
# 26:	total: 2.1s	remaining: 13.4s
# 27:	total: 2.21s	remaining: 13.6s
# 28:	total: 2.32s	remaining: 13.7s
# 29:	total: 2.44s	remaining: 13.8s
# 30:	total: 2.56s	remaining: 14s
# 31:	total: 2.69s	remaining: 14.1s
# 32:	total: 2.79s	remaining: 14.1s
# 33:	total: 2.9s	remaining: 14.2s
# 34:	total: 3.02s	remaining: 14.3s
# 35:	total: 3.14s	remaining: 14.3s
# 36:	total: 3.25s	remaining: 14.3s
# 37:	total: 3.36s	remaining: 14.3s
# 38:	total: 3.47s	remaining: 14.3s
# 39:	total: 3.61s	remaining: 14.4s
# 40:	total: 3.72s	remaining: 14.4s
# 41:	total: 3.82s	remaining: 14.4s
# 42:	total: 3.93s	remaining: 14.4s
# 43:	total: 4.06s	remaining: 14.4s
# 44:	total: 4.17s	remaining: 14.4s
# 45:	total: 4.28s	remaining: 14.3s
# 46:	total: 4.39s	remaining: 14.3s
# 47:	total: 4.51s	remaining: 14.3s
# 48:	total: 4.62s	remaining: 14.2s
# 49:	total: 4.73s	remaining: 14.2s
# 50:	total: 4.86s	remaining: 14.2s
# 51:	total: 4.97s	remaining: 14.1s
# 52:	total: 5.09s	remaining: 14.1s
# 53:	total: 5.22s	remaining: 14.1s
# 54:	total: 5.3s	remaining: 14s
# 55:	total: 5.35s	remaining: 13.8s
# 56:	total: 5.41s	remaining: 13.6s
# 57:	total: 5.46s	remaining: 13.4s
# 58:	total: 5.51s	remaining: 13.2s
# 59:	total: 5.57s	remaining: 13s
# 60:	total: 5.63s	remaining: 12.8s
# 61:	total: 5.7s	remaining: 12.7s
# 62:	total: 5.75s	remaining: 12.5s
# 63:	total: 5.81s	remaining: 12.4s
# 64:	total: 5.87s	remaining: 12.2s
# 65:	total: 5.93s	remaining: 12s
# 66:	total: 5.99s	remaining: 11.9s
# 67:	total: 6.05s	remaining: 11.7s
# 68:	total: 6.12s	remaining: 11.6s
# 69:	total: 6.17s	remaining: 11.5s
# 70:	total: 6.23s	remaining: 11.3s
# 71:	total: 6.29s	remaining: 11.2s
# 72:	total: 6.34s	remaining: 11s
# 73:	total: 6.39s	remaining: 10.9s
# 74:	total: 6.46s	remaining: 10.8s
# 75:	total: 6.52s	remaining: 10.6s
# 76:	total: 6.57s	remaining: 10.5s
# 77:	total: 6.63s	remaining: 10.4s
# 78:	total: 6.69s	remaining: 10.2s
# 79:	total: 6.74s	remaining: 10.1s
# 80:	total: 6.8s	remaining: 9.99s
# 81:	total: 6.86s	remaining: 9.87s
# 82:	total: 6.92s	remaining: 9.76s
# 83:	total: 6.98s	remaining: 9.63s
# 84:	total: 7.03s	remaining: 9.52s
# 85:	total: 7.09s	remaining: 9.4s
# 86:	total: 7.16s	remaining: 9.29s
# 87:	total: 7.22s	remaining: 9.19s
# 88:	total: 7.27s	remaining: 9.07s
# 89:	total: 7.33s	remaining: 8.96s
# 90:	total: 7.38s	remaining: 8.84s
# 91:	total: 7.44s	remaining: 8.74s
# 92:	total: 7.5s	remaining: 8.63s
# 93:	total: 7.55s	remaining: 8.52s
# 94:	total: 7.61s	remaining: 8.41s
# 95:	total: 7.67s	remaining: 8.3s
# 96:	total: 7.72s	remaining: 8.2s
# 97:	total: 7.78s	remaining: 8.09s
# 98:	total: 7.85s	remaining: 8.01s
# 99:	total: 7.91s	remaining: 7.91s
# 100:	total: 7.98s	remaining: 7.82s
# 101:	total: 8.04s	remaining: 7.72s
# 102:	total: 8.11s	remaining: 7.63s
# 103:	total: 8.16s	remaining: 7.54s
# 104:	total: 8.22s	remaining: 7.44s
# 105:	total: 8.28s	remaining: 7.34s
# 106:	total: 8.34s	remaining: 7.25s
# 107:	total: 8.39s	remaining: 7.15s
# 108:	total: 8.45s	remaining: 7.05s
# 109:	total: 8.5s	remaining: 6.96s
# 110:	total: 8.56s	remaining: 6.87s
# 111:	total: 8.62s	remaining: 6.77s
# 112:	total: 8.68s	remaining: 6.68s
# 113:	total: 8.73s	remaining: 6.59s
# 114:	total: 8.79s	remaining: 6.5s
# 115:	total: 8.84s	remaining: 6.4s
# 116:	total: 8.9s	remaining: 6.31s
# 117:	total: 8.96s	remaining: 6.23s
# 118:	total: 9.04s	remaining: 6.15s
# 119:	total: 9.1s	remaining: 6.06s
# 120:	total: 9.15s	remaining: 5.98s
# 121:	total: 9.22s	remaining: 5.89s
# 122:	total: 9.28s	remaining: 5.81s
# 123:	total: 9.33s	remaining: 5.72s
# 124:	total: 9.39s	remaining: 5.63s
# 125:	total: 9.44s	remaining: 5.55s
# 126:	total: 9.49s	remaining: 5.46s
# 127:	total: 9.56s	remaining: 5.38s
# 128:	total: 9.62s	remaining: 5.29s
# 129:	total: 9.68s	remaining: 5.21s
# 130:	total: 9.74s	remaining: 5.13s
# 131:	total: 9.79s	remaining: 5.04s
# 132:	total: 9.85s	remaining: 4.96s
# 133:	total: 9.91s	remaining: 4.88s
# 134:	total: 9.97s	remaining: 4.8s
# 135:	total: 10s	remaining: 4.73s
# 136:	total: 10.1s	remaining: 4.65s
# 137:	total: 10.2s	remaining: 4.56s
# 138:	total: 10.2s	remaining: 4.49s
# 139:	total: 10.3s	remaining: 4.41s
# 140:	total: 10.3s	remaining: 4.33s
# 141:	total: 10.4s	remaining: 4.25s
# 142:	total: 10.5s	remaining: 4.17s
# 143:	total: 10.5s	remaining: 4.08s
# 144:	total: 10.6s	remaining: 4.01s
# 145:	total: 10.6s	remaining: 3.93s
# 146:	total: 10.7s	remaining: 3.85s
# 147:	total: 10.7s	remaining: 3.77s
# 148:	total: 10.8s	remaining: 3.69s
# 149:	total: 10.8s	remaining: 3.62s
# 150:	total: 10.9s	remaining: 3.54s
# 151:	total: 11s	remaining: 3.46s
# 152:	total: 11s	remaining: 3.39s
# 153:	total: 11.1s	remaining: 3.31s
# 154:	total: 11.2s	remaining: 3.24s
# 155:	total: 11.3s	remaining: 3.17s
# 156:	total: 11.3s	remaining: 3.1s
# 157:	total: 11.4s	remaining: 3.02s
# 158:	total: 11.4s	remaining: 2.95s
# 159:	total: 11.5s	remaining: 2.87s
# 160:	total: 11.5s	remaining: 2.8s
# 161:	total: 11.6s	remaining: 2.72s
# 162:	total: 11.7s	remaining: 2.65s
# 163:	total: 11.7s	remaining: 2.57s
# 164:	total: 11.8s	remaining: 2.5s
# 165:	total: 11.8s	remaining: 2.42s
# 166:	total: 11.9s	remaining: 2.35s
# 167:	total: 12s	remaining: 2.28s
# 168:	total: 12s	remaining: 2.2s
# 169:	total: 12.1s	remaining: 2.13s
# 170:	total: 12.2s	remaining: 2.06s
# 171:	total: 12.2s	remaining: 1.99s
# 172:	total: 12.3s	remaining: 1.91s
# 173:	total: 12.3s	remaining: 1.84s
# 174:	total: 12.4s	remaining: 1.77s
# 175:	total: 12.4s	remaining: 1.7s
# 176:	total: 12.5s	remaining: 1.62s
# 177:	total: 12.5s	remaining: 1.55s
# 178:	total: 12.6s	remaining: 1.48s
# 179:	total: 12.7s	remaining: 1.41s
# 180:	total: 12.7s	remaining: 1.33s
# 181:	total: 12.8s	remaining: 1.26s
# 182:	total: 12.8s	remaining: 1.19s
# 183:	total: 12.9s	remaining: 1.12s
# 184:	total: 12.9s	remaining: 1.05s
# 185:	total: 13s	remaining: 978ms
# 186:	total: 13s	remaining: 907ms
# 187:	total: 13.1s	remaining: 837ms
# 188:	total: 13.2s	remaining: 767ms
# 189:	total: 13.2s	remaining: 696ms
# 190:	total: 13.3s	remaining: 626ms
# 191:	total: 13.3s	remaining: 556ms
# 192:	total: 13.4s	remaining: 486ms
# 193:	total: 13.4s	remaining: 416ms
# 194:	total: 13.5s	remaining: 346ms
# 195:	total: 13.6s	remaining: 277ms
# 196:	total: 13.6s	remaining: 207ms
# 197:	total: 13.7s	remaining: 138ms
# 198:	total: 13.7s	remaining: 69ms
# 199:	total: 13.8s	remaining: 0us
# 0:	total: 130ms	remaining: 25.9s
# 1:	total: 226ms	remaining: 22.4s
# 2:	total: 337ms	remaining: 22.1s
# 3:	total: 455ms	remaining: 22.3s
# 4:	total: 584ms	remaining: 22.8s
# 5:	total: 708ms	remaining: 22.9s
# 6:	total: 826ms	remaining: 22.8s
# 7:	total: 949ms	remaining: 22.8s
# 8:	total: 1.06s	remaining: 22.6s
# 9:	total: 1.2s	remaining: 22.9s
# 10:	total: 1.32s	remaining: 22.7s
# 11:	total: 1.44s	remaining: 22.5s
# 12:	total: 1.55s	remaining: 22.3s
# 13:	total: 1.65s	remaining: 21.9s
# 14:	total: 1.76s	remaining: 21.7s
# 15:	total: 1.87s	remaining: 21.5s
# 16:	total: 1.95s	remaining: 21s
# 17:	total: 2.04s	remaining: 20.7s
# 18:	total: 2.16s	remaining: 20.6s
# 19:	total: 2.29s	remaining: 20.6s
# 20:	total: 2.43s	remaining: 20.7s
# 21:	total: 2.54s	remaining: 20.6s
# 22:	total: 2.66s	remaining: 20.4s
# 23:	total: 2.78s	remaining: 20.4s
# 24:	total: 2.9s	remaining: 20.3s
# 25:	total: 2.96s	remaining: 19.8s
# 26:	total: 3.02s	remaining: 19.3s
# 27:	total: 3.07s	remaining: 18.9s
# 28:	total: 3.13s	remaining: 18.4s
# 29:	total: 3.18s	remaining: 18s
# 30:	total: 3.24s	remaining: 17.7s
# 31:	total: 3.3s	remaining: 17.3s
# 32:	total: 3.36s	remaining: 17s
# 33:	total: 3.42s	remaining: 16.7s
# 34:	total: 3.48s	remaining: 16.4s
# 35:	total: 3.55s	remaining: 16.2s
# 36:	total: 3.62s	remaining: 15.9s
# 37:	total: 3.68s	remaining: 15.7s
# 38:	total: 3.74s	remaining: 15.4s
# 39:	total: 3.79s	remaining: 15.2s
# 40:	total: 3.87s	remaining: 15s
# 41:	total: 3.92s	remaining: 14.8s
# 42:	total: 3.99s	remaining: 14.6s
# 43:	total: 4.05s	remaining: 14.3s
# 44:	total: 4.11s	remaining: 14.2s
# 45:	total: 4.16s	remaining: 13.9s
# 46:	total: 4.22s	remaining: 13.8s
# 47:	total: 4.28s	remaining: 13.6s
# 48:	total: 4.34s	remaining: 13.4s
# 49:	total: 4.41s	remaining: 13.2s
# 50:	total: 4.46s	remaining: 13s
# 51:	total: 4.52s	remaining: 12.9s
# 52:	total: 4.59s	remaining: 12.7s
# 53:	total: 4.65s	remaining: 12.6s
# 54:	total: 4.71s	remaining: 12.4s
# 55:	total: 4.76s	remaining: 12.2s
# 56:	total: 4.82s	remaining: 12.1s
# 57:	total: 4.88s	remaining: 11.9s
# 58:	total: 4.94s	remaining: 11.8s
# 59:	total: 5s	remaining: 11.7s
# 60:	total: 5.05s	remaining: 11.5s
# 61:	total: 5.11s	remaining: 11.4s
# 62:	total: 5.17s	remaining: 11.2s
# 63:	total: 5.23s	remaining: 11.1s
# 64:	total: 5.28s	remaining: 11s
# 65:	total: 5.35s	remaining: 10.9s
# 66:	total: 5.4s	remaining: 10.7s
# 67:	total: 5.46s	remaining: 10.6s
# 68:	total: 5.52s	remaining: 10.5s
# 69:	total: 5.58s	remaining: 10.4s
# 70:	total: 5.64s	remaining: 10.3s
# 71:	total: 5.7s	remaining: 10.1s
# 72:	total: 5.76s	remaining: 10s
# 73:	total: 5.82s	remaining: 9.9s
# 74:	total: 5.88s	remaining: 9.8s
# 75:	total: 5.95s	remaining: 9.71s
# 76:	total: 6.01s	remaining: 9.6s
# 77:	total: 6.07s	remaining: 9.49s
# 78:	total: 6.12s	remaining: 9.38s
# 79:	total: 6.18s	remaining: 9.27s
# 80:	total: 6.24s	remaining: 9.17s
# 81:	total: 6.3s	remaining: 9.07s
# 82:	total: 6.36s	remaining: 8.97s
# 83:	total: 6.42s	remaining: 8.86s
# 84:	total: 6.47s	remaining: 8.75s
# 85:	total: 6.54s	remaining: 8.66s
# 86:	total: 6.6s	remaining: 8.57s
# 87:	total: 6.67s	remaining: 8.5s
# 88:	total: 6.73s	remaining: 8.39s
# 89:	total: 6.78s	remaining: 8.29s
# 90:	total: 6.84s	remaining: 8.2s
# 91:	total: 6.9s	remaining: 8.1s
# 92:	total: 6.96s	remaining: 8.01s
# 93:	total: 7.03s	remaining: 7.92s
# 94:	total: 7.08s	remaining: 7.83s
# 95:	total: 7.14s	remaining: 7.74s
# 96:	total: 7.21s	remaining: 7.65s
# 97:	total: 7.27s	remaining: 7.57s
# 98:	total: 7.32s	remaining: 7.47s
# 99:	total: 7.38s	remaining: 7.38s
# 100:	total: 7.43s	remaining: 7.28s
# 101:	total: 7.49s	remaining: 7.19s
# 102:	total: 7.55s	remaining: 7.12s
# 103:	total: 7.62s	remaining: 7.03s
# 104:	total: 7.67s	remaining: 6.94s
# 105:	total: 7.73s	remaining: 6.86s
# 106:	total: 7.79s	remaining: 6.77s
# 107:	total: 7.85s	remaining: 6.69s
# 108:	total: 7.92s	remaining: 6.61s
# 109:	total: 8s	remaining: 6.54s
# 110:	total: 8.06s	remaining: 6.46s
# 111:	total: 8.11s	remaining: 6.37s
# 112:	total: 8.16s	remaining: 6.28s
# 113:	total: 8.22s	remaining: 6.2s
# 114:	total: 8.28s	remaining: 6.12s
# 115:	total: 8.32s	remaining: 6.03s
# 116:	total: 8.38s	remaining: 5.95s
# 117:	total: 8.44s	remaining: 5.87s
# 118:	total: 8.5s	remaining: 5.79s
# 119:	total: 8.57s	remaining: 5.71s
# 120:	total: 8.63s	remaining: 5.63s
# 121:	total: 8.69s	remaining: 5.55s
# 122:	total: 8.74s	remaining: 5.47s
# 123:	total: 8.8s	remaining: 5.39s
# 124:	total: 8.86s	remaining: 5.31s
# 125:	total: 8.93s	remaining: 5.24s
# 126:	total: 8.98s	remaining: 5.16s
# 127:	total: 9.04s	remaining: 5.09s
# 128:	total: 9.1s	remaining: 5.01s
# 129:	total: 9.17s	remaining: 4.94s
# 130:	total: 9.23s	remaining: 4.86s
# 131:	total: 9.28s	remaining: 4.78s
# 132:	total: 9.34s	remaining: 4.7s
# 133:	total: 9.41s	remaining: 4.63s
# 134:	total: 9.46s	remaining: 4.56s
# 135:	total: 9.52s	remaining: 4.48s
# 136:	total: 9.59s	remaining: 4.41s
# 137:	total: 9.65s	remaining: 4.33s
# 138:	total: 9.71s	remaining: 4.26s
# 139:	total: 9.77s	remaining: 4.19s
# 140:	total: 9.82s	remaining: 4.11s
# 141:	total: 9.88s	remaining: 4.04s
# 142:	total: 9.94s	remaining: 3.96s
# 143:	total: 10s	remaining: 3.89s
# 144:	total: 10.1s	remaining: 3.82s
# 145:	total: 10.1s	remaining: 3.75s
# 146:	total: 10.2s	remaining: 3.67s
# 147:	total: 10.2s	remaining: 3.6s
# 148:	total: 10.3s	remaining: 3.52s
# 149:	total: 10.4s	remaining: 3.45s
# 150:	total: 10.4s	remaining: 3.38s
# 151:	total: 10.5s	remaining: 3.31s
# 152:	total: 10.5s	remaining: 3.23s
# 153:	total: 10.6s	remaining: 3.16s
# 154:	total: 10.6s	remaining: 3.09s
# 155:	total: 10.7s	remaining: 3.02s
# 156:	total: 10.8s	remaining: 2.94s
# 157:	total: 10.8s	remaining: 2.87s
# 158:	total: 10.9s	remaining: 2.8s
# 159:	total: 10.9s	remaining: 2.73s
# 160:	total: 11s	remaining: 2.66s
# 161:	total: 11.1s	remaining: 2.59s
# 162:	total: 11.1s	remaining: 2.52s
# 163:	total: 11.2s	remaining: 2.45s
# 164:	total: 11.2s	remaining: 2.38s
# 165:	total: 11.3s	remaining: 2.31s
# 166:	total: 11.3s	remaining: 2.24s
# 167:	total: 11.4s	remaining: 2.17s
# 168:	total: 11.5s	remaining: 2.1s
# 169:	total: 11.5s	remaining: 2.03s
# 170:	total: 11.6s	remaining: 1.97s
# 171:	total: 11.6s	remaining: 1.9s
# 172:	total: 11.7s	remaining: 1.82s
# 173:	total: 11.8s	remaining: 1.76s
# 174:	total: 11.8s	remaining: 1.69s
# 175:	total: 11.9s	remaining: 1.62s
# 176:	total: 11.9s	remaining: 1.55s
# 177:	total: 12s	remaining: 1.48s
# 178:	total: 12.1s	remaining: 1.42s
# 179:	total: 12.1s	remaining: 1.35s
# 180:	total: 12.2s	remaining: 1.28s
# 181:	total: 12.2s	remaining: 1.21s
# 182:	total: 12.3s	remaining: 1.14s
# 183:	total: 12.4s	remaining: 1.07s
# 184:	total: 12.4s	remaining: 1.01s
# 185:	total: 12.5s	remaining: 939ms
# 186:	total: 12.5s	remaining: 872ms
# 187:	total: 12.6s	remaining: 804ms
# 188:	total: 12.7s	remaining: 737ms
# 189:	total: 12.7s	remaining: 670ms
# 190:	total: 12.8s	remaining: 603ms
# 191:	total: 12.8s	remaining: 535ms
# 192:	total: 12.9s	remaining: 468ms
# 193:	total: 13s	remaining: 402ms
# 194:	total: 13.1s	remaining: 337ms
# 195:	total: 13.2s	remaining: 270ms
# 196:	total: 13.3s	remaining: 203ms
# 197:	total: 13.4s	remaining: 136ms
# 198:	total: 13.6s	remaining: 68.1ms
# 199:	total: 13.7s	remaining: 0us
# 0:	total: 66.8ms	remaining: 13.3s
# 1:	total: 123ms	remaining: 12.2s
# 2:	total: 180ms	remaining: 11.8s
# 3:	total: 246ms	remaining: 12.1s
# 4:	total: 314ms	remaining: 12.2s
# 5:	total: 378ms	remaining: 12.2s
# 6:	total: 435ms	remaining: 12s
# 7:	total: 500ms	remaining: 12s
# 8:	total: 559ms	remaining: 11.9s
# 9:	total: 620ms	remaining: 11.8s
# 10:	total: 677ms	remaining: 11.6s
# 11:	total: 731ms	remaining: 11.5s
# 12:	total: 796ms	remaining: 11.5s
# 13:	total: 866ms	remaining: 11.5s
# 14:	total: 931ms	remaining: 11.5s
# 15:	total: 998ms	remaining: 11.5s
# 16:	total: 1.07s	remaining: 11.5s
# 17:	total: 1.13s	remaining: 11.5s
# 18:	total: 1.19s	remaining: 11.4s
# 19:	total: 1.28s	remaining: 11.5s
# 20:	total: 1.34s	remaining: 11.4s
# 21:	total: 1.39s	remaining: 11.3s
# 22:	total: 1.45s	remaining: 11.2s
# 23:	total: 1.52s	remaining: 11.1s
# 24:	total: 1.57s	remaining: 11s
# 25:	total: 1.62s	remaining: 10.9s
# 26:	total: 1.68s	remaining: 10.8s
# 27:	total: 1.75s	remaining: 10.7s
# 28:	total: 1.8s	remaining: 10.6s
# 29:	total: 1.85s	remaining: 10.5s
# 30:	total: 1.91s	remaining: 10.4s
# 31:	total: 1.97s	remaining: 10.3s
# 32:	total: 2.02s	remaining: 10.2s
# 33:	total: 2.09s	remaining: 10.2s
# 34:	total: 2.14s	remaining: 10.1s
# 35:	total: 2.21s	remaining: 10.1s
# 36:	total: 2.27s	remaining: 10s
# 37:	total: 2.32s	remaining: 9.91s
# 38:	total: 2.38s	remaining: 9.8s
# 39:	total: 2.44s	remaining: 9.75s
# 40:	total: 2.5s	remaining: 9.68s
# 41:	total: 2.56s	remaining: 9.63s
# 42:	total: 2.62s	remaining: 9.55s
# 43:	total: 2.68s	remaining: 9.51s
# 44:	total: 2.73s	remaining: 9.41s
# 45:	total: 2.79s	remaining: 9.33s
# 46:	total: 2.85s	remaining: 9.28s
# 47:	total: 2.92s	remaining: 9.24s
# 48:	total: 2.97s	remaining: 9.17s
# 49:	total: 3.03s	remaining: 9.1s
# 50:	total: 3.1s	remaining: 9.05s
# 51:	total: 3.16s	remaining: 8.99s
# 52:	total: 3.22s	remaining: 8.92s
# 53:	total: 3.28s	remaining: 8.88s
# 54:	total: 3.35s	remaining: 8.83s
# 55:	total: 3.41s	remaining: 8.77s
# 56:	total: 3.47s	remaining: 8.7s
# 57:	total: 3.52s	remaining: 8.62s
# 58:	total: 3.59s	remaining: 8.57s
# 59:	total: 3.64s	remaining: 8.49s
# 60:	total: 3.71s	remaining: 8.44s
# 61:	total: 3.77s	remaining: 8.38s
# 62:	total: 3.82s	remaining: 8.31s
# 63:	total: 3.88s	remaining: 8.24s
# 64:	total: 3.94s	remaining: 8.18s
# 65:	total: 3.99s	remaining: 8.11s
# 66:	total: 4.05s	remaining: 8.04s
# 67:	total: 4.12s	remaining: 8s
# 68:	total: 4.18s	remaining: 7.94s
# 69:	total: 4.25s	remaining: 7.9s
# 70:	total: 4.32s	remaining: 7.84s
# 71:	total: 4.38s	remaining: 7.78s
# 72:	total: 4.43s	remaining: 7.71s
# 73:	total: 4.49s	remaining: 7.65s
# 74:	total: 4.54s	remaining: 7.57s
# 75:	total: 4.6s	remaining: 7.51s
# 76:	total: 4.67s	remaining: 7.45s
# 77:	total: 4.73s	remaining: 7.39s
# 78:	total: 4.79s	remaining: 7.33s
# 79:	total: 4.84s	remaining: 7.27s
# 80:	total: 4.9s	remaining: 7.2s
# 81:	total: 4.96s	remaining: 7.13s
# 82:	total: 5.01s	remaining: 7.06s
# 83:	total: 5.08s	remaining: 7.01s
# 84:	total: 5.15s	remaining: 6.96s
# 85:	total: 5.21s	remaining: 6.91s
# 86:	total: 5.27s	remaining: 6.85s
# 87:	total: 5.33s	remaining: 6.78s
# 88:	total: 5.39s	remaining: 6.73s
# 89:	total: 5.47s	remaining: 6.68s
# 90:	total: 5.52s	remaining: 6.61s
# 91:	total: 5.59s	remaining: 6.57s
# 92:	total: 5.65s	remaining: 6.5s
# 93:	total: 5.71s	remaining: 6.44s
# 94:	total: 5.76s	remaining: 6.37s
# 95:	total: 5.82s	remaining: 6.3s
# 96:	total: 5.88s	remaining: 6.24s
# 97:	total: 5.93s	remaining: 6.17s
# 98:	total: 5.99s	remaining: 6.11s
# 99:	total: 6.05s	remaining: 6.05s
# 100:	total: 6.1s	remaining: 5.98s
# 101:	total: 6.17s	remaining: 5.93s
# 102:	total: 6.23s	remaining: 5.87s
# 103:	total: 6.29s	remaining: 5.81s
# 104:	total: 6.34s	remaining: 5.74s
# 105:	total: 6.4s	remaining: 5.67s
# 106:	total: 6.45s	remaining: 5.61s
# 107:	total: 6.51s	remaining: 5.54s
# 108:	total: 6.56s	remaining: 5.48s
# 109:	total: 6.62s	remaining: 5.41s
# 110:	total: 6.67s	remaining: 5.35s
# 111:	total: 6.73s	remaining: 5.29s
# 112:	total: 6.79s	remaining: 5.22s
# 113:	total: 6.84s	remaining: 5.16s
# 114:	total: 6.9s	remaining: 5.1s
# 115:	total: 6.95s	remaining: 5.03s
# 116:	total: 7.02s	remaining: 4.98s
# 117:	total: 7.08s	remaining: 4.92s
# 118:	total: 7.15s	remaining: 4.87s
# 119:	total: 7.25s	remaining: 4.83s
# 120:	total: 7.3s	remaining: 4.77s
# 121:	total: 7.37s	remaining: 4.71s
# 122:	total: 7.46s	remaining: 4.67s
# 123:	total: 7.52s	remaining: 4.61s
# 124:	total: 7.58s	remaining: 4.55s
# 125:	total: 7.64s	remaining: 4.49s
# 126:	total: 7.7s	remaining: 4.42s
# 127:	total: 7.75s	remaining: 4.36s
# 128:	total: 7.8s	remaining: 4.29s
# 129:	total: 7.85s	remaining: 4.23s
# 130:	total: 7.93s	remaining: 4.18s
# 131:	total: 7.99s	remaining: 4.12s
# 132:	total: 8.04s	remaining: 4.05s
# 133:	total: 8.12s	remaining: 4s
# 134:	total: 8.19s	remaining: 3.94s
# 135:	total: 8.27s	remaining: 3.89s
# 136:	total: 8.32s	remaining: 3.83s
# 137:	total: 8.37s	remaining: 3.76s
# 138:	total: 8.45s	remaining: 3.71s
# 139:	total: 8.51s	remaining: 3.65s
# 140:	total: 8.56s	remaining: 3.58s
# 141:	total: 8.62s	remaining: 3.52s
# 142:	total: 8.67s	remaining: 3.46s
# 143:	total: 8.74s	remaining: 3.4s
# 144:	total: 8.79s	remaining: 3.33s
# 145:	total: 8.85s	remaining: 3.27s
# 146:	total: 8.92s	remaining: 3.21s
# 147:	total: 8.97s	remaining: 3.15s
# 148:	total: 9.03s	remaining: 3.09s
# 149:	total: 9.08s	remaining: 3.03s
# 150:	total: 9.15s	remaining: 2.97s
# 151:	total: 9.21s	remaining: 2.91s
# 152:	total: 9.28s	remaining: 2.85s
# 153:	total: 9.34s	remaining: 2.79s
# 154:	total: 9.4s	remaining: 2.73s
# 155:	total: 9.46s	remaining: 2.67s
# 156:	total: 9.52s	remaining: 2.61s
# 157:	total: 9.58s	remaining: 2.54s
# 158:	total: 9.64s	remaining: 2.48s
# 159:	total: 9.69s	remaining: 2.42s
# 160:	total: 9.76s	remaining: 2.36s
# 161:	total: 9.82s	remaining: 2.3s
# 162:	total: 9.89s	remaining: 2.25s
# 163:	total: 9.98s	remaining: 2.19s
# 164:	total: 10.1s	remaining: 2.14s
# 165:	total: 10.2s	remaining: 2.09s
# 166:	total: 10.3s	remaining: 2.04s
# 167:	total: 10.5s	remaining: 1.99s
# 168:	total: 10.6s	remaining: 1.94s
# 169:	total: 10.7s	remaining: 1.89s
# 170:	total: 10.8s	remaining: 1.84s
# 171:	total: 10.9s	remaining: 1.78s
# 172:	total: 11.1s	remaining: 1.73s
# 173:	total: 11.2s	remaining: 1.67s
# 174:	total: 11.3s	remaining: 1.61s
# 175:	total: 11.4s	remaining: 1.55s
# 176:	total: 11.5s	remaining: 1.49s
# 177:	total: 11.6s	remaining: 1.43s
# 178:	total: 11.7s	remaining: 1.37s
# 179:	total: 11.8s	remaining: 1.31s
# 180:	total: 11.9s	remaining: 1.25s
# 181:	total: 12s	remaining: 1.19s
# 182:	total: 12.1s	remaining: 1.13s
# 183:	total: 12.2s	remaining: 1.06s
# 184:	total: 12.4s	remaining: 1s
# 185:	total: 12.5s	remaining: 939ms
# 186:	total: 12.6s	remaining: 875ms
# 187:	total: 12.7s	remaining: 811ms
# 188:	total: 12.8s	remaining: 746ms
# 189:	total: 12.9s	remaining: 680ms
# 190:	total: 13s	remaining: 614ms
# 191:	total: 13.1s	remaining: 548ms
# 192:	total: 13.2s	remaining: 480ms
# 193:	total: 13.3s	remaining: 413ms
# 194:	total: 13.4s	remaining: 344ms
# 195:	total: 13.5s	remaining: 275ms
# 196:	total: 13.5s	remaining: 206ms
# 197:	total: 13.6s	remaining: 137ms
# 198:	total: 13.7s	remaining: 68.7ms
# 199:	total: 13.7s	remaining: 0us
# XG-CV: 0.2597865314464895
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629856213006646
# CB-CV: 0.3309547098229581
# (307511, 4),(48744, 4)
